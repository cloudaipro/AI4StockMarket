# %%
# %matplotlib inline
from IPython.display import display

import torch
import random
import pandas as pd
import numpy as np
import pandas_datareader.data as web
from matplotlib import pyplot
import seaborn as sns
import os
import sys

#Plotting 
from pandas.plotting import scatter_matrix

#Libraries for Statistical Models
import statsmodels.api as sm

#logging
from MyPyUtil.logconf import logging
log = logging.getLogger(__name__)
# log.setLevel(logging.ERROR)
log.setLevel(logging.INFO)
# log.setLevel(logging.WARN)
# log.setLevel(logging.DEBUG)


#Diable the warnings
import warnings
warnings.filterwarnings('ignore')

pd.options.display.max_columns = None
pd.options.display.expand_frame_repr = False
pd.options.display.float_format = '{:.3f}'.format

# max output width in numpy
np.set_printoptions(
    threshold=sys.maxsize,  # 20,
    edgeitems=10,
    linewidth=140,
    formatter=dict(float=lambda x: "%.3g" % x),
)  # float arrays %.3g


torch.seed = 42
random.seed(42)
np.random.seed(42)

# %run 'nb_utils.ipynb'
task_name = "StockPCTLabelPredictLSTM_A3" # get_filename_of_ipynb()
print(task_name)
data_dir = f'{os.getcwd()}/data/'
log_dir_base = f'{os.getcwd()}/runs/{task_name}'
if os.path.exists(log_dir_base) == False:
    os.mkdir(log_dir_base)
log_dir = log_dir_base
print(f'{data_dir}\n{log_dir}')
# Out:
# StockPCTLabelPredictLSTM_A3
# /mnt/AIWorkSpace/work/AI4StockMarket/data/
# /mnt/AIWorkSpace/work/AI4StockMarket/runs/StockPCTLabelPredictLSTM_A3

# %%
# hyperparameters turning
from ray import tune, train, ray
from ray.tune.schedulers import ASHAScheduler

ray.init(log_to_driver=False)
# Out:
# 2024-02-28 15:39:25,811	INFO worker.py:1715 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.8.18', ray_version='2.9.1', ray_commit='cfbf98c315cfb2710c56039a3c96477d196de049', protocol_version=None)

# %%
stk_symbols = [
    "AAPL",
    "MSFT",
    "AMZN",
    "NVDA",
    "GOOGL",
    "GOOG",
    "META",
    "TSLA",
    "UNH",
    "LLY",
    "JPM",
    "XOM",
    "JNJ",
    "V",
    "PG",
    "AVGO",
    "MA",
    "HD",
    "CVX",
    "MRK",
    "ABBV",
    "PEP",
    "COST",
    "ADBE",
    "KO",
    "CSCO",
    "WMT",
    "TMO",
    "MCD",
    "PFE",
    "CRM",
    "BAC",
    "ACN",
    "CMCSA",
    "LIN",
    "NFLX",
    "ABT",
    "ORCL",
    "DHR",
    "AMD",
    "WFC",
    "DIS",
    "TXN",
    "PM",
    "VZ",
    "INTU",
    "COP",
    "CAT",
    "AMGN",
    "NEE",
    "INTC",
    "UNP",
    "LOW",
    "IBM",
    "BMY",
    "SPGI",
    "RTX",
    "HON",
    "BA",
    "UPS",
    "GE",
    "QCOM",
    "AMAT",
    "NKE",
    "PLD",
    "NOW",
    "BKNG",
    "SBUX",
    "MS",
    "ELV",
    "MDT",
    "GS",
    "DE",
    "ADP",
    "LMT",
    "TJX",
    "T",
    "BLK",
    "ISRG",
    "MDLZ",
    "GILD",
    "MMC",
    "AXP",
    "SYK",
    "REGN",
    "VRTX",
    "ETN",
    "LRCX",
    "ADI",
    "SCHW",
    "CVS",
    "ZTS",
    "CI",
    "CB",
    "AMT",
    "SLB",
    "C",
    "BDX",
    "MO",
    "PGR",
    "TMUS",
    "FI",
    "SO",
    "EOG",
    "BSX",
    "CME",
    "EQIX",
    "MU",
    "DUK",
    "PANW",
    "PYPL",
    "AON",
    "SNPS",
    "ITW",
    "KLAC",
    "LULU",
    "ICE",
    "APD",
    "SHW",
    "CDNS",
    "CSX",
    "NOC",
    "CL",
    "MPC",
    "HUM",
    "FDX",
    "WM",
    "MCK",
    "TGT",
    "ORLY",
    "HCA",
    "FCX",
    "EMR",
    "PXD",
    "MMM",
    "MCO",
    "ROP",
    "CMG",
    "PSX",
    "MAR",
    "PH",
    "APH",
    "GD",
    "USB",
    "NXPI",
    "AJG",
    "NSC",
    "PNC",
    "VLO",
    "GBP",
    "F",
    "MSI",
    "GM",
    "TT",
    "EW",
    "CARR",
    "AZO",
    "ADSK",
    "TDG",
    "ANET",
    "SRE",
    "ECL",
    "OXY",
    "PCAR",
    "ADM",
    "MNST",
    "KMB",
    "PSA",
    "CCI",
    "CHTR",
    "MCHP",
    "MSCI",
    "CTAS",
    "WMB",
    "AIG",
    "STZ",
    "HES",
    "NUE",
    "ROST",
    "AFL",
    "AEP",
    "IDXX",
    "D",
    "TEL",
    "JCI",
    "MET",
    "GIS",
    "IQV",
    "EXC",
    "WELL",
    "DXCM",
    "HLT",
    "ON",
    "COF",
    "PAYX",
    "TFC",
    "USD",
    "BIIB",
    "O",
    "FTNT",
    "DOW",
    "TRV",
    "DLR",
    "MRNA",
    "CPRT",
    "ODFL",
    "DHI",
    "YUM",
    "SPG",
    "CTSH",
    "AME",
    "BKR",
    "SYY",
    "A",
    "CTVA",
    "CNC",
    "EL",
    "AMP",
    # "CEG",  # PCT <= -0.05,  size = 0
    "HAL",
    # "OTIS",  # PCT <= -0.05,  size = 0
    "ROK",
    "PRU",
    "DD",
    "KMI",
    "VRSK",
    "LHX",
    "DG",
    "FIS",
    "CMI",
    "CSGP",
    "FAST",
    "PPG",
    "GPN",
    "GWW",
    "HSY",
    "BK",
    "XEL",
    "DVN",
    "EA",
    "NEM",
    "ED",
    "URI",
    "VICI",
    "PEG",
    "KR",
    "RSG",
    "LEN",
    "PWR",
    "WST",
    "COR",
    "OKE",
    "VMC",
    "KDP",
    "WBD",
    "ACGL",
    "ALL",
    "IR",
    "CDW",
    "FANG",
    "MLM",
    "PCG",
    "DAL",
    "EXR",
    "FTV",
    "AWK",
    "IT",
    "KHC",
    # "GEHC",  # PCT <= -0.05,  size = 0
    "WEC",
    "HPQ",
    "EIX",
    "CBRE",
    "APTV",
    "ANSS",
    "MTD",
    "DLTR",
    "AVB",
    "ILMN",
    "ALGN",
    "LYB",
    "TROW",
    "GLW",
    "EFX",
    "WY",
    "ZBH",
    "XYL",
    "SBAC",
    "RMD",
    "TSCO",
    "EBAY",
    "KEYS",
    "CHD",
    "STT",
    "DFS",
    "HIG",
    "ALB",
    "STE",
    "ES",
    "TTWO",
    "MPWR",
    "CAH",
    "EQR",
    "RCL",
    "WTW",
    "HPE",
    "DTE",
    "GPC",
    "BR",
    "ULTA",
    "FICO",
    "CTRA",
    "BAX",
    "AEE",
    "MTB",
    "MKC",
    "ETR",
    "WAB",
    "DOV",
    "FE",
    "RJF",
    "INVH",
    "FLT",
    "CLX",
    "TDY",
    "TRGP",
    "DRI",
    "LH",
    "HOLX",
    "VRSN",
    "MOH",
    "LUV",
    "PPL",
    "ARE",
    "NVR",
    "COO",
    "WBA",
    "PHM",
    "NDAQ",
    "HWM",
    "RF",
    "CNP",
    "IRM",
    "LVS",
    "FITB",
    "EXPD",
    "VTR",
    "FSLR",
    "PFG",
    "BRO",
    "J",
    "IEX",
    "BG",
    "ATO",
    "FDS",
    "ENPH",
    "MAA",
    "CMS",
    "IFF",
    "BALL",
    "SWKS",
    "CINF",
    "NTAP",
    "STLD",
    "UAL",
    "WAT",
    "OMC",
    "TER",
    "CCL",
    "JBHT",
    "MRO",
    "TYL",
    "HBAN",
    "K",
    "GRMN",
    "CBOE",
    "NTRS",
    "TSN",
    "AKAM",
    "EG",
    "ESS",
    "EQT",
    "TXT",
    "EXPE",
    "SJM",
    "PTC",
    "DGX",
    "AVY",
    "RVTY",
    "BBY",
    "CF",
    "CAG",
    "EPAM",
    "AMCR",
    "LW",
    "PAYC",
    "SNA",
    "AXON",
    "POOL",
    "SYF",
    "SWK",
    "ZBRA",
    "DPZ",
    "PKG",
    "CFG",
    "LDOS",
    "VTRS",
    "PODD",
    "LKQ",
    "MOS",
    "APA",
    "EVRG",
    "TRMB",
    "MGM",
    "NDSN",
    "WDC",
    "MAS",
    "LNT",
    "IPG",
    "MTCH",
    "STX",
    "KMX",
    "TECH",
    "WRB",
    "LYV",
    "IP",
    "UDR",
    "AES",
    "CE",
    "INCY",
    "L",
    "TAP",
    "GEN",
    "CPT",
    "KIM",
    "JKHY",
    "HRL",
    "HST",
    "FMC",
    "CZR",
    "PEAK",
    "CDAY",
    "PNR",
    "NI",
    "CHRW",
    "HSIC",
    "CRL",
    "REG",
    "QRVO",
    "TFX",
    "KEY",
    "GL",
    "EMN",
    "WYNN",
    "ALLE",
    "AAL",
    "FFIV",
    "BWA",
    "BXP",
    "MKTX",
    "ROL",
    "JNPR",
    "PNW",
    "ETSY",
    "BLDR",
    "FOXA",
    "AOS",
    "HAS",
    "HII",
    "NRG",
    "CPB",
    "UHS",
    "BIO",
    "WRK",
    "RHI",
    "CTLT",
    "XRAY",
    "BBWI",
    "NWSA",
    "TPR",
    "PARA",
    "WHR",
    "BEN",
    "AIZ",
    "NCLH",
    "GNRC",
    "FRT",
    "IVZ",
    "VFC",
    "CMA",
    "DVA",
    "JBL",
    "HUBB",
    "ZION",
    "UBER",
    "MHK",
    "RL",
    "FOX",
    "BX",
    "ABNB",
    "NWS",
]
# stk_symbols = [
#     "AAPL",
#     "MSFT",
#     "AMZN",
#     "NVDA",
#     "GOOGL",
#     "TSLA",
#     "META",
#     "GOOG",
#     "ADBE",
#     "NFLX",
#     "CSCO",
#     "INTC",
#     "INTU",
#     "CMCSA",
#     "TXN",
#     "AMAT",
#     "ADSK",
#     "AMD",
#     "QCOM",
#     "MU",
# ]

# stk_symbols = [
#     "AAPL",
#     "MSFT",
#     "AMZN",
#     "NVDA",
#     "GOOGL",
#     "TSLA",
#     "META",
#     "GOOG",
# ]

# %%
from datetime import datetime
import yfinance as yfin
from MyPyUtil.util import is_contained


def load_stk_data(stk_symbols, start, end, empty_vol_threshold):
    ticks_data = []
    for symbol in stk_symbols:
        stk_file = f"{data_dir}{symbol}_{start.strftime('%Y%m%d')}-{end.strftime('%Y%m%d')}.csv"
        bLoad = False
        if os.path.isfile(stk_file):
            try:
                _stk_data = pd.read_csv(stk_file).set_index("Date")
                bLoad = True
                print(f"read {stk_file} completely!")
            except:
                None
        if bLoad == False:
            # _stk_data = web.get_data_yahoo(stk_tickers, start, end)
            _stk_data = yfin.download([symbol], start, end).dropna()
            _stk_data.to_csv(stk_file)
            print(f"download {symbol} from yfin and write to {stk_file} completely!")

        statistics = _stk_data.describe()
        if is_contained(statistics, 0):
            if is_contained(
                statistics.loc[:, ["Open", "High", "Low", "Close", "Adj Close"]], 0
            ) or is_contained(statistics.loc["std"], 0):
                print(f"{symbol}: contains numerical errors. Ignore it.")
                continue
            else:
                empty_vol_index = _stk_data[_stk_data["Volume"] == 0].index
                if len(empty_vol_index) > empty_vol_threshold:
                    print(
                        f"The total volume with a value of zero ({len(empty_vol_index)}) is greater than the threshold({empty_vol_threshold}). Ignore it."
                    )
                    continue
                print(
                    f"A total of {len(empty_vol_index)} volume values ​​are zero. Delete these data."
                )

                cleaned_data = _stk_data.drop(empty_vol_index)
                print(
                    f"The cleaned data size is {len(cleaned_data)}. The original data size is {len(_stk_data)}."
                )
                if len(cleaned_data) == 0:
                    continue
                _stk_data = cleaned_data

        ticks_data.append(_stk_data)
        print(f"{symbol}, size:{len(_stk_data)}")
    return ticks_data

# %%
empty_vol_threshold = 5
data1 = load_stk_data(
    stk_symbols, datetime(2014, 1, 1), datetime(2019, 12, 31), empty_vol_threshold
)
data2 = load_stk_data(
    stk_symbols, datetime(2021, 1, 1), datetime(2022, 11, 9), empty_vol_threshold
)
data3 = load_stk_data(
    stk_symbols, datetime(2023, 1, 1), datetime(2023, 12, 31), empty_vol_threshold
)
ticks_data = []
ticks_data.extend(data1)
ticks_data.extend(data2)
ticks_data.extend(data3)
print(len(ticks_data))
# Out:
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AAPL_20140101-20191231.csv completely!
# AAPL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MSFT_20140101-20191231.csv completely!
# MSFT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AMZN_20140101-20191231.csv completely!
# AMZN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NVDA_20140101-20191231.csv completely!
# NVDA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GOOGL_20140101-20191231.csv completely!
# GOOGL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GOOG_20140101-20191231.csv completely!
# GOOG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/META_20140101-20191231.csv completely!
# META, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TSLA_20140101-20191231.csv completely!
# TSLA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/UNH_20140101-20191231.csv completely!
# UNH, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LLY_20140101-20191231.csv completely!
# LLY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/JPM_20140101-20191231.csv completely!
# JPM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/XOM_20140101-20191231.csv completely!
# XOM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/JNJ_20140101-20191231.csv completely!
# JNJ, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/V_20140101-20191231.csv completely!
# V, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PG_20140101-20191231.csv completely!
# PG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AVGO_20140101-20191231.csv completely!
# AVGO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MA_20140101-20191231.csv completely!
# MA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HD_20140101-20191231.csv completely!
# HD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CVX_20140101-20191231.csv completely!
# CVX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MRK_20140101-20191231.csv completely!
# MRK, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ABBV_20140101-20191231.csv completely!
# ABBV, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PEP_20140101-20191231.csv completely!
# PEP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/COST_20140101-20191231.csv completely!
# COST, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ADBE_20140101-20191231.csv completely!
# ADBE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/KO_20140101-20191231.csv completely!
# KO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CSCO_20140101-20191231.csv completely!
# CSCO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WMT_20140101-20191231.csv completely!
# WMT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TMO_20140101-20191231.csv completely!
# TMO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MCD_20140101-20191231.csv completely!
# MCD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PFE_20140101-20191231.csv completely!
# PFE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CRM_20140101-20191231.csv completely!
# CRM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BAC_20140101-20191231.csv completely!
# BAC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ACN_20140101-20191231.csv completely!
# ACN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CMCSA_20140101-20191231.csv completely!
# CMCSA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LIN_20140101-20191231.csv completely!
# LIN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NFLX_20140101-20191231.csv completely!
# NFLX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ABT_20140101-20191231.csv completely!
# ABT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ORCL_20140101-20191231.csv completely!
# ORCL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DHR_20140101-20191231.csv completely!
# DHR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AMD_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# AMD, size:1508
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WFC_20140101-20191231.csv completely!
# WFC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DIS_20140101-20191231.csv completely!
# DIS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TXN_20140101-20191231.csv completely!
# TXN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PM_20140101-20191231.csv completely!
# PM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/VZ_20140101-20191231.csv completely!
# VZ, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/INTU_20140101-20191231.csv completely!
# INTU, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/COP_20140101-20191231.csv completely!
# COP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CAT_20140101-20191231.csv completely!
# CAT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AMGN_20140101-20191231.csv completely!
# AMGN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NEE_20140101-20191231.csv completely!
# NEE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/INTC_20140101-20191231.csv completely!
# INTC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/UNP_20140101-20191231.csv completely!
# UNP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LOW_20140101-20191231.csv completely!
# LOW, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IBM_20140101-20191231.csv completely!
# IBM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BMY_20140101-20191231.csv completely!
# BMY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SPGI_20140101-20191231.csv completely!
# SPGI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/RTX_20140101-20191231.csv completely!
# RTX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HON_20140101-20191231.csv completely!
# HON, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BA_20140101-20191231.csv completely!
# BA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/UPS_20140101-20191231.csv completely!
# UPS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GE_20140101-20191231.csv completely!
# GE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/QCOM_20140101-20191231.csv completely!
# QCOM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AMAT_20140101-20191231.csv completely!
# AMAT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NKE_20140101-20191231.csv completely!
# NKE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PLD_20140101-20191231.csv completely!
# PLD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NOW_20140101-20191231.csv completely!
# NOW, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BKNG_20140101-20191231.csv completely!
# BKNG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SBUX_20140101-20191231.csv completely!
# SBUX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MS_20140101-20191231.csv completely!
# MS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ELV_20140101-20191231.csv completely!
# ELV, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MDT_20140101-20191231.csv completely!
# MDT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GS_20140101-20191231.csv completely!
# GS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DE_20140101-20191231.csv completely!
# DE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ADP_20140101-20191231.csv completely!
# ADP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LMT_20140101-20191231.csv completely!
# LMT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TJX_20140101-20191231.csv completely!
# TJX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/T_20140101-20191231.csv completely!
# T, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BLK_20140101-20191231.csv completely!
# BLK, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ISRG_20140101-20191231.csv completely!
# ISRG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MDLZ_20140101-20191231.csv completely!
# MDLZ, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GILD_20140101-20191231.csv completely!
# GILD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MMC_20140101-20191231.csv completely!
# MMC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AXP_20140101-20191231.csv completely!
# AXP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SYK_20140101-20191231.csv completely!
# SYK, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/REGN_20140101-20191231.csv completely!
# REGN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/VRTX_20140101-20191231.csv completely!
# VRTX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ETN_20140101-20191231.csv completely!
# ETN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LRCX_20140101-20191231.csv completely!
# LRCX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ADI_20140101-20191231.csv completely!
# ADI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SCHW_20140101-20191231.csv completely!
# SCHW, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CVS_20140101-20191231.csv completely!
# CVS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ZTS_20140101-20191231.csv completely!
# ZTS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CI_20140101-20191231.csv completely!
# CI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CB_20140101-20191231.csv completely!
# CB, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AMT_20140101-20191231.csv completely!
# AMT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SLB_20140101-20191231.csv completely!
# SLB, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/C_20140101-20191231.csv completely!
# C, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BDX_20140101-20191231.csv completely!
# BDX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MO_20140101-20191231.csv completely!
# MO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PGR_20140101-20191231.csv completely!
# PGR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TMUS_20140101-20191231.csv completely!
# TMUS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FI_20140101-20191231.csv completely!
# FI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SO_20140101-20191231.csv completely!
# SO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EOG_20140101-20191231.csv completely!
# EOG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BSX_20140101-20191231.csv completely!
# BSX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CME_20140101-20191231.csv completely!
# CME, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EQIX_20140101-20191231.csv completely!
# EQIX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MU_20140101-20191231.csv completely!
# MU, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DUK_20140101-20191231.csv completely!
# DUK, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PANW_20140101-20191231.csv completely!
# PANW, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PYPL_20140101-20191231.csv completely!
# PYPL, size:1131
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AON_20140101-20191231.csv completely!
# AON, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SNPS_20140101-20191231.csv completely!
# SNPS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ITW_20140101-20191231.csv completely!
# ITW, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/KLAC_20140101-20191231.csv completely!
# KLAC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LULU_20140101-20191231.csv completely!
# LULU, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ICE_20140101-20191231.csv completely!
# ICE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/APD_20140101-20191231.csv completely!
# APD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SHW_20140101-20191231.csv completely!
# SHW, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CDNS_20140101-20191231.csv completely!
# CDNS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CSX_20140101-20191231.csv completely!
# CSX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NOC_20140101-20191231.csv completely!
# NOC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CL_20140101-20191231.csv completely!
# CL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MPC_20140101-20191231.csv completely!
# MPC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HUM_20140101-20191231.csv completely!
# HUM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FDX_20140101-20191231.csv completely!
# FDX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WM_20140101-20191231.csv completely!
# WM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MCK_20140101-20191231.csv completely!
# MCK, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TGT_20140101-20191231.csv completely!
# TGT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ORLY_20140101-20191231.csv completely!
# ORLY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HCA_20140101-20191231.csv completely!
# HCA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FCX_20140101-20191231.csv completely!
# FCX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EMR_20140101-20191231.csv completely!
# EMR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PXD_20140101-20191231.csv completely!
# PXD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MMM_20140101-20191231.csv completely!
# MMM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MCO_20140101-20191231.csv completely!
# MCO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ROP_20140101-20191231.csv completely!
# ROP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CMG_20140101-20191231.csv completely!
# CMG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PSX_20140101-20191231.csv completely!
# PSX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MAR_20140101-20191231.csv completely!
# MAR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PH_20140101-20191231.csv completely!
# PH, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/APH_20140101-20191231.csv completely!
# APH, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GD_20140101-20191231.csv completely!
# GD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/USB_20140101-20191231.csv completely!
# USB, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NXPI_20140101-20191231.csv completely!
# NXPI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AJG_20140101-20191231.csv completely!
# AJG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NSC_20140101-20191231.csv completely!
# NSC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PNC_20140101-20191231.csv completely!
# PNC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/VLO_20140101-20191231.csv completely!
# VLO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GBP_20140101-20191231.csv completely!
# GBP: contains numerical errors. Ignore it.
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/F_20140101-20191231.csv completely!
# F, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MSI_20140101-20191231.csv completely!
# MSI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GM_20140101-20191231.csv completely!
# GM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TT_20140101-20191231.csv completely!
# TT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EW_20140101-20191231.csv completely!
# EW, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CARR_20140101-20191231.csv completely!
# CARR: contains numerical errors. Ignore it.
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AZO_20140101-20191231.csv completely!
# AZO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ADSK_20140101-20191231.csv completely!
# ADSK, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TDG_20140101-20191231.csv completely!
# TDG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ANET_20140101-20191231.csv completely!
# ANET, size:1402
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SRE_20140101-20191231.csv completely!
# SRE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ECL_20140101-20191231.csv completely!
# ECL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/OXY_20140101-20191231.csv completely!
# OXY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PCAR_20140101-20191231.csv completely!
# PCAR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ADM_20140101-20191231.csv completely!
# ADM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MNST_20140101-20191231.csv completely!
# MNST, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/KMB_20140101-20191231.csv completely!
# KMB, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PSA_20140101-20191231.csv completely!
# PSA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CCI_20140101-20191231.csv completely!
# CCI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CHTR_20140101-20191231.csv completely!
# CHTR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MCHP_20140101-20191231.csv completely!
# MCHP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MSCI_20140101-20191231.csv completely!
# MSCI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CTAS_20140101-20191231.csv completely!
# CTAS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WMB_20140101-20191231.csv completely!
# WMB, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AIG_20140101-20191231.csv completely!
# AIG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/STZ_20140101-20191231.csv completely!
# STZ, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HES_20140101-20191231.csv completely!
# HES, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NUE_20140101-20191231.csv completely!
# NUE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ROST_20140101-20191231.csv completely!
# ROST, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AFL_20140101-20191231.csv completely!
# AFL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AEP_20140101-20191231.csv completely!
# AEP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IDXX_20140101-20191231.csv completely!
# IDXX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/D_20140101-20191231.csv completely!
# D, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TEL_20140101-20191231.csv completely!
# TEL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/JCI_20140101-20191231.csv completely!
# JCI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MET_20140101-20191231.csv completely!
# MET, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GIS_20140101-20191231.csv completely!
# GIS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IQV_20140101-20191231.csv completely!
# IQV, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EXC_20140101-20191231.csv completely!
# EXC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WELL_20140101-20191231.csv completely!
# WELL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DXCM_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# DXCM, size:1508
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HLT_20140101-20191231.csv completely!
# HLT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ON_20140101-20191231.csv completely!
# ON, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/COF_20140101-20191231.csv completely!
# COF, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PAYX_20140101-20191231.csv completely!
# PAYX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TFC_20140101-20191231.csv completely!
# TFC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/USD_20140101-20191231.csv completely!
# The total volume with a value of zero (6) is greater than the threshold(5). Ignore it.
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BIIB_20140101-20191231.csv completely!
# BIIB, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/O_20140101-20191231.csv completely!
# O, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FTNT_20140101-20191231.csv completely!
# FTNT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DOW_20140101-20191231.csv completely!
# DOW, size:198
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TRV_20140101-20191231.csv completely!
# TRV, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DLR_20140101-20191231.csv completely!
# DLR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MRNA_20140101-20191231.csv completely!
# MRNA, size:267
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CPRT_20140101-20191231.csv completely!
# CPRT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ODFL_20140101-20191231.csv completely!
# ODFL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DHI_20140101-20191231.csv completely!
# DHI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/YUM_20140101-20191231.csv completely!
# YUM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SPG_20140101-20191231.csv completely!
# SPG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CTSH_20140101-20191231.csv completely!
# CTSH, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AME_20140101-20191231.csv completely!
# AME, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BKR_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# BKR, size:1508
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SYY_20140101-20191231.csv completely!
# SYY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/A_20140101-20191231.csv completely!
# A, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CTVA_20140101-20191231.csv completely!
# CTVA, size:152
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CNC_20140101-20191231.csv completely!
# CNC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EL_20140101-20191231.csv completely!
# EL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AMP_20140101-20191231.csv completely!
# AMP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HAL_20140101-20191231.csv completely!
# HAL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ROK_20140101-20191231.csv completely!
# ROK, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PRU_20140101-20191231.csv completely!
# PRU, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DD_20140101-20191231.csv completely!
# DD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/KMI_20140101-20191231.csv completely!
# KMI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/VRSK_20140101-20191231.csv completely!
# VRSK, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LHX_20140101-20191231.csv completely!
# LHX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DG_20140101-20191231.csv completely!
# DG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FIS_20140101-20191231.csv completely!
# FIS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CMI_20140101-20191231.csv completely!
# CMI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CSGP_20140101-20191231.csv completely!
# CSGP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FAST_20140101-20191231.csv completely!
# FAST, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PPG_20140101-20191231.csv completely!
# PPG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GPN_20140101-20191231.csv completely!
# GPN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GWW_20140101-20191231.csv completely!
# GWW, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HSY_20140101-20191231.csv completely!
# HSY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BK_20140101-20191231.csv completely!
# BK, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/XEL_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# XEL, size:1508
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DVN_20140101-20191231.csv completely!
# DVN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EA_20140101-20191231.csv completely!
# EA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NEM_20140101-20191231.csv completely!
# NEM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ED_20140101-20191231.csv completely!
# ED, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/URI_20140101-20191231.csv completely!
# URI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/VICI_20140101-20191231.csv completely!
# VICI, size:502
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PEG_20140101-20191231.csv completely!
# PEG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/KR_20140101-20191231.csv completely!
# KR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/RSG_20140101-20191231.csv completely!
# RSG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LEN_20140101-20191231.csv completely!
# LEN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PWR_20140101-20191231.csv completely!
# PWR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WST_20140101-20191231.csv completely!
# WST, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/COR_20140101-20191231.csv completely!
# COR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/OKE_20140101-20191231.csv completely!
# OKE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/VMC_20140101-20191231.csv completely!
# VMC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/KDP_20140101-20191231.csv completely!
# KDP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WBD_20140101-20191231.csv completely!
# WBD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ACGL_20140101-20191231.csv completely!
# ACGL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ALL_20140101-20191231.csv completely!
# ALL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IR_20140101-20191231.csv completely!
# IR, size:663
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CDW_20140101-20191231.csv completely!
# CDW, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FANG_20140101-20191231.csv completely!
# FANG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MLM_20140101-20191231.csv completely!
# MLM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PCG_20140101-20191231.csv completely!
# PCG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DAL_20140101-20191231.csv completely!
# DAL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EXR_20140101-20191231.csv completely!
# EXR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FTV_20140101-20191231.csv completely!
# FTV, size:879
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AWK_20140101-20191231.csv completely!
# AWK, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IT_20140101-20191231.csv completely!
# IT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/KHC_20140101-20191231.csv completely!
# KHC, size:1131
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WEC_20140101-20191231.csv completely!
# WEC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HPQ_20140101-20191231.csv completely!
# HPQ, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EIX_20140101-20191231.csv completely!
# EIX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CBRE_20140101-20191231.csv completely!
# CBRE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/APTV_20140101-20191231.csv completely!
# APTV, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ANSS_20140101-20191231.csv completely!
# ANSS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MTD_20140101-20191231.csv completely!
# MTD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DLTR_20140101-20191231.csv completely!
# DLTR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AVB_20140101-20191231.csv completely!
# AVB, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ILMN_20140101-20191231.csv completely!
# ILMN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ALGN_20140101-20191231.csv completely!
# ALGN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LYB_20140101-20191231.csv completely!
# LYB, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TROW_20140101-20191231.csv completely!
# TROW, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GLW_20140101-20191231.csv completely!
# GLW, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EFX_20140101-20191231.csv completely!
# EFX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WY_20140101-20191231.csv completely!
# WY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ZBH_20140101-20191231.csv completely!
# ZBH, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/XYL_20140101-20191231.csv completely!
# XYL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SBAC_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# SBAC, size:1508
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/RMD_20140101-20191231.csv completely!
# RMD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TSCO_20140101-20191231.csv completely!
# TSCO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EBAY_20140101-20191231.csv completely!
# EBAY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/KEYS_20140101-20191231.csv completely!
# KEYS, size:1308
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CHD_20140101-20191231.csv completely!
# CHD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/STT_20140101-20191231.csv completely!
# STT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DFS_20140101-20191231.csv completely!
# DFS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HIG_20140101-20191231.csv completely!
# HIG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ALB_20140101-20191231.csv completely!
# ALB, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/STE_20140101-20191231.csv completely!
# STE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ES_20140101-20191231.csv completely!
# ES, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TTWO_20140101-20191231.csv completely!
# TTWO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MPWR_20140101-20191231.csv completely!
# MPWR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CAH_20140101-20191231.csv completely!
# CAH, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EQR_20140101-20191231.csv completely!
# EQR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/RCL_20140101-20191231.csv completely!
# RCL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WTW_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# WTW, size:1508
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HPE_20140101-20191231.csv completely!
# HPE, size:1057
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DTE_20140101-20191231.csv completely!
# DTE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GPC_20140101-20191231.csv completely!
# GPC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BR_20140101-20191231.csv completely!
# BR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ULTA_20140101-20191231.csv completely!
# ULTA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FICO_20140101-20191231.csv completely!
# FICO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CTRA_20140101-20191231.csv completely!
# CTRA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BAX_20140101-20191231.csv completely!
# BAX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AEE_20140101-20191231.csv completely!
# AEE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MTB_20140101-20191231.csv completely!
# MTB, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MKC_20140101-20191231.csv completely!
# MKC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ETR_20140101-20191231.csv completely!
# ETR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WAB_20140101-20191231.csv completely!
# WAB, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DOV_20140101-20191231.csv completely!
# DOV, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FE_20140101-20191231.csv completely!
# FE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/RJF_20140101-20191231.csv completely!
# RJF, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/INVH_20140101-20191231.csv completely!
# INVH, size:733
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FLT_20140101-20191231.csv completely!
# FLT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CLX_20140101-20191231.csv completely!
# CLX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TDY_20140101-20191231.csv completely!
# TDY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TRGP_20140101-20191231.csv completely!
# TRGP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DRI_20140101-20191231.csv completely!
# DRI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LH_20140101-20191231.csv completely!
# LH, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HOLX_20140101-20191231.csv completely!
# HOLX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/VRSN_20140101-20191231.csv completely!
# VRSN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MOH_20140101-20191231.csv completely!
# MOH, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LUV_20140101-20191231.csv completely!
# LUV, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PPL_20140101-20191231.csv completely!
# PPL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ARE_20140101-20191231.csv completely!
# ARE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NVR_20140101-20191231.csv completely!
# NVR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/COO_20140101-20191231.csv completely!
# A total of 2 volume values ​​are zero. Delete these data.
# The cleaned data size is 1507. The original data size is 1509.
# COO, size:1507
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WBA_20140101-20191231.csv completely!
# WBA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PHM_20140101-20191231.csv completely!
# PHM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NDAQ_20140101-20191231.csv completely!
# NDAQ, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HWM_20140101-20191231.csv completely!
# The total volume with a value of zero (35) is greater than the threshold(5). Ignore it.
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/RF_20140101-20191231.csv completely!
# RF, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CNP_20140101-20191231.csv completely!
# CNP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IRM_20140101-20191231.csv completely!
# IRM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LVS_20140101-20191231.csv completely!
# LVS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FITB_20140101-20191231.csv completely!
# FITB, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EXPD_20140101-20191231.csv completely!
# EXPD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/VTR_20140101-20191231.csv completely!
# VTR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FSLR_20140101-20191231.csv completely!
# FSLR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PFG_20140101-20191231.csv completely!
# A total of 2 volume values ​​are zero. Delete these data.
# The cleaned data size is 1507. The original data size is 1509.
# PFG, size:1507
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BRO_20140101-20191231.csv completely!
# BRO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/J_20140101-20191231.csv completely!
# J, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IEX_20140101-20191231.csv completely!
# IEX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BG_20140101-20191231.csv completely!
# BG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ATO_20140101-20191231.csv completely!
# ATO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FDS_20140101-20191231.csv completely!
# FDS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ENPH_20140101-20191231.csv completely!
# ENPH, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MAA_20140101-20191231.csv completely!
# MAA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CMS_20140101-20191231.csv completely!
# CMS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IFF_20140101-20191231.csv completely!
# IFF, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BALL_20140101-20191231.csv completely!
# BALL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SWKS_20140101-20191231.csv completely!
# SWKS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CINF_20140101-20191231.csv completely!
# CINF, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NTAP_20140101-20191231.csv completely!
# NTAP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/STLD_20140101-20191231.csv completely!
# STLD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/UAL_20140101-20191231.csv completely!
# UAL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WAT_20140101-20191231.csv completely!
# WAT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/OMC_20140101-20191231.csv completely!
# OMC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TER_20140101-20191231.csv completely!
# TER, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CCL_20140101-20191231.csv completely!
# CCL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/JBHT_20140101-20191231.csv completely!
# JBHT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MRO_20140101-20191231.csv completely!
# MRO, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TYL_20140101-20191231.csv completely!
# TYL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HBAN_20140101-20191231.csv completely!
# HBAN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/K_20140101-20191231.csv completely!
# K, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GRMN_20140101-20191231.csv completely!
# GRMN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CBOE_20140101-20191231.csv completely!
# CBOE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NTRS_20140101-20191231.csv completely!
# NTRS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TSN_20140101-20191231.csv completely!
# TSN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AKAM_20140101-20191231.csv completely!
# AKAM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EG_20140101-20191231.csv completely!
# EG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ESS_20140101-20191231.csv completely!
# ESS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EQT_20140101-20191231.csv completely!
# EQT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TXT_20140101-20191231.csv completely!
# TXT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EXPE_20140101-20191231.csv completely!
# EXPE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SJM_20140101-20191231.csv completely!
# SJM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PTC_20140101-20191231.csv completely!
# PTC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DGX_20140101-20191231.csv completely!
# DGX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AVY_20140101-20191231.csv completely!
# AVY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/RVTY_20140101-20191231.csv completely!
# RVTY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BBY_20140101-20191231.csv completely!
# BBY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CF_20140101-20191231.csv completely!
# CF, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CAG_20140101-20191231.csv completely!
# CAG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EPAM_20140101-20191231.csv completely!
# EPAM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AMCR_20140101-20191231.csv completely!
# The total volume with a value of zero (1110) is greater than the threshold(5). Ignore it.
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LW_20140101-20191231.csv completely!
# LW, size:788
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PAYC_20140101-20191231.csv completely!
# PAYC, size:1438
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SNA_20140101-20191231.csv completely!
# SNA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AXON_20140101-20191231.csv completely!
# AXON, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/POOL_20140101-20191231.csv completely!
# POOL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SYF_20140101-20191231.csv completely!
# SYF, size:1364
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SWK_20140101-20191231.csv completely!
# SWK, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ZBRA_20140101-20191231.csv completely!
# ZBRA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DPZ_20140101-20191231.csv completely!
# DPZ, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PKG_20140101-20191231.csv completely!
# PKG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CFG_20140101-20191231.csv completely!
# CFG, size:1326
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LDOS_20140101-20191231.csv completely!
# LDOS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/VTRS_20140101-20191231.csv completely!
# VTRS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PODD_20140101-20191231.csv completely!
# PODD, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LKQ_20140101-20191231.csv completely!
# LKQ, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MOS_20140101-20191231.csv completely!
# MOS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/APA_20140101-20191231.csv completely!
# APA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EVRG_20140101-20191231.csv completely!
# EVRG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TRMB_20140101-20191231.csv completely!
# TRMB, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MGM_20140101-20191231.csv completely!
# MGM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NDSN_20140101-20191231.csv completely!
# NDSN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WDC_20140101-20191231.csv completely!
# WDC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MAS_20140101-20191231.csv completely!
# MAS, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LNT_20140101-20191231.csv completely!
# LNT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IPG_20140101-20191231.csv completely!
# IPG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MTCH_20140101-20191231.csv completely!
# MTCH, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/STX_20140101-20191231.csv completely!
# STX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/KMX_20140101-20191231.csv completely!
# KMX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TECH_20140101-20191231.csv completely!
# TECH, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WRB_20140101-20191231.csv completely!
# WRB, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LYV_20140101-20191231.csv completely!
# LYV, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IP_20140101-20191231.csv completely!
# IP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/UDR_20140101-20191231.csv completely!
# UDR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AES_20140101-20191231.csv completely!
# AES, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CE_20140101-20191231.csv completely!
# CE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/INCY_20140101-20191231.csv completely!
# INCY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/L_20140101-20191231.csv completely!
# L, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TAP_20140101-20191231.csv completely!
# TAP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GEN_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# GEN, size:1508
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CPT_20140101-20191231.csv completely!
# CPT, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/KIM_20140101-20191231.csv completely!
# KIM, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/JKHY_20140101-20191231.csv completely!
# JKHY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HRL_20140101-20191231.csv completely!
# HRL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HST_20140101-20191231.csv completely!
# HST, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FMC_20140101-20191231.csv completely!
# FMC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CZR_20140101-20191231.csv completely!
# CZR, size:1328
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PEAK_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# PEAK, size:1508
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CDAY_20140101-20191231.csv completely!
# CDAY, size:423
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PNR_20140101-20191231.csv completely!
# PNR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NI_20140101-20191231.csv completely!
# NI, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CHRW_20140101-20191231.csv completely!
# CHRW, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HSIC_20140101-20191231.csv completely!
# HSIC, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CRL_20140101-20191231.csv completely!
# CRL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/REG_20140101-20191231.csv completely!
# REG, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/QRVO_20140101-20191231.csv completely!
# QRVO, size:1257
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TFX_20140101-20191231.csv completely!
# TFX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/KEY_20140101-20191231.csv completely!
# KEY, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GL_20140101-20191231.csv completely!
# GL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EMN_20140101-20191231.csv completely!
# EMN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WYNN_20140101-20191231.csv completely!
# WYNN, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ALLE_20140101-20191231.csv completely!
# ALLE, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AAL_20140101-20191231.csv completely!
# AAL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FFIV_20140101-20191231.csv completely!
# FFIV, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BWA_20140101-20191231.csv completely!
# BWA, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BXP_20140101-20191231.csv completely!
# BXP, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MKTX_20140101-20191231.csv completely!
# MKTX, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ROL_20140101-20191231.csv completely!
# ROL, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/JNPR_20140101-20191231.csv completely!
# JNPR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PNW_20140101-20191231.csv completely!
# PNW, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ETSY_20140101-20191231.csv completely!
# ETSY, size:1186
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BLDR_20140101-20191231.csv completely!
# BLDR, size:1509
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FOXA_20140101-20191231.csv completely!
# FOXA, size:204
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AOS_20140101-20191231.csv completely!
# ...
# RF, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CNP_20230101-20231231.csv completely!
# CNP, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IRM_20230101-20231231.csv completely!
# IRM, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LVS_20230101-20231231.csv completely!
# LVS, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FITB_20230101-20231231.csv completely!
# FITB, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EXPD_20230101-20231231.csv completely!
# EXPD, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/VTR_20230101-20231231.csv completely!
# VTR, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FSLR_20230101-20231231.csv completely!
# FSLR, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PFG_20230101-20231231.csv completely!
# PFG, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BRO_20230101-20231231.csv completely!
# BRO, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/J_20230101-20231231.csv completely!
# J, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IEX_20230101-20231231.csv completely!
# IEX, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BG_20230101-20231231.csv completely!
# BG, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ATO_20230101-20231231.csv completely!
# ATO, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FDS_20230101-20231231.csv completely!
# FDS, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ENPH_20230101-20231231.csv completely!
# ENPH, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MAA_20230101-20231231.csv completely!
# MAA, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CMS_20230101-20231231.csv completely!
# CMS, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IFF_20230101-20231231.csv completely!
# IFF, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BALL_20230101-20231231.csv completely!
# BALL, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SWKS_20230101-20231231.csv completely!
# SWKS, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CINF_20230101-20231231.csv completely!
# CINF, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NTAP_20230101-20231231.csv completely!
# NTAP, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/STLD_20230101-20231231.csv completely!
# STLD, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/UAL_20230101-20231231.csv completely!
# UAL, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WAT_20230101-20231231.csv completely!
# WAT, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/OMC_20230101-20231231.csv completely!
# OMC, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TER_20230101-20231231.csv completely!
# TER, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CCL_20230101-20231231.csv completely!
# CCL, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/JBHT_20230101-20231231.csv completely!
# JBHT, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MRO_20230101-20231231.csv completely!
# MRO, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TYL_20230101-20231231.csv completely!
# TYL, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HBAN_20230101-20231231.csv completely!
# HBAN, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/K_20230101-20231231.csv completely!
# K, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GRMN_20230101-20231231.csv completely!
# GRMN, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CBOE_20230101-20231231.csv completely!
# CBOE, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NTRS_20230101-20231231.csv completely!
# NTRS, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TSN_20230101-20231231.csv completely!
# TSN, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AKAM_20230101-20231231.csv completely!
# AKAM, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EG_20230101-20231231.csv completely!
# EG, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ESS_20230101-20231231.csv completely!
# ESS, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EQT_20230101-20231231.csv completely!
# EQT, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TXT_20230101-20231231.csv completely!
# TXT, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EXPE_20230101-20231231.csv completely!
# EXPE, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SJM_20230101-20231231.csv completely!
# SJM, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PTC_20230101-20231231.csv completely!
# PTC, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DGX_20230101-20231231.csv completely!
# DGX, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AVY_20230101-20231231.csv completely!
# AVY, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/RVTY_20230101-20231231.csv completely!
# RVTY, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BBY_20230101-20231231.csv completely!
# BBY, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CF_20230101-20231231.csv completely!
# CF, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CAG_20230101-20231231.csv completely!
# CAG, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EPAM_20230101-20231231.csv completely!
# EPAM, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AMCR_20230101-20231231.csv completely!
# AMCR, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LW_20230101-20231231.csv completely!
# LW, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PAYC_20230101-20231231.csv completely!
# PAYC, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SNA_20230101-20231231.csv completely!
# SNA, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AXON_20230101-20231231.csv completely!
# AXON, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/POOL_20230101-20231231.csv completely!
# POOL, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SYF_20230101-20231231.csv completely!
# SYF, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/SWK_20230101-20231231.csv completely!
# SWK, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ZBRA_20230101-20231231.csv completely!
# ZBRA, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DPZ_20230101-20231231.csv completely!
# DPZ, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PKG_20230101-20231231.csv completely!
# PKG, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CFG_20230101-20231231.csv completely!
# CFG, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LDOS_20230101-20231231.csv completely!
# LDOS, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/VTRS_20230101-20231231.csv completely!
# VTRS, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PODD_20230101-20231231.csv completely!
# PODD, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LKQ_20230101-20231231.csv completely!
# LKQ, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MOS_20230101-20231231.csv completely!
# MOS, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/APA_20230101-20231231.csv completely!
# APA, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EVRG_20230101-20231231.csv completely!
# EVRG, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TRMB_20230101-20231231.csv completely!
# TRMB, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MGM_20230101-20231231.csv completely!
# MGM, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NDSN_20230101-20231231.csv completely!
# NDSN, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WDC_20230101-20231231.csv completely!
# WDC, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MAS_20230101-20231231.csv completely!
# MAS, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LNT_20230101-20231231.csv completely!
# LNT, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IPG_20230101-20231231.csv completely!
# IPG, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MTCH_20230101-20231231.csv completely!
# MTCH, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/STX_20230101-20231231.csv completely!
# STX, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/KMX_20230101-20231231.csv completely!
# KMX, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TECH_20230101-20231231.csv completely!
# TECH, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WRB_20230101-20231231.csv completely!
# WRB, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/LYV_20230101-20231231.csv completely!
# LYV, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IP_20230101-20231231.csv completely!
# IP, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/UDR_20230101-20231231.csv completely!
# UDR, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AES_20230101-20231231.csv completely!
# AES, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CE_20230101-20231231.csv completely!
# CE, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/INCY_20230101-20231231.csv completely!
# INCY, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/L_20230101-20231231.csv completely!
# L, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TAP_20230101-20231231.csv completely!
# TAP, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GEN_20230101-20231231.csv completely!
# GEN, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CPT_20230101-20231231.csv completely!
# CPT, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/KIM_20230101-20231231.csv completely!
# KIM, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/JKHY_20230101-20231231.csv completely!
# JKHY, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HRL_20230101-20231231.csv completely!
# HRL, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HST_20230101-20231231.csv completely!
# HST, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FMC_20230101-20231231.csv completely!
# FMC, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CZR_20230101-20231231.csv completely!
# CZR, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PEAK_20230101-20231231.csv completely!
# PEAK, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CDAY_20230101-20231231.csv completely!
# CDAY, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PNR_20230101-20231231.csv completely!
# PNR, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NI_20230101-20231231.csv completely!
# NI, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CHRW_20230101-20231231.csv completely!
# CHRW, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HSIC_20230101-20231231.csv completely!
# HSIC, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CRL_20230101-20231231.csv completely!
# CRL, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/REG_20230101-20231231.csv completely!
# REG, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/QRVO_20230101-20231231.csv completely!
# QRVO, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TFX_20230101-20231231.csv completely!
# TFX, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/KEY_20230101-20231231.csv completely!
# KEY, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GL_20230101-20231231.csv completely!
# GL, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/EMN_20230101-20231231.csv completely!
# EMN, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WYNN_20230101-20231231.csv completely!
# WYNN, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ALLE_20230101-20231231.csv completely!
# ALLE, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AAL_20230101-20231231.csv completely!
# AAL, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FFIV_20230101-20231231.csv completely!
# FFIV, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BWA_20230101-20231231.csv completely!
# BWA, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BXP_20230101-20231231.csv completely!
# BXP, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MKTX_20230101-20231231.csv completely!
# MKTX, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ROL_20230101-20231231.csv completely!
# ROL, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/JNPR_20230101-20231231.csv completely!
# JNPR, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PNW_20230101-20231231.csv completely!
# PNW, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ETSY_20230101-20231231.csv completely!
# ETSY, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BLDR_20230101-20231231.csv completely!
# BLDR, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FOXA_20230101-20231231.csv completely!
# FOXA, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AOS_20230101-20231231.csv completely!
# AOS, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HAS_20230101-20231231.csv completely!
# HAS, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HII_20230101-20231231.csv completely!
# HII, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NRG_20230101-20231231.csv completely!
# NRG, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CPB_20230101-20231231.csv completely!
# CPB, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/UHS_20230101-20231231.csv completely!
# UHS, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BIO_20230101-20231231.csv completely!
# BIO, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WRK_20230101-20231231.csv completely!
# WRK, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/RHI_20230101-20231231.csv completely!
# RHI, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CTLT_20230101-20231231.csv completely!
# CTLT, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/XRAY_20230101-20231231.csv completely!
# XRAY, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BBWI_20230101-20231231.csv completely!
# BBWI, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NWSA_20230101-20231231.csv completely!
# NWSA, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/TPR_20230101-20231231.csv completely!
# TPR, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/PARA_20230101-20231231.csv completely!
# PARA, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/WHR_20230101-20231231.csv completely!
# WHR, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BEN_20230101-20231231.csv completely!
# BEN, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/AIZ_20230101-20231231.csv completely!
# AIZ, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NCLH_20230101-20231231.csv completely!
# NCLH, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/GNRC_20230101-20231231.csv completely!
# GNRC, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FRT_20230101-20231231.csv completely!
# FRT, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/IVZ_20230101-20231231.csv completely!
# IVZ, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/VFC_20230101-20231231.csv completely!
# VFC, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/CMA_20230101-20231231.csv completely!
# CMA, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/DVA_20230101-20231231.csv completely!
# DVA, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/JBL_20230101-20231231.csv completely!
# JBL, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/HUBB_20230101-20231231.csv completely!
# HUBB, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ZION_20230101-20231231.csv completely!
# ZION, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/UBER_20230101-20231231.csv completely!
# UBER, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/MHK_20230101-20231231.csv completely!
# MHK, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/RL_20230101-20231231.csv completely!
# RL, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/FOX_20230101-20231231.csv completely!
# FOX, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/BX_20230101-20231231.csv completely!
# BX, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/ABNB_20230101-20231231.csv completely!
# ABNB, size:250
# read /mnt/AIWorkSpace/work/AI4StockMarket/data/NWS_20230101-20231231.csv completely!
# NWS, size:250
# 1486

# %%
import torch

device_name = (
    "cuda"
    if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available() else "cpu"
)
device = torch.device(device_name)
return_period = 5
seq_len = 3
validation_size = 0.2
epoch_num = 100
batch_size = 32
num_workers = 3
pin_memory = True
shuffle = True
print(f"device_name:{device}")
# Out:
# device_name:cuda

# %%
pct_threshold = 0.04
class_percentage_threshold = 0  # percentage threshold for class size
classificationThreshold = 0.5


# # number of classes = 3
# # 0: PCT <= -0.05
# # 1: 0.05 < PCT < -0.05
# # 2: PCT >= 0.05
# num_classes = 3


# def gen_pct_label(stk_data, _return_period):
#     max_price_period = (
#         stk_data["Adj Close"].rolling(_return_period).max().shift(-_return_period)
#     )
#     max_pct_period = (max_price_period - stk_data["Adj Close"]) / stk_data["Adj Close"]
#     pct_label = max_pct_period.apply(
#         lambda x: 2 if x >= pct_threshold else 0 if x <= -pct_threshold else 1
#     ).astype("int8")
#     pct_label.name = "label"
#     return pct_label


# number of classes = 2
# 0: PCT < 0.05
# 1: PCT >= -0.05
num_classes = 2


def gen_pct_label(stk_data, _return_period):
    max_price_period = (
        stk_data["Adj Close"].rolling(_return_period).max().shift(-_return_period)
    )
    max_pct_period = (max_price_period - stk_data["Adj Close"]) / stk_data["Adj Close"]
    pct_label = max_pct_period.apply(lambda x: 1 if x >= pct_threshold else 0).astype(
        "int8"
    )
    pct_label.name = "label"
    return pct_label


def class_percentage(analysis_data):
    stat = analysis_data.groupby("label").size()
    total = len(analysis_data)
    p = []
    for i in range(num_classes):
        p.append(stat[i] / total if i in stat.index else 0.0)
    return p

# %%
def to_adjusted(stk_data):
    """
    Adjusted Open = Open * Adjusted Close / Close
    Adjusted High = High * Adjusted Close / Close
    Adjusted Low = Low * Adjusted Close / Close
    Adjusted volume = Volume / (Adjusted Close / Close)
    """
    ratio_data = stk_data["Adj Close"] / stk_data["Close"]
    adjusted_OHLV = pd.DataFrame(index=stk_data.index)
    adjusted_OHLV["Adj Open"] = ratio_data * stk_data["Open"]
    adjusted_OHLV["Adj High"] = ratio_data * stk_data["High"]
    adjusted_OHLV["Adj Low"] = ratio_data * stk_data["Low"]
    adjusted_OHLV["Adj Close"] = stk_data["Adj Close"]
    adjusted_OHLV["Adj Volume"] = (ratio_data * stk_data["Volume"]).astype("int")
    adjusted_OHLV["Pre Adj Close"] = stk_data["Adj Close"].shift(1)
    adjusted_OHLV["Pre Adj Volume"] = adjusted_OHLV["Adj Volume"].shift(1)
    adjusted_OHLV = adjusted_OHLV.dropna()
    adjusted_OHLV["Pre Adj Volume"] = adjusted_OHLV["Pre Adj Volume"].astype("int")
    adjusted_OHLV["B4_Adj Open pct"] = (
        adjusted_OHLV["Adj Open"] - adjusted_OHLV["Pre Adj Close"]
    ) / adjusted_OHLV["Pre Adj Close"]
    adjusted_OHLV["B4_Adj High pct"] = (
        adjusted_OHLV["Adj High"] - adjusted_OHLV["Pre Adj Close"]
    ) / adjusted_OHLV["Pre Adj Close"]
    adjusted_OHLV["B4_Adj Low pct"] = (
        adjusted_OHLV["Adj Low"] - adjusted_OHLV["Pre Adj Close"]
    ) / adjusted_OHLV["Pre Adj Close"]
    adjusted_OHLV["B4_Adj Volume pct"] = (
        adjusted_OHLV["Adj Volume"] - adjusted_OHLV["Pre Adj Volume"]
    ) / adjusted_OHLV["Pre Adj Volume"]

    return adjusted_OHLV

# %%
def gen_buy_sell_signal(stk_data):
    import pandas_ta as ta

    sma = pd.concat(
        [
            stk_data.ta.sma(close="Adj Close", length=10),
            stk_data.ta.sma(close="Adj Close", length=60),
        ],
        axis=1,
    ).dropna()
    buy_signal = sma["SMA_10"] > sma["SMA_60"]

    buy_sell_signal = stk_data[[]].copy()
    buy_sell_signal["Signal"] = (buy_signal).astype("int")

    return buy_sell_signal


def gen_analysis_data(stk_data, _return_period):
    import pandas_ta as ta

    try:
        adjusted_OHLV = to_adjusted(stk_data)
        data = pd.concat(
            [
                # stk_data.ta.adosc(prefix="B1"),
                # stk_data.ta.kvo(prefix="B1"),
                adjusted_OHLV.ta.adosc(
                    high="Adj High",
                    low="Adj Low",
                    close="Adj Close",
                    volume="Adj Volume",
                    prefix="B2",
                ),
                adjusted_OHLV.ta.kvo(
                    high="Adj High",
                    low="Adj Low",
                    close="Adj Close",
                    volume="Adj Volume",
                    prefix="B2",
                ),
                stk_data.ta.rsi(close="Adj Close", length=10, prefix="B3"),
                stk_data.ta.rsi(close="Adj Close", length=30, prefix="B3"),
                stk_data.ta.rsi(close="Adj Close", length=200, prefix="B3"),
                stk_data.ta.stoch(k=10, prefix="B3"),
                stk_data.ta.stoch(k=30, prefix="B3"),
                stk_data.ta.stoch(k=200, prefix="B3"),
                adjusted_OHLV.loc[
                    :,
                    [
                        "B4_Adj Open pct",
                        "B4_Adj High pct",
                        "B4_Adj Low pct",
                        "B4_Adj Volume pct",
                    ],
                ],
                gen_buy_sell_signal(stk_data),
            ],
            axis=1,
        )

        data = pd.concat(
            [data.astype("float32"), gen_pct_label(stk_data, _return_period)],
            axis=1,
        ).dropna()
    except:
        data = None
    return data


def prepare_analysis_data(_return_period, verbose=False):
    from tqdm import tqdm

    ticks_dataset = []
    ignore_ticks_data_count = 0
    for i, tick_data in enumerate(tqdm(ticks_data)):
        analysis_data = gen_analysis_data(tick_data, _return_period)
        if analysis_data is None:
            print(f"Failed to generate {stk_symbols[i]} analysis data")
            continue
        classes_percentage = class_percentage(analysis_data)
        if 0 in classes_percentage:
            if verbose:
                print(
                    f"Some classes don't have any data  : {stk_symbols[i]}, {classes_percentage}"
                )
            ignore_ticks_data_count += 1
        elif any(p < class_percentage_threshold for p in classes_percentage):
            if verbose:
                print(
                    f"Some classes are too small  : {stk_symbols[i]}, {classes_percentage}"
                )
            ignore_ticks_data_count += 1
        else:
            ticks_dataset.append(analysis_data)
    if ignore_ticks_data_count > 0:
        print(
            f"There are {ignore_ticks_data_count} stocks in total, some classes have no data or are too small"
        )
    return ticks_dataset

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import math
from MyPyUtil.util import ivmax


class LSTMDataSet(Dataset):
    def __init__(self, ticks_data_X, ticks_data_Y, _seq_len):
        self.ticks_data_X = ticks_data_X
        self.ticks_data_Y = ticks_data_Y
        self.seq_len = _seq_len

        len_array = [len(d) - self.seq_len + 1 for d in ticks_data_X]
        self.idx_boundary = [len_array[0]]

        for i in range(1, len(len_array)):
            self.idx_boundary.append(len_array[i] + self.idx_boundary[i - 1])

        self.build_class_indices()

    def build_class_indices(self):
        total_y = pd.concat(
            [t[self.seq_len - 1 :]["label"] for t in self.ticks_data_Y]
        ).reset_index()
        self.class_indices = []
        for i in range(num_classes):
            class_idx_list = total_y.index[total_y["label"] == i].tolist()
            self.class_indices.append(class_idx_list)

    def __len__(self):
        return self.idx_boundary[-1]

    def info(self):
        print(f"Dataset size: {self.idx_boundary[-1]}")
        for i in range(num_classes):
            print(
                f"class {i}: {len(self.class_indices[i]) * 100 /self.idx_boundary[-1]:.1f}% {len(self.class_indices[i])}"
            )

    def __getitem__(self, idx):
        for ticks_data_idx in range(len(self.ticks_data_X)):
            if self.idx_boundary[ticks_data_idx] > idx:
                break
        offset = (
            idx if ticks_data_idx == 0 else idx - self.idx_boundary[ticks_data_idx - 1]
        )
        x = np.array(self.ticks_data_X[ticks_data_idx][offset : offset + self.seq_len])
        y = int(self.ticks_data_Y[ticks_data_idx].iloc[offset + self.seq_len - 1, :])
        return (x, y)

# %%
import random
import math
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler, Normalizer
from sklearn_pandas import DataFrameMapper
from sklearn.utils.class_weight import compute_class_weight


def find_alpha_and_class_weight(y):
    weight_of_CE = compute_class_weight(
        class_weight="balanced", classes=np.unique(y), y=y["label"].values
    )
    alpha = []
    for i in range(len(weight_of_CE)):
        alpha.append(weight_of_CE[i] / sum(weight_of_CE))

    return (alpha, weight_of_CE)


def prepare_XYData(_return_period):
    ticks_dataset = prepare_analysis_data(_return_period)
    ticks_X_train_data = []
    ticks_Y_train_data = []
    ticks_X_test_data = []
    ticks_Y_test_data = []
    ticks_X_dfm = []
    for idx, dataset in enumerate(ticks_dataset):
        # test_size = int(dataset.shape[0] * validation_size)
        train_size = int(dataset.shape[0] * (1 - validation_size))
        train_data = dataset.iloc[0:train_size]
        test_data = dataset.iloc[train_size - seq_len + 1 :]

        X_train_data = train_data.iloc[:, :-1]
        Y_train_data = train_data.iloc[:, -1:]

        X_test_data = test_data.iloc[:, :-1]
        Y_test_data = test_data.iloc[:, -1:]

        features = [
            ([column], StandardScaler()) for column in X_train_data.columns[:-1].values
        ]
        features.extend(
            [([column], None) for column in X_train_data.columns[-1:].values]
        )
        if len(features) != 17:
            print(f"Wrong data: {stk_symbols[idx]}, {X_train_data.columns.values}")
            continue
        # print(idx)
        X_dfm = DataFrameMapper(features, input_df=True, df_out=True)
        X_train_data = X_dfm.fit_transform(X_train_data)
        X_test_data = X_dfm.transform(X_test_data)

        ticks_X_dfm.append(X_dfm)
        ticks_X_train_data.append(X_train_data)
        ticks_Y_train_data.append(Y_train_data)
        ticks_X_test_data.append(X_test_data)
        ticks_Y_test_data.append(Y_test_data)

    return [
        ticks_X_train_data,
        ticks_Y_train_data,
        ticks_X_test_data,
        ticks_Y_test_data,
    ], find_alpha_and_class_weight(pd.concat(ticks_Y_train_data))

# %%
from sklearn.decomposition import PCA


def prepare_XYData_PCA(_return_period):
    XYData, (alpha, class_weight) = prepare_XYData(_return_period)
    X_train_data = XYData[0]
    X_test_data = XYData[2]
    big_X_train_data = pd.concat(X_train_data)

    pca = PCA()
    pca.fit(big_X_train_data)
    eig_vector = pca.components_[:12].T
    # display(eig_vector)

    for i in range(len(X_train_data)):
        X_train_data[i] = X_train_data[i] @ eig_vector
        X_test_data[i] = X_test_data[i] @ eig_vector

    return XYData, (alpha, class_weight)

# %%
from torch import nn


class StockPCTLabelPredictLSTM(nn.Module):
    def __init__(self, input_size, config):
        super().__init__()
        self.setup_model(
            input_size=input_size,
            hidden_size=config["hidden_size"],
            num_layers=config["num_layers"],
            num_fc_layers=config["num_fc_layers"],
            activation_type=config["activation_type"],
        )

    def setup_model(
        self,
        input_size,
        hidden_size,
        num_layers,
        num_fc_layers,
        activation_type,
    ):
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        """
            input_size    : The number of expected features in the input x
            hidden_size   : The number of features in the hidden state h
            num_layers    : Number of recurrent layers. E.g., setting num_layers=2 would mean stacking two LSTMs together to form a stacked LSTM, with the second LSTM taking in outputs of the first LSTM and computing the final results. Default: 1
            bias          : If False, then the layer does not use bias weights b_ih and b_hh. Default: True
            batch_first   : If True, then the input and output tensors are provided as (batch, seq, feature) instead of (seq, batch, feature). Note that this does not apply to hidden or cell states. See the Inputs/Outputs sections below for details. Default: False
            dropout       : If non-zero, introduces a Dropout layer on the outputs of each LSTM layer except the last layer, with dropout probability equal to dropout. Default: 0
            bidirectional : If True, becomes a bidirectional LSTM. Default: False
            proj_size     : If > 0, will use LSTM with projections of corresponding size. Default: 0
        """
        self.rnn = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)

        layers = []
        in_features = self.hidden_size
        for i in range(1, num_fc_layers):
            out_features = int(in_features / 2)
            if out_features <= num_classes:
                break
            layers.append(nn.Linear(in_features, out_features))
            (
                layers.append(nn.ReLU() if activation_type == 1 else nn.Sigmoid())
                if activation_type == 2
                else nn.Tanh()
            )
            in_features = out_features

        layers.append(nn.Linear(in_features, num_classes))
        self.fc = nn.Sequential(*layers)
        self.fc.apply(self.init_weights)

    def init_weights(self, m):
        if isinstance(m, nn.Linear):
            initrange = 0.5
            nn.init.uniform_(m.weight, -initrange, initrange)
            nn.init.zeros_(m.bias)

    def forward(self, x):
        h_0 = torch.zeros(self.num_layers, x.shape[0], self.hidden_size).to(device)
        c_0 = torch.zeros(self.num_layers, x.shape[0], self.hidden_size).to(device)
        out, (h_out, _) = self.rnn(x, (h_0, c_0))

        fc_input = h_out[-1].view(-1, self.hidden_size)
        return self.fc(fc_input)


def save_model(model, hyper_parameters, file_path, epoch_num=None):
    state = {
        "epoch_num": epoch_num,
        "time": str(datetime.now),
        "model_state": model.state_dict(),
        "input_size": model.input_size,
        "hyper_parameters": hyper_parameters,
    }
    torch.save(state, file_path)


def load_model(file_path):
    data_dict = torch.load(file_path)
    hyper_parameters = data_dict["hyper_parameters"]
    model = StockPCTLabelPredictLSTM(
        input_size=data_dict["input_size"],
        config=hyper_parameters,
    )
    model.load_state_dict(data_dict["model_state"])
    return model, hyper_parameters

# %%
import torch.nn as nn

METRICS_LABEL_NDX = 0  # ground_truth
METRICS_PBTY_NDX = 1  # Probability of predicition
METRICS_PRED_NDX = 2  # class(label) of predicition
METRICS_LOSS_NDX = 3
METRICS_SIZE = 4
softmax = nn.Softmax(dim=1)
totalTrainingSamples_count = 0

# %%
from collections import namedtuple
from torch.utils.tensorboard import SummaryWriter


def logMetrics(
    epoch_ndx,
    mode_str,
    metrics_t,
    classificationThreshold=0.5,
    config=None,
    log_hparam=False,
):
    log.info(
        "E{} {}".format(
            epoch_ndx,
            task_name,
        )
    )
    F1_rec = namedtuple(
        "f1_rec",
        "target_class pos_correct neg_correct pos_count neg_count pos_loss neg_loss precision recall F1",
    )
    F1_metrics = []
    for target_class in reversed(range(num_classes)):
        posLabel_mask = metrics_t[METRICS_LABEL_NDX] == target_class
        pos_count = posLabel_mask.sum()
        negLabel_mask = metrics_t[METRICS_LABEL_NDX] != target_class
        neg_count = negLabel_mask.sum()

        posPred_mask = metrics_t[METRICS_PRED_NDX] == target_class
        threshold_mask = metrics_t[METRICS_PBTY_NDX] > classificationThreshold
        # TP, truePos_count
        TP = pos_correct = int((posLabel_mask & posPred_mask & threshold_mask).sum())

        negPred_mask = metrics_t[METRICS_PRED_NDX] != target_class
        # TN, trueNeg_count
        TN = neg_correct = int((negLabel_mask & negPred_mask).sum())

        # FP, falsePos_count
        FP = neg_count - neg_correct
        # FN, falseNeg_count
        FN = pos_count - pos_correct

        # precision = TP / (TP + FP)
        precision = 0.0 if (TP + FP) == 0 else TP / np.float32(TP + FP)
        # recall = TP / (TP + FN)
        recall = 0.0 if (TP + FN) == 0 else TP / np.float32(TP + FN)
        # F1 = 2 * precision * recall / (precision + recall)
        F1 = (
            0.0
            if (precision + recall) == 0.0
            else (2 * precision * recall) / np.float32(precision + recall)
        )
        F1_metrics.append(
            F1_rec(
                target_class,
                pos_correct,
                neg_correct,
                pos_count,
                neg_count,
                metrics_t[METRICS_LOSS_NDX, posLabel_mask].mean(),
                metrics_t[METRICS_LOSS_NDX, negLabel_mask].mean(),
                precision,
                recall,
                F1,
            )
        )

        if num_classes == 2:
            break

    metrics_dict = {}
    metrics_dict[" e_loss/all"] = metrics_t[METRICS_LOSS_NDX].mean()
    log.info(
        ("E{} {:8} { e_loss/all:.4f} loss").format(
            epoch_ndx,
            mode_str,
            **metrics_dict,
        )
    )

    for target_class, rec in enumerate(F1_metrics):
        target_class_str = f"class {rec.target_class}" if num_classes > 2 else ""
        metrics_dict[f"{target_class_str} e_loss/pos"] = rec.pos_loss
        metrics_dict[f"{target_class_str} e_loss/neg"] = rec.neg_loss

        metrics_dict[f"{target_class_str} correct/all"] = (
            (rec.pos_correct + rec.neg_correct) / metrics_t.shape[1] * 100
        )
        metrics_dict[f"{target_class_str} correct/neg"] = (
            (rec.neg_correct) / rec.neg_count * 100
        )
        metrics_dict[f"{target_class_str} correct/pos"] = (
            (rec.pos_correct) / rec.pos_count * 100
        )
        metrics_dict[f"{target_class_str} pr/precision"] = rec.precision
        metrics_dict[f"{target_class_str} pr/recall"] = rec.recall
        metrics_dict[f"{target_class_str} pr/f1_score"] = rec.F1

        log.info(
            (
                "E{} {:8} {} {"
                + f"{target_class_str}"
                + " correct/all:-5.1f}% correct, "
                + "{"
                + f"{target_class_str}"
                + " pr/precision:.4f} precision, "
                + "{"
                + f"{target_class_str}"
                + " pr/recall:.4f} recall, "
                + "{"
                + f"{target_class_str}"
                + " pr/f1_score:.4f} f1 score"
            ).format(epoch_ndx, mode_str, target_class_str, **metrics_dict)
        )
        log.info(
            (
                "E{} {:8} {} {"
                + f"{target_class_str}"
                + " e_loss/neg:.4f} loss, "
                + "{"
                + f"{target_class_str}"
                + " correct/neg:-5.1f}% correct ({neg_correct:} of {neg_count:})"
            ).format(
                epoch_ndx,
                mode_str + "_neg",
                target_class_str,
                neg_correct=rec.neg_correct,
                neg_count=rec.neg_count,
                **metrics_dict,
            )
        )
        log.info(
            (
                "E{} {:8} {} {"
                + f"{target_class_str}"
                + " e_loss/pos:.4f} loss, "
                + "{"
                + f"{target_class_str}"
                + " correct/pos:-5.1f}% correct ({pos_correct:} of {pos_count:})"
            ).format(
                epoch_ndx,
                mode_str + "_pos",
                target_class_str,
                pos_correct=rec.pos_correct,
                pos_count=rec.pos_count,
                **metrics_dict,
            )
        )

    writer = SummaryWriter(log_dir=log_dir + f"/{mode_str}_cls")
    for key, value in metrics_dict.items():
        writer.add_scalar(key, value, totalTrainingSamples_count)

    writer.add_pr_curve(
        "pr",
        metrics_t[METRICS_LABEL_NDX],
        metrics_t[METRICS_PRED_NDX],
        totalTrainingSamples_count,
    )

    bins = [x / 50.0 for x in range(51)]
    negHist_mask = negLabel_mask & (metrics_t[METRICS_PBTY_NDX] > 0.01)
    posHist_mask = posLabel_mask & (metrics_t[METRICS_PBTY_NDX] < 0.99)
    if negHist_mask.any():
        writer.add_histogram(
            "is_neg",
            metrics_t[METRICS_PBTY_NDX, negHist_mask],
            totalTrainingSamples_count,
            bins=bins,
        )
    if posHist_mask.any():
        writer.add_histogram(
            "is_pos",
            metrics_t[METRICS_PBTY_NDX, posHist_mask],
            totalTrainingSamples_count,
            bins=bins,
        )

    if log_hparam:
        hparam = config.copy()
        hparam["0:trn,1:val"] = 0 if mode_str == "trn" else 1
        writer.add_hparams(
            hparam,
            {
                "loss": metrics_t[METRICS_LOSS_NDX].mean(),
                "F1": F1_metrics[-1].F1,
            },
        )

    writer.close()

    return float(metrics_dict[" e_loss/all"]), F1_metrics
# Out:
# 2024-02-28 15:39:33.166652: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-28 15:39:33.395775: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-28 15:39:33.868543: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2, ignore_index=-100, reduction="mean"):
        super().__init__()
        # use standard CE loss without reducion as basis
        self.CE = nn.CrossEntropyLoss(reduction="none", ignore_index=ignore_index)
        self.alpha = alpha
        if isinstance(alpha, (float, int)):
            self.alpha = torch.Tensor([alpha, 1 - alpha]).to(device)
        if isinstance(alpha, list):
            self.alpha = torch.Tensor(alpha).to(device)
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, input, target):
        """
        input (B, N)
        target (B)
        """
        minus_logpt = self.CE(input, target)
        pt = torch.exp(-minus_logpt)  # don't forget the minus here
        focal_loss = (1 - pt) ** self.gamma * minus_logpt

        # apply class weights
        if self.alpha != None:
            focal_loss *= self.alpha.gather(0, target)

        if self.reduction == "mean":
            return focal_loss.mean()
        elif self.reduction == "sum":
            return focal_loss.sum()
        else:
            return focal_loss

# %%
import sys


def computeBatchLoss(model, loss_fn, x, y, metrics_g, batch_idx):
    x_g = x.to(device)
    y_g = y.to(device)
    outputs = model(x_g)
    if outputs.isnan().sum() > 0:
        return sys.float_info.max

    loss_g = loss_fn(outputs, y_g)
    probability_g, predition_g = torch.max(softmax(outputs), dim=1)

    start_ndx = batch_idx * batch_size
    end_ndx = start_ndx + y.size(0)
    if metrics_g != None:
        metrics_g[METRICS_LABEL_NDX, start_ndx:end_ndx] = y_g
        metrics_g[METRICS_PBTY_NDX, start_ndx:end_ndx] = probability_g
        metrics_g[METRICS_PRED_NDX, start_ndx:end_ndx] = predition_g
        metrics_g[METRICS_LOSS_NDX, start_ndx:end_ndx] = loss_g
    loss = loss_g.mean()
    return loss

# %%
from MyPyUtil.util import enumerateWithEstimate
import torch
from tqdm import tqdm


def doTraining(model, optimizer, loss_fn, epoch_ndx, train_dl, trnMetrics_g):
    global totalTrainingSamples_count
    model.train()

    batch_iter = enumerateWithEstimate(
        train_dl,
        "E{} Training".format(epoch_ndx),
        start_ndx=train_dl.num_workers,
    )
    for batch_ndx, (x, y) in batch_iter:
        # for batch_ndx, (x, y) in enumerate(tqdm(train_dl)):
        optimizer.zero_grad()

        loss = computeBatchLoss(
            model,
            loss_fn,
            x,
            y,
            trnMetrics_g,
            batch_ndx,
        )

        if loss == sys.float_info.max:
            print(f"forward error: {batch_ndx}")
        else:
            loss.backward()
            optimizer.step()

    totalTrainingSamples_count += len(train_dl.dataset)
    return trnMetrics_g.to("cpu") if trnMetrics_g != None else None

# %%
from MyPyUtil.util import enumerateWithEstimate
import torch
from tqdm import tqdm


def doTrainingForRayTune(model, optimizer, loss_fn, epoch_ndx, train_dl):
    global totalTrainingSamples_count
    model.train()

    total_loss = 0.0
    batch_iter = enumerateWithEstimate(
        train_dl,
        "E{} Training".format(epoch_ndx),
        start_ndx=train_dl.num_workers,
    )
    for batch_ndx, (x, y) in batch_iter:
        # for batch_ndx, (x, y) in enumerate(tqdm(train_dl)):
        optimizer.zero_grad()

        loss = computeBatchLoss(
            model,
            loss_fn,
            x,
            y,
            None,
            batch_ndx,
        )

        if loss == sys.float_info.max:
            print(f"forward error: {batch_ndx}")
        else:
            loss.backward()
            optimizer.step()
            total_loss += loss.item() * len(x)

    totalTrainingSamples_count += len(train_dl.dataset)
    return total_loss / len(train_dl.dataset)

# %%
def doValidation(model, loss_fn, epoch_ndx, val_dl, valMetrics_g):
    from sklearn.metrics import f1_score

    with torch.no_grad():
        model.eval()

        batch_iter = enumerateWithEstimate(
            val_dl,
            "E{} Validation ".format(epoch_ndx),
            start_ndx=val_dl.num_workers,
        )
        for batch_ndx, (x, y) in batch_iter:
            # for batch_ndx, (x, y) in enumerate(tqdm(val_dl)):
            loss = computeBatchLoss(model, loss_fn, x, y, valMetrics_g, batch_ndx)
            if loss == sys.float_info.max:
                print(f"forward error: {batch_ndx}")

    return valMetrics_g.to("cpu")

# %%
def config_2_str(config):
    return "_".join(
        (
            v
            if type(v).__name__ == "str"
            else "None" if v is None else str(v) if v < 1 else f"{v:g}"
        )
        for v in config.values()
    )

# %%
def ray_train_task(config, data, alpha, class_weight, time_str):
    global totalTrainingSamples_count
    global log_dir

    best_f1 = 0

    lr = config["lr"]
    momentum = config["momentum"]
    optim_type = config["optim_type"]
    totalTrainingSamples_count = 0

    id_str = config_2_str(config)
    # print(id_str)
    log_dir = f"{log_dir_base}/{time_str}/{id_str}"
    os.mkdir(log_dir)

    model_name = f"{log_dir}/{id_str}.pt"

    train_dataset = LSTMDataSet(
        data[0],
        data[1],
        seq_len,
    )
    test_dataset = LSTMDataSet(
        data[2],
        data[3],
        seq_len,
    )

    print("Training data:")
    train_dataset.info()
    print("\nTest data")
    test_dataset.info()

    train_loader = DataLoader(
        train_dataset,
        batch_size,
        shuffle=shuffle,
        num_workers=num_workers,
        pin_memory=pin_memory,
        pin_memory_device=device_name,
    )
    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        pin_memory=pin_memory,
        pin_memory_device=device_name,
    )

    features_size = len(data[0][0].columns)

    model = StockPCTLabelPredictLSTM(input_size=features_size, config=config)
    model = model.to(device)

    optimizer = (
        torch.optim.Adam(model.parameters(), lr=lr)
        if optim_type == 1
        else torch.optim.SGD(
            model.parameters(),
            lr=lr,
            momentum=momentum,
            weight_decay=config["weight decay"],
        )
    )

    if config["loss_fn"] == "CrossEntropy":
        loss_fn = torch.nn.CrossEntropyLoss(
            weight=torch.tensor(class_weight, dtype=torch.float32).to(device),
            reduction="none",
        )
    else:
        loss_fn = FocalLoss(alpha=alpha, reduction="none")

    # trnMetrics_g = None
    trnMetrics_g = torch.empty(
        METRICS_SIZE,
        len(train_loader.dataset),
        device=device,
    )
    valMetrics_g = torch.empty(
        METRICS_SIZE,
        len(test_loader.dataset),
        device=device,
    )

    for epoch_ndx in range(epoch_num):
        trnMetrics_g.zero_()
        valMetrics_g.zero_()

        # loss = doTrainingForRayTune(model, optimizer, loss_fn, epoch_ndx, train_loader)

        trnMetrics_t = doTraining(
            model, optimizer, loss_fn, epoch_ndx, train_loader, trnMetrics_g
        )
        loss, _ = logMetrics(
            epoch_ndx,
            "trn",
            trnMetrics_t,
            classificationThreshold,
            config,
            (epoch_ndx == epoch_num - 1),
        )

        valMetrics_t = doValidation(
            model, loss_fn, epoch_ndx, test_loader, valMetrics_g
        )
        _, F1_metrics = logMetrics(
            epoch_ndx,
            "val",
            valMetrics_t,
            classificationThreshold,
            config,
            (epoch_ndx == epoch_num - 1),
        )
        if F1_metrics[0].F1 > best_f1:
            best_f1 = F1_metrics[0].F1
            save_model(model, config, model_name)

        train.report(
            {
                "loss": loss,
                "f1_score": F1_metrics[0].F1,
                "precision": F1_metrics[0].precision,
                "recall": F1_metrics[0].recall,
            }
        )

# %%
config = {
    "loss_fn": "CrossEntropy",
    "lr": 0.01,
    "momentum": 0.11646759543664197,
    "optim_type": 2,  # 1: Adam, 2: SGD  => Adam bad result
    "weight decay": 0.00001,  # best value
    "num_layers": 3,  # [1, 2, 4, 8] best value = 3 or 4
    "hidden_size": 128,  # [8, 16, 32, 64, 128]
    "num_fc_layers": 1,  # 1, 2, 3]),
    "activation_type": 2,  # 1: ReLU(),  2: Sigmoid(),  3: Tanh()  => meaningless num_fc_layers == 1
}
time_str = datetime.now().strftime("%Y-%m-%d_%H.%M.%S")
log_dir = f"{log_dir_base}/{time_str}"
os.mkdir(log_dir)

XYData, (alpha, class_weight) = prepare_XYData_PCA(return_period)
ray_train_task(
    config,
    data=XYData,
    alpha=alpha,
    class_weight=class_weight,
    time_str=time_str,
)
# Out:
#  34%|███▍      | 511/1486 [00:05<00:09, 99.20it/s]
# Failed to generate HUBB analysis data
# 100%|██████████| 1486/1486 [00:14<00:00, 99.70it/s]
# There are 12 stocks in total, some classes have no data or are too small
# Wrong data: BIIB, ['B2_ADOSC_3_10' 'B2_KVO_34_55_13' 'B2_KVOs_34_55_13' 'B3_RSI_10' 'B3_RSI_30' 'Open' 'High' 'Low' 'Close' 'Adj Close' 'Volume'
#  'B3_STOCHk_10_3_3' 'B3_STOCHd_10_3_3' 'B3_STOCHk_30_3_3' 'B3_STOCHd_30_3_3' 'Open' 'High' 'Low' 'Close' 'Adj Close' 'Volume'
#  'B4_Adj Open pct' 'B4_Adj High pct' 'B4_Adj Low pct' 'B4_Adj Volume pct' 'Signal']
# Wrong data: BKR, ['B2_ADOSC_3_10' 'B2_KVO_34_55_13' 'B2_KVOs_34_55_13' 'B3_RSI_10' 'B3_RSI_30' 'Open' 'High' 'Low' 'Close' 'Adj Close' 'Volume'
#  'B3_STOCHk_10_3_3' 'B3_STOCHd_10_3_3' 'B3_STOCHk_30_3_3' 'B3_STOCHd_30_3_3' 'Open' 'High' 'Low' 'Close' 'Adj Close' 'Volume'
#  'B4_Adj Open pct' 'B4_Adj High pct' 'B4_Adj Low pct' 'B4_Adj Volume pct' 'Signal']
# Wrong data: VFC, ['B2_ADOSC_3_10' 'B2_KVO_34_55_13' 'B2_KVOs_34_55_13' 'B3_RSI_10' 'B3_RSI_30' 'Open' 'High' 'Low' 'Close' 'Adj Close' 'Volume'
#  'B3_STOCHk_10_3_3' 'B3_STOCHd_10_3_3' 'B3_STOCHk_30_3_3' 'B3_STOCHd_30_3_3' 'Open' 'High' 'Low' 'Close' 'Adj Close' 'Volume'
#  'B4_Adj Open pct' 'B4_Adj High pct' 'B4_Adj Low pct' 'B4_Adj Volume pct' 'Signal']
# 2024-02-28 15:40:25,514 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E0 Training ----/19399, starting
# Training data:
# Dataset size: 620749
# class 0: 84.0% 521318
# class 1: 16.0% 99431
#
# Test data
# Dataset size: 156874
# class 0: 82.7% 129778
# class 1: 17.3% 27096
# 2024-02-28 15:40:25,844 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E0 Training   32/19399, done at 2024-02-28 15:40:48, 0:00:22
# 2024-02-28 15:40:26,095 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E0 Training  256/19399, done at 2024-02-28 15:40:47, 0:00:21
# 2024-02-28 15:40:27,980 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E0 Training 2048/19399, done at 2024-02-28 15:40:46, 0:00:20
# 2024-02-28 15:40:43,053 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E0 Training 16384/19399, done at 2024-02-28 15:40:46, 0:00:20
# 2024-02-28 15:40:46,118 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E0 Training 19399/19399, done at 2024-02-28 15:40:46
# 2024-02-28 15:40:46,121 INFO     pid:12811 __main__:013:logMetrics E0 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:40:46,134 INFO     pid:12811 __main__:074:logMetrics E0 trn      0.6666 loss
# 2024-02-28 15:40:46,135 INFO     pid:12811 __main__:100:logMetrics E0 trn        61.1% correct, 0.2219 precision, 0.5696 recall, 0.3194 f1 score
# 2024-02-28 15:40:46,135 INFO     pid:12811 __main__:116:logMetrics E0 trn_neg   0.3963 loss,  61.9% correct (322671 of 521318)
# 2024-02-28 15:40:46,135 INFO     pid:12811 __main__:133:logMetrics E0 trn_pos   2.0840 loss,  57.0% correct (56640 of 99431)
# 2024-02-28 15:40:46,186 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E0 Validation  ----/4903, starting
# 2024-02-28 15:40:46,254 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E0 Validation    16/4903, done at 2024-02-28 15:40:49, 0:00:03
# 2024-02-28 15:40:46,287 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E0 Validation    64/4903, done at 2024-02-28 15:40:49, 0:00:03
# 2024-02-28 15:40:46,427 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E0 Validation   256/4903, done at 2024-02-28 15:40:49, 0:00:03
# 2024-02-28 15:40:46,999 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E0 Validation  1024/4903, done at 2024-02-28 15:40:49, 0:00:03
# 2024-02-28 15:40:49,957 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E0 Validation  4096/4903, done at 2024-02-28 15:40:50, 0:00:04
# 2024-02-28 15:40:50,716 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E0 Validation  4903/4903, done at 2024-02-28 15:40:50
# 2024-02-28 15:40:50,717 INFO     pid:12811 __main__:013:logMetrics E0 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:40:50,720 INFO     pid:12811 __main__:074:logMetrics E0 val      0.6786 loss
# 2024-02-28 15:40:50,720 INFO     pid:12811 __main__:100:logMetrics E0 val        60.3% correct, 0.2456 precision, 0.6277 recall, 0.3530 f1 score
# 2024-02-28 15:40:50,720 INFO     pid:12811 __main__:116:logMetrics E0 val_neg   0.4085 loss,  59.7% correct (77523 of 129778)
# 2024-02-28 15:40:50,720 INFO     pid:12811 __main__:133:logMetrics E0 val_pos   1.9723 loss,  62.8% correct (17008 of 27096)
# 2024-02-28 15:40:50,734 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E1 Training ----/19399, starting
# 2024-02-28 15:40:50,844 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E1 Training   32/19399, done at 2024-02-28 15:41:12, 0:00:22
# 2024-02-28 15:40:51,086 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E1 Training  256/19399, done at 2024-02-28 15:41:11, 0:00:21
# 2024-02-28 15:40:52,879 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E1 Training 2048/19399, done at 2024-02-28 15:41:10, 0:00:19
# 2024-02-28 15:41:08,017 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E1 Training 16384/19399, done at 2024-02-28 15:41:11, 0:00:20
# 2024-02-28 15:41:10,959 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E1 Training 19399/19399, done at 2024-02-28 15:41:10
# 2024-02-28 15:41:10,962 INFO     pid:12811 __main__:013:logMetrics E1 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:41:10,971 INFO     pid:12811 __main__:074:logMetrics E1 trn      0.6609 loss
# 2024-02-28 15:41:10,972 INFO     pid:12811 __main__:100:logMetrics E1 trn        62.8% correct, 0.2314 precision, 0.5701 recall, 0.3291 f1 score
# 2024-02-28 15:41:10,972 INFO     pid:12811 __main__:116:logMetrics E1 trn_neg   0.3929 loss,  63.9% correct (333003 of 521318)
# 2024-02-28 15:41:10,972 INFO     pid:12811 __main__:133:logMetrics E1 trn_pos   2.0659 loss,  57.0% correct (56684 of 99431)
# 2024-02-28 15:41:11,020 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E1 Validation  ----/4903, starting
# 2024-02-28 15:41:11,095 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E1 Validation    16/4903, done at 2024-02-28 15:41:15, 0:00:04
# 2024-02-28 15:41:11,137 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E1 Validation    64/4903, done at 2024-02-28 15:41:15, 0:00:04
# 2024-02-28 15:41:11,292 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E1 Validation   256/4903, done at 2024-02-28 15:41:15, 0:00:04
# 2024-02-28 15:41:11,832 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E1 Validation  1024/4903, done at 2024-02-28 15:41:14, 0:00:03
# 2024-02-28 15:41:14,802 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E1 Validation  4096/4903, done at 2024-02-28 15:41:15, 0:00:04
# 2024-02-28 15:41:15,547 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E1 Validation  4903/4903, done at 2024-02-28 15:41:15
# 2024-02-28 15:41:15,548 INFO     pid:12811 __main__:013:logMetrics E1 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:41:15,552 INFO     pid:12811 __main__:074:logMetrics E1 val      0.6789 loss
# 2024-02-28 15:41:15,552 INFO     pid:12811 __main__:100:logMetrics E1 val        53.7% correct, 0.2330 precision, 0.7336 recall, 0.3536 f1 score
# 2024-02-28 15:41:15,552 INFO     pid:12811 __main__:116:logMetrics E1 val_neg   0.4547 loss,  49.6% correct (64340 of 129778)
# 2024-02-28 15:41:15,552 INFO     pid:12811 __main__:133:logMetrics E1 val_pos   1.7526 loss,  73.4% correct (19877 of 27096)
# 2024-02-28 15:41:15,566 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E2 Training ----/19399, starting
# 2024-02-28 15:41:15,684 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E2 Training   32/19399, done at 2024-02-28 15:41:39, 0:00:23
# 2024-02-28 15:41:15,929 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E2 Training  256/19399, done at 2024-02-28 15:41:37, 0:00:21
# 2024-02-28 15:41:18,333 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E2 Training 2048/19399, done at 2024-02-28 15:41:41, 0:00:25
# 2024-02-28 15:41:33,099 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E2 Training 16384/19399, done at 2024-02-28 15:41:36, 0:00:20
# 2024-02-28 15:41:35,977 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E2 Training 19399/19399, done at 2024-02-28 15:41:35
# 2024-02-28 15:41:35,980 INFO     pid:12811 __main__:013:logMetrics E2 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:41:35,990 INFO     pid:12811 __main__:074:logMetrics E2 trn      0.6590 loss
# 2024-02-28 15:41:35,991 INFO     pid:12811 __main__:100:logMetrics E2 trn        63.1% correct, 0.2336 precision, 0.5724 recall, 0.3318 f1 score
# 2024-02-28 15:41:35,991 INFO     pid:12811 __main__:116:logMetrics E2 trn_neg   0.3918 loss,  64.2% correct (334621 of 521318)
# 2024-02-28 15:41:35,992 INFO     pid:12811 __main__:133:logMetrics E2 trn_pos   2.0603 loss,  57.2% correct (56910 of 99431)
# 2024-02-28 15:41:36,041 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E2 Validation  ----/4903, starting
# 2024-02-28 15:41:36,124 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E2 Validation    16/4903, done at 2024-02-28 15:41:39, 0:00:03
# 2024-02-28 15:41:36,165 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E2 Validation    64/4903, done at 2024-02-28 15:41:40, 0:00:04
# 2024-02-28 15:41:36,308 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E2 Validation   256/4903, done at 2024-02-28 15:41:39, 0:00:03
# 2024-02-28 15:41:36,834 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E2 Validation  1024/4903, done at 2024-02-28 15:41:39, 0:00:03
# 2024-02-28 15:41:39,851 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E2 Validation  4096/4903, done at 2024-02-28 15:41:40, 0:00:04
# 2024-02-28 15:41:40,629 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E2 Validation  4903/4903, done at 2024-02-28 15:41:40
# 2024-02-28 15:41:40,630 INFO     pid:12811 __main__:013:logMetrics E2 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:41:40,633 INFO     pid:12811 __main__:074:logMetrics E2 val      0.6784 loss
# 2024-02-28 15:41:40,633 INFO     pid:12811 __main__:100:logMetrics E2 val        54.9% correct, 0.2348 precision, 0.7141 recall, 0.3534 f1 score
# 2024-02-28 15:41:40,633 INFO     pid:12811 __main__:116:logMetrics E2 val_neg   0.4439 loss,  51.4% correct (66714 of 129778)
# 2024-02-28 15:41:40,634 INFO     pid:12811 __main__:133:logMetrics E2 val_pos   1.8017 loss,  71.4% correct (19349 of 27096)
# 2024-02-28 15:41:40,647 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E3 Training ----/19399, starting
# 2024-02-28 15:41:40,778 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E3 Training   32/19399, done at 2024-02-28 15:42:06, 0:00:25
# 2024-02-28 15:41:41,002 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E3 Training  256/19399, done at 2024-02-28 15:42:00, 0:00:20
# 2024-02-28 15:41:43,388 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E3 Training 2048/19399, done at 2024-02-28 15:42:05, 0:00:25
# 2024-02-28 15:41:58,244 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E3 Training 16384/19399, done at 2024-02-28 15:42:01, 0:00:20
# 2024-02-28 15:42:01,312 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E3 Training 19399/19399, done at 2024-02-28 15:42:01
# 2024-02-28 15:42:01,315 INFO     pid:12811 __main__:013:logMetrics E3 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:42:01,325 INFO     pid:12811 __main__:074:logMetrics E3 trn      0.6570 loss
# 2024-02-28 15:42:01,326 INFO     pid:12811 __main__:100:logMetrics E3 trn        63.2% correct, 0.2350 precision, 0.5766 recall, 0.3339 f1 score
# 2024-02-28 15:42:01,326 INFO     pid:12811 __main__:116:logMetrics E3 trn_neg   0.3906 loss,  64.2% correct (334725 of 521318)
# 2024-02-28 15:42:01,326 INFO     pid:12811 __main__:133:logMetrics E3 trn_pos   2.0539 loss,  57.7% correct (57328 of 99431)
# 2024-02-28 15:42:01,373 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E3 Validation  ----/4903, starting
# 2024-02-28 15:42:01,466 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E3 Validation    16/4903, done at 2024-02-28 15:42:05, 0:00:03
# 2024-02-28 15:42:01,511 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E3 Validation    64/4903, done at 2024-02-28 15:42:05, 0:00:04
# 2024-02-28 15:42:01,668 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E3 Validation   256/4903, done at 2024-02-28 15:42:05, 0:00:04
# 2024-02-28 15:42:02,539 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E3 Validation  1024/4903, done at 2024-02-28 15:42:06, 0:00:05
# 2024-02-28 15:42:04,935 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E3 Validation  4096/4903, done at 2024-02-28 15:42:05, 0:00:04
# 2024-02-28 15:42:05,726 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E3 Validation  4903/4903, done at 2024-02-28 15:42:05
# 2024-02-28 15:42:05,727 INFO     pid:12811 __main__:013:logMetrics E3 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:42:05,730 INFO     pid:12811 __main__:074:logMetrics E3 val      0.6813 loss
# 2024-02-28 15:42:05,731 INFO     pid:12811 __main__:100:logMetrics E3 val        64.9% correct, 0.2555 precision, 0.5396 recall, 0.3468 f1 score
# 2024-02-28 15:42:05,731 INFO     pid:12811 __main__:116:logMetrics E3 val_neg   0.3796 loss,  67.2% correct (87176 of 129778)
# 2024-02-28 15:42:05,731 INFO     pid:12811 __main__:133:logMetrics E3 val_pos   2.1264 loss,  54.0% correct (14622 of 27096)
# 2024-02-28 15:42:05,744 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E4 Training ----/19399, starting
# 2024-02-28 15:42:05,888 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E4 Training   32/19399, done at 2024-02-28 15:42:33, 0:00:27
# 2024-02-28 15:42:06,115 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E4 Training  256/19399, done at 2024-02-28 15:42:26, 0:00:20
# 2024-02-28 15:42:08,231 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E4 Training 2048/19399, done at 2024-02-28 15:42:28, 0:00:22
# 2024-02-28 15:42:23,688 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E4 Training 16384/19399, done at 2024-02-28 15:42:26, 0:00:21
# 2024-02-28 15:42:27,011 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E4 Training 19399/19399, done at 2024-02-28 15:42:27
# 2024-02-28 15:42:27,013 INFO     pid:12811 __main__:013:logMetrics E4 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:42:27,024 INFO     pid:12811 __main__:074:logMetrics E4 trn      0.6551 loss
# 2024-02-28 15:42:27,024 INFO     pid:12811 __main__:100:logMetrics E4 trn        63.2% correct, 0.2364 precision, 0.5809 recall, 0.3361 f1 score
# 2024-02-28 15:42:27,025 INFO     pid:12811 __main__:116:logMetrics E4 trn_neg   0.3893 loss,  64.2% correct (334789 of 521318)
# 2024-02-28 15:42:27,025 INFO     pid:12811 __main__:133:logMetrics E4 trn_pos   2.0492 loss,  58.1% correct (57755 of 99431)
# 2024-02-28 15:42:27,077 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E4 Validation  ----/4903, starting
# 2024-02-28 15:42:27,179 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E4 Validation    16/4903, done at 2024-02-28 15:42:30, 0:00:03
# 2024-02-28 15:42:27,221 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E4 Validation    64/4903, done at 2024-02-28 15:42:31, 0:00:04
# 2024-02-28 15:42:27,365 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E4 Validation   256/4903, done at 2024-02-28 15:42:30, 0:00:03
# 2024-02-28 15:42:27,907 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E4 Validation  1024/4903, done at 2024-02-28 15:42:30, 0:00:03
# 2024-02-28 15:42:30,248 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E4 Validation  4096/4903, done at 2024-02-28 15:42:30, 0:00:03
# 2024-02-28 15:42:31,022 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E4 Validation  4903/4903, done at 2024-02-28 15:42:31
# 2024-02-28 15:42:31,024 INFO     pid:12811 __main__:013:logMetrics E4 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:42:31,027 INFO     pid:12811 __main__:074:logMetrics E4 val      0.6786 loss
# 2024-02-28 15:42:31,028 INFO     pid:12811 __main__:100:logMetrics E4 val        61.7% correct, 0.2480 precision, 0.5997 recall, 0.3509 f1 score
# 2024-02-28 15:42:31,028 INFO     pid:12811 __main__:116:logMetrics E4 val_neg   0.3986 loss,  62.0% correct (80493 of 129778)
# 2024-02-28 15:42:31,028 INFO     pid:12811 __main__:133:logMetrics E4 val_pos   2.0198 loss,  60.0% correct (16250 of 27096)
# 2024-02-28 15:42:31,041 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E5 Training ----/19399, starting
# 2024-02-28 15:42:31,188 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E5 Training   32/19399, done at 2024-02-28 15:42:56, 0:00:25
# 2024-02-28 15:42:31,433 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E5 Training  256/19399, done at 2024-02-28 15:42:52, 0:00:21
# 2024-02-28 15:42:33,246 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E5 Training 2048/19399, done at 2024-02-28 15:42:51, 0:00:19
# 2024-02-28 15:42:47,962 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E5 Training 16384/19399, done at 2024-02-28 15:42:51, 0:00:19
# 2024-02-28 15:42:51,889 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E5 Training 19399/19399, done at 2024-02-28 15:42:51
# 2024-02-28 15:42:51,893 INFO     pid:12811 __main__:013:logMetrics E5 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:42:51,905 INFO     pid:12811 __main__:074:logMetrics E5 trn      0.6536 loss
# 2024-02-28 15:42:51,906 INFO     pid:12811 __main__:100:logMetrics E5 trn        63.2% correct, 0.2373 precision, 0.5872 recall, 0.3380 f1 score
# 2024-02-28 15:42:51,906 INFO     pid:12811 __main__:116:logMetrics E5 trn_neg   0.3883 loss,  64.0% correct (333685 of 521318)
# 2024-02-28 15:42:51,906 INFO     pid:12811 __main__:133:logMetrics E5 trn_pos   2.0450 loss,  58.7% correct (58389 of 99431)
# 2024-02-28 15:42:51,954 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E5 Validation  ----/4903, starting
# 2024-02-28 15:42:52,065 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E5 Validation    16/4903, done at 2024-02-28 15:42:56, 0:00:03
# 2024-02-28 15:42:52,104 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E5 Validation    64/4903, done at 2024-02-28 15:42:56, 0:00:04
# 2024-02-28 15:42:52,248 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E5 Validation   256/4903, done at 2024-02-28 15:42:55, 0:00:03
# 2024-02-28 15:42:52,801 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E5 Validation  1024/4903, done at 2024-02-28 15:42:55, 0:00:03
# 2024-02-28 15:42:55,137 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E5 Validation  4096/4903, done at 2024-02-28 15:42:55, 0:00:03
# 2024-02-28 15:42:55,923 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E5 Validation  4903/4903, done at 2024-02-28 15:42:55
# 2024-02-28 15:42:55,924 INFO     pid:12811 __main__:013:logMetrics E5 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:42:55,927 INFO     pid:12811 __main__:074:logMetrics E5 val      0.6770 loss
# 2024-02-28 15:42:55,927 INFO     pid:12811 __main__:100:logMetrics E5 val        57.2% correct, 0.2397 precision, 0.6808 recall, 0.3546 f1 score
# 2024-02-28 15:42:55,927 INFO     pid:12811 __main__:116:logMetrics E5 val_neg   0.4324 loss,  54.9% correct (71283 of 129778)
# 2024-02-28 15:42:55,928 INFO     pid:12811 __main__:133:logMetrics E5 val_pos   1.8484 loss,  68.1% correct (18446 of 27096)
# 2024-02-28 15:42:55,942 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E6 Training ----/19399, starting
# 2024-02-28 15:42:56,095 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E6 Training   32/19399, done at 2024-02-28 15:43:18, 0:00:22
# 2024-02-28 15:42:56,336 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E6 Training  256/19399, done at 2024-02-28 15:43:17, 0:00:21
# 2024-02-28 15:42:58,213 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E6 Training 2048/19399, done at 2024-02-28 15:43:16, 0:00:20
# 2024-02-28 15:43:12,523 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E6 Training 16384/19399, done at 2024-02-28 15:43:15, 0:00:19
# 2024-02-28 15:43:16,228 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E6 Training 19399/19399, done at 2024-02-28 15:43:16
# 2024-02-28 15:43:16,230 INFO     pid:12811 __main__:013:logMetrics E6 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:43:16,241 INFO     pid:12811 __main__:074:logMetrics E6 trn      0.6525 loss
# 2024-02-28 15:43:16,242 INFO     pid:12811 __main__:100:logMetrics E6 trn        63.2% correct, 0.2382 precision, 0.5904 recall, 0.3395 f1 score
# 2024-02-28 15:43:16,242 INFO     pid:12811 __main__:116:logMetrics E6 trn_neg   0.3876 loss,  64.0% correct (333580 of 521318)
# 2024-02-28 15:43:16,242 INFO     pid:12811 __main__:133:logMetrics E6 trn_pos   2.0413 loss,  59.0% correct (58705 of 99431)
# 2024-02-28 15:43:16,290 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E6 Validation  ----/4903, starting
# 2024-02-28 15:43:16,408 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E6 Validation    16/4903, done at 2024-02-28 15:43:20, 0:00:03
# 2024-02-28 15:43:16,443 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E6 Validation    64/4903, done at 2024-02-28 15:43:20, 0:00:03
# 2024-02-28 15:43:16,574 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E6 Validation   256/4903, done at 2024-02-28 15:43:19, 0:00:03
# 2024-02-28 15:43:17,153 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E6 Validation  1024/4903, done at 2024-02-28 15:43:20, 0:00:03
# 2024-02-28 15:43:19,525 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E6 Validation  4096/4903, done at 2024-02-28 15:43:20, 0:00:03
# 2024-02-28 15:43:20,335 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E6 Validation  4903/4903, done at 2024-02-28 15:43:20
# 2024-02-28 15:43:20,336 INFO     pid:12811 __main__:013:logMetrics E6 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:43:20,338 INFO     pid:12811 __main__:074:logMetrics E6 val      0.6809 loss
# 2024-02-28 15:43:20,339 INFO     pid:12811 __main__:100:logMetrics E6 val        61.0% correct, 0.2445 precision, 0.6007 recall, 0.3475 f1 score
# 2024-02-28 15:43:20,339 INFO     pid:12811 __main__:116:logMetrics E6 val_neg   0.4024 loss,  61.2% correct (79478 of 129778)
# 2024-02-28 15:43:20,339 INFO     pid:12811 __main__:133:logMetrics E6 val_pos   2.0148 loss,  60.1% correct (16276 of 27096)
# 2024-02-28 15:43:20,352 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E7 Training ----/19399, starting
# 2024-02-28 15:43:20,511 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E7 Training   32/19399, done at 2024-02-28 15:43:42, 0:00:22
# 2024-02-28 15:43:20,749 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E7 Training  256/19399, done at 2024-02-28 15:43:41, 0:00:20
# 2024-02-28 15:43:22,567 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E7 Training 2048/19399, done at 2024-02-28 15:43:40, 0:00:19
# 2024-02-28 15:43:37,482 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E7 Training 16384/19399, done at 2024-02-28 15:43:40, 0:00:20
# 2024-02-28 15:43:41,524 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E7 Training 19399/19399, done at 2024-02-28 15:43:41
# 2024-02-28 15:43:41,527 INFO     pid:12811 __main__:013:logMetrics E7 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:43:41,537 INFO     pid:12811 __main__:074:logMetrics E7 trn      0.6516 loss
# 2024-02-28 15:43:41,538 INFO     pid:12811 __main__:100:logMetrics E7 trn        63.2% correct, 0.2385 precision, 0.5919 recall, 0.3400 f1 score
# 2024-02-28 15:43:41,538 INFO     pid:12811 __main__:116:logMetrics E7 trn_neg   0.3870 loss,  64.0% correct (333424 of 521318)
# 2024-02-28 15:43:41,539 INFO     pid:12811 __main__:133:logMetrics E7 trn_pos   2.0390 loss,  59.2% correct (58849 of 99431)
# 2024-02-28 15:43:41,586 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E7 Validation  ----/4903, starting
# 2024-02-28 15:43:41,714 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E7 Validation    16/4903, done at 2024-02-28 15:43:44, 0:00:03
# 2024-02-28 15:43:41,751 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E7 Validation    64/4903, done at 2024-02-28 15:43:45, 0:00:03
# 2024-02-28 15:43:41,903 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E7 Validation   256/4903, done at 2024-02-28 15:43:45, 0:00:03
# 2024-02-28 15:43:42,441 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E7 Validation  1024/4903, done at 2024-02-28 15:43:45, 0:00:03
# 2024-02-28 15:43:44,823 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E7 Validation  4096/4903, done at 2024-02-28 15:43:45, 0:00:03
# 2024-02-28 15:43:45,596 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E7 Validation  4903/4903, done at 2024-02-28 15:43:45
# 2024-02-28 15:43:45,598 INFO     pid:12811 __main__:013:logMetrics E7 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:43:45,600 INFO     pid:12811 __main__:074:logMetrics E7 val      0.6799 loss
# 2024-02-28 15:43:45,601 INFO     pid:12811 __main__:100:logMetrics E7 val        62.6% correct, 0.2499 precision, 0.5821 recall, 0.3497 f1 score
# 2024-02-28 15:43:45,601 INFO     pid:12811 __main__:116:logMetrics E7 val_neg   0.3923 loss,  63.5% correct (82444 of 129778)
# 2024-02-28 15:43:45,601 INFO     pid:12811 __main__:133:logMetrics E7 val_pos   2.0573 loss,  58.2% correct (15772 of 27096)
# 2024-02-28 15:43:45,615 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E8 Training ----/19399, starting
# 2024-02-28 15:43:45,792 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E8 Training   32/19399, done at 2024-02-28 15:44:09, 0:00:23
# 2024-02-28 15:43:46,039 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E8 Training  256/19399, done at 2024-02-28 15:44:07, 0:00:21
# 2024-02-28 15:43:47,932 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E8 Training 2048/19399, done at 2024-02-28 15:44:06, 0:00:20
# 2024-02-28 15:44:02,995 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E8 Training 16384/19399, done at 2024-02-28 15:44:06, 0:00:20
# 2024-02-28 15:44:07,075 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E8 Training 19399/19399, done at 2024-02-28 15:44:07
# 2024-02-28 15:44:07,078 INFO     pid:12811 __main__:013:logMetrics E8 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:44:07,089 INFO     pid:12811 __main__:074:logMetrics E8 trn      0.6508 loss
# 2024-02-28 15:44:07,089 INFO     pid:12811 __main__:100:logMetrics E8 trn        63.3% correct, 0.2391 precision, 0.5925 recall, 0.3407 f1 score
# 2024-02-28 15:44:07,090 INFO     pid:12811 __main__:116:logMetrics E8 trn_neg   0.3865 loss,  64.0% correct (333830 of 521318)
# 2024-02-28 15:44:07,090 INFO     pid:12811 __main__:133:logMetrics E8 trn_pos   2.0369 loss,  59.2% correct (58912 of 99431)
# 2024-02-28 15:44:07,137 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E8 Validation  ----/4903, starting
# 2024-02-28 15:44:07,276 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E8 Validation    16/4903, done at 2024-02-28 15:44:10, 0:00:03
# 2024-02-28 15:44:07,309 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E8 Validation    64/4903, done at 2024-02-28 15:44:10, 0:00:03
# 2024-02-28 15:44:07,440 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E8 Validation   256/4903, done at 2024-02-28 15:44:10, 0:00:03
# 2024-02-28 15:44:07,989 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E8 Validation  1024/4903, done at 2024-02-28 15:44:10, 0:00:03
# 2024-02-28 15:44:10,333 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E8 Validation  4096/4903, done at 2024-02-28 15:44:10, 0:00:03
# 2024-02-28 15:44:11,109 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E8 Validation  4903/4903, done at 2024-02-28 15:44:11
# 2024-02-28 15:44:11,110 INFO     pid:12811 __main__:013:logMetrics E8 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:44:11,113 INFO     pid:12811 __main__:074:logMetrics E8 val      0.6815 loss
# 2024-02-28 15:44:11,114 INFO     pid:12811 __main__:100:logMetrics E8 val        61.9% correct, 0.2462 precision, 0.5845 recall, 0.3465 f1 score
# 2024-02-28 15:44:11,114 INFO     pid:12811 __main__:116:logMetrics E8 val_neg   0.3958 loss,  62.6% correct (81300 of 129778)
# 2024-02-28 15:44:11,115 INFO     pid:12811 __main__:133:logMetrics E8 val_pos   2.0496 loss,  58.4% correct (15837 of 27096)
# 2024-02-28 15:44:11,130 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E9 Training ----/19399, starting
# 2024-02-28 15:44:11,315 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E9 Training   32/19399, done at 2024-02-28 15:44:36, 0:00:25
# 2024-02-28 15:44:11,545 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E9 Training  256/19399, done at 2024-02-28 15:44:31, 0:00:20
# 2024-02-28 15:44:13,338 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E9 Training 2048/19399, done at 2024-02-28 15:44:30, 0:00:19
# 2024-02-28 15:44:29,145 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E9 Training 16384/19399, done at 2024-02-28 15:44:32, 0:00:21
# 2024-02-28 15:44:32,206 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E9 Training 19399/19399, done at 2024-02-28 15:44:32
# 2024-02-28 15:44:32,209 INFO     pid:12811 __main__:013:logMetrics E9 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:44:32,220 INFO     pid:12811 __main__:074:logMetrics E9 trn      0.6502 loss
# 2024-02-28 15:44:32,220 INFO     pid:12811 __main__:100:logMetrics E9 trn        63.4% correct, 0.2399 precision, 0.5934 recall, 0.3417 f1 score
# 2024-02-28 15:44:32,221 INFO     pid:12811 __main__:116:logMetrics E9 trn_neg   0.3860 loss,  64.1% correct (334380 of 521318)
# 2024-02-28 15:44:32,221 INFO     pid:12811 __main__:133:logMetrics E9 trn_pos   2.0350 loss,  59.3% correct (59004 of 99431)
# 2024-02-28 15:44:32,268 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E9 Validation  ----/4903, starting
# 2024-02-28 15:44:32,415 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E9 Validation    16/4903, done at 2024-02-28 15:44:36, 0:00:04
# 2024-02-28 15:44:32,455 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E9 Validation    64/4903, done at 2024-02-28 15:44:36, 0:00:04
# 2024-02-28 15:44:32,596 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E9 Validation   256/4903, done at 2024-02-28 15:44:36, 0:00:03
# 2024-02-28 15:44:33,177 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E9 Validation  1024/4903, done at 2024-02-28 15:44:36, 0:00:03
# 2024-02-28 15:44:35,567 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E9 Validation  4096/4903, done at 2024-02-28 15:44:36, 0:00:03
# 2024-02-28 15:44:36,397 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E9 Validation  4903/4903, done at 2024-02-28 15:44:36
# 2024-02-28 15:44:36,398 INFO     pid:12811 __main__:013:logMetrics E9 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:44:36,401 INFO     pid:12811 __main__:074:logMetrics E9 val      0.6784 loss
# 2024-02-28 15:44:36,401 INFO     pid:12811 __main__:100:logMetrics E9 val        58.8% correct, 0.2431 precision, 0.6566 recall, 0.3548 f1 score
# 2024-02-28 15:44:36,401 INFO     pid:12811 __main__:116:logMetrics E9 val_neg   0.4272 loss,  57.3% correct (74390 of 129778)
# 2024-02-28 15:44:36,402 INFO     pid:12811 __main__:133:logMetrics E9 val_pos   1.8818 loss,  65.7% correct (17790 of 27096)
# 2024-02-28 15:44:36,416 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E10 Training ----/19399, starting
# 2024-02-28 15:44:36,609 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E10 Training   32/19399, done at 2024-02-28 15:45:02, 0:00:25
# 2024-02-28 15:44:36,827 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E10 Training  256/19399, done at 2024-02-28 15:44:56, 0:00:19
# 2024-02-28 15:44:38,734 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E10 Training 2048/19399, done at 2024-02-28 15:44:57, 0:00:20
# 2024-02-28 15:44:54,340 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E10 Training 16384/19399, done at 2024-02-28 15:44:57, 0:00:21
# 2024-02-28 15:44:57,395 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E10 Training 19399/19399, done at 2024-02-28 15:44:57
# 2024-02-28 15:44:57,397 INFO     pid:12811 __main__:013:logMetrics E10 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:44:57,407 INFO     pid:12811 __main__:074:logMetrics E10 trn      0.6495 loss
# 2024-02-28 15:44:57,408 INFO     pid:12811 __main__:100:logMetrics E10 trn        63.4% correct, 0.2404 precision, 0.5943 recall, 0.3423 f1 score
# 2024-02-28 15:44:57,408 INFO     pid:12811 __main__:116:logMetrics E10 trn_neg   0.3856 loss,  64.2% correct (334554 of 521318)
# 2024-02-28 15:44:57,408 INFO     pid:12811 __main__:133:logMetrics E10 trn_pos   2.0331 loss,  59.4% correct (59094 of 99431)
# 2024-02-28 15:44:57,457 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E10 Validation  ----/4903, starting
# 2024-02-28 15:44:57,611 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E10 Validation    16/4903, done at 2024-02-28 15:45:01, 0:00:03
# 2024-02-28 15:44:57,651 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E10 Validation    64/4903, done at 2024-02-28 15:45:01, 0:00:04
# 2024-02-28 15:44:57,797 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E10 Validation   256/4903, done at 2024-02-28 15:45:01, 0:00:03
# 2024-02-28 15:44:58,354 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E10 Validation  1024/4903, done at 2024-02-28 15:45:01, 0:00:03
# 2024-02-28 15:45:00,760 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E10 Validation  4096/4903, done at 2024-02-28 15:45:01, 0:00:03
# 2024-02-28 15:45:02,259 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E10 Validation  4903/4903, done at 2024-02-28 15:45:02
# 2024-02-28 15:45:02,260 INFO     pid:12811 __main__:013:logMetrics E10 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:45:02,263 INFO     pid:12811 __main__:074:logMetrics E10 val      0.6805 loss
# 2024-02-28 15:45:02,263 INFO     pid:12811 __main__:100:logMetrics E10 val        56.8% correct, 0.2368 precision, 0.6760 recall, 0.3507 f1 score
# 2024-02-28 15:45:02,263 INFO     pid:12811 __main__:116:logMetrics E10 val_neg   0.4348 loss,  54.5% correct (70748 of 129778)
# 2024-02-28 15:45:02,264 INFO     pid:12811 __main__:133:logMetrics E10 val_pos   1.8572 loss,  67.6% correct (18316 of 27096)
# 2024-02-28 15:45:02,277 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E11 Training ----/19399, starting
# 2024-02-28 15:45:02,473 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E11 Training   32/19399, done at 2024-02-28 15:45:25, 0:00:23
# 2024-02-28 15:45:02,696 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E11 Training  256/19399, done at 2024-02-28 15:45:22, 0:00:19
# 2024-02-28 15:45:04,507 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E11 Training 2048/19399, done at 2024-02-28 15:45:22, 0:00:19
# 2024-02-28 15:45:20,649 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E11 Training 16384/19399, done at 2024-02-28 15:45:24, 0:00:21
# 2024-02-28 15:45:23,741 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E11 Training 19399/19399, done at 2024-02-28 15:45:23
# 2024-02-28 15:45:23,745 INFO     pid:12811 __main__:013:logMetrics E11 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:45:23,756 INFO     pid:12811 __main__:074:logMetrics E11 trn      0.6487 loss
# 2024-02-28 15:45:23,756 INFO     pid:12811 __main__:100:logMetrics E11 trn        63.5% correct, 0.2408 precision, 0.5952 recall, 0.3429 f1 score
# 2024-02-28 15:45:23,756 INFO     pid:12811 __main__:116:logMetrics E11 trn_neg   0.3852 loss,  64.2% correct (334705 of 521318)
# 2024-02-28 15:45:23,756 INFO     pid:12811 __main__:133:logMetrics E11 trn_pos   2.0304 loss,  59.5% correct (59181 of 99431)
# 2024-02-28 15:45:23,803 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E11 Validation  ----/4903, starting
# 2024-02-28 15:45:23,969 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E11 Validation    16/4903, done at 2024-02-28 15:45:27, 0:00:03
# 2024-02-28 15:45:24,005 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E11 Validation    64/4903, done at 2024-02-28 15:45:27, 0:00:03
# 2024-02-28 15:45:24,147 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E11 Validation   256/4903, done at 2024-02-28 15:45:27, 0:00:03
# 2024-02-28 15:45:24,726 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E11 Validation  1024/4903, done at 2024-02-28 15:45:27, 0:00:03
# 2024-02-28 15:45:27,809 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E11 Validation  4096/4903, done at 2024-02-28 15:45:28, 0:00:04
# 2024-02-28 15:45:28,647 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E11 Validation  4903/4903, done at 2024-02-28 15:45:28
# 2024-02-28 15:45:28,648 INFO     pid:12811 __main__:013:logMetrics E11 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:45:28,651 INFO     pid:12811 __main__:074:logMetrics E11 val      0.6834 loss
# 2024-02-28 15:45:28,651 INFO     pid:12811 __main__:100:logMetrics E11 val        62.4% correct, 0.2472 precision, 0.5759 recall, 0.3459 f1 score
# 2024-02-28 15:45:28,652 INFO     pid:12811 __main__:116:logMetrics E11 val_neg   0.3947 loss,  63.4% correct (82265 of 129778)
# 2024-02-28 15:45:28,652 INFO     pid:12811 __main__:133:logMetrics E11 val_pos   2.0658 loss,  57.6% correct (15604 of 27096)
# 2024-02-28 15:45:28,665 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E12 Training ----/19399, starting
# 2024-02-28 15:45:28,876 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E12 Training   32/19399, done at 2024-02-28 15:45:51, 0:00:22
# 2024-02-28 15:45:29,107 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E12 Training  256/19399, done at 2024-02-28 15:45:49, 0:00:20
# 2024-02-28 15:45:30,900 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E12 Training 2048/19399, done at 2024-02-28 15:45:48, 0:00:19
# 2024-02-28 15:45:46,444 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E12 Training 16384/19399, done at 2024-02-28 15:45:49, 0:00:20
# 2024-02-28 15:45:49,561 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E12 Training 19399/19399, done at 2024-02-28 15:45:49
# 2024-02-28 15:45:49,564 INFO     pid:12811 __main__:013:logMetrics E12 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:45:49,575 INFO     pid:12811 __main__:074:logMetrics E12 trn      0.6482 loss
# 2024-02-28 15:45:49,576 INFO     pid:12811 __main__:100:logMetrics E12 trn        63.6% correct, 0.2414 precision, 0.5926 recall, 0.3431 f1 score
# 2024-02-28 15:45:49,576 INFO     pid:12811 __main__:116:logMetrics E12 trn_neg   0.3847 loss,  64.5% correct (336176 of 521318)
# 2024-02-28 15:45:49,576 INFO     pid:12811 __main__:133:logMetrics E12 trn_pos   2.0296 loss,  59.3% correct (58921 of 99431)
# 2024-02-28 15:45:49,624 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E12 Validation  ----/4903, starting
# 2024-02-28 15:45:49,796 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E12 Validation    16/4903, done at 2024-02-28 15:45:53, 0:00:03
# 2024-02-28 15:45:49,831 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E12 Validation    64/4903, done at 2024-02-28 15:45:53, 0:00:03
# 2024-02-28 15:45:49,976 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E12 Validation   256/4903, done at 2024-02-28 15:45:53, 0:00:03
# 2024-02-28 15:45:50,549 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E12 Validation  1024/4903, done at 2024-02-28 15:45:53, 0:00:03
# 2024-02-28 15:45:53,915 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E12 Validation  4096/4903, done at 2024-02-28 15:45:54, 0:00:04
# 2024-02-28 15:45:54,734 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E12 Validation  4903/4903, done at 2024-02-28 15:45:54
# 2024-02-28 15:45:54,736 INFO     pid:12811 __main__:013:logMetrics E12 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:45:54,738 INFO     pid:12811 __main__:074:logMetrics E12 val      0.6807 loss
# 2024-02-28 15:45:54,738 INFO     pid:12811 __main__:100:logMetrics E12 val        58.6% correct, 0.2413 precision, 0.6509 recall, 0.3521 f1 score
# 2024-02-28 15:45:54,739 INFO     pid:12811 __main__:116:logMetrics E12 val_neg   0.4222 loss,  57.3% correct (74341 of 129778)
# 2024-02-28 15:45:54,739 INFO     pid:12811 __main__:133:logMetrics E12 val_pos   1.9190 loss,  65.1% correct (17636 of 27096)
# 2024-02-28 15:45:54,760 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E13 Training ----/19399, starting
# 2024-02-28 15:45:54,982 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E13 Training   32/19399, done at 2024-02-28 15:46:21, 0:00:26
# 2024-02-28 15:45:55,232 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E13 Training  256/19399, done at 2024-02-28 15:46:17, 0:00:22
# 2024-02-28 15:45:57,140 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E13 Training 2048/19399, done at 2024-02-28 15:46:15, 0:00:20
# 2024-02-28 15:46:13,021 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E13 Training 16384/19399, done at 2024-02-28 15:46:16, 0:00:21
# 2024-02-28 15:46:16,134 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E13 Training 19399/19399, done at 2024-02-28 15:46:16
# 2024-02-28 15:46:16,137 INFO     pid:12811 __main__:013:logMetrics E13 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:46:16,147 INFO     pid:12811 __main__:074:logMetrics E13 trn      0.6476 loss
# 2024-02-28 15:46:16,148 INFO     pid:12811 __main__:100:logMetrics E13 trn        63.6% correct, 0.2420 precision, 0.5955 recall, 0.3442 f1 score
# 2024-02-28 15:46:16,148 INFO     pid:12811 __main__:116:logMetrics E13 trn_neg   0.3844 loss,  64.4% correct (335887 of 521318)
# 2024-02-28 15:46:16,148 INFO     pid:12811 __main__:133:logMetrics E13 trn_pos   2.0278 loss,  59.5% correct (59211 of 99431)
# 2024-02-28 15:46:16,196 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E13 Validation  ----/4903, starting
# 2024-02-28 15:46:16,382 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E13 Validation    16/4903, done at 2024-02-28 15:46:20, 0:00:04
# 2024-02-28 15:46:16,417 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E13 Validation    64/4903, done at 2024-02-28 15:46:20, 0:00:03
# 2024-02-28 15:46:16,551 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E13 Validation   256/4903, done at 2024-02-28 15:46:19, 0:00:03
# 2024-02-28 15:46:17,109 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E13 Validation  1024/4903, done at 2024-02-28 15:46:19, 0:00:03
# 2024-02-28 15:46:20,181 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E13 Validation  4096/4903, done at 2024-02-28 15:46:20, 0:00:04
# 2024-02-28 15:46:21,004 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E13 Validation  4903/4903, done at 2024-02-28 15:46:21
# 2024-02-28 15:46:21,005 INFO     pid:12811 __main__:013:logMetrics E13 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:46:21,008 INFO     pid:12811 __main__:074:logMetrics E13 val      0.6792 loss
# 2024-02-28 15:46:21,008 INFO     pid:12811 __main__:100:logMetrics E13 val        59.1% correct, 0.2440 precision, 0.6520 recall, 0.3551 f1 score
# 2024-02-28 15:46:21,008 INFO     pid:12811 __main__:116:logMetrics E13 val_neg   0.4230 loss,  57.8% correct (75040 of 129778)
# 2024-02-28 15:46:21,008 INFO     pid:12811 __main__:133:logMetrics E13 val_pos   1.9063 loss,  65.2% correct (17666 of 27096)
# 2024-02-28 15:46:21,023 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E14 Training ----/19399, starting
# 2024-02-28 15:46:21,247 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E14 Training   32/19399, done at 2024-02-28 15:46:44, 0:00:23
# 2024-02-28 15:46:21,507 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E14 Training  256/19399, done at 2024-02-28 15:46:43, 0:00:22
# 2024-02-28 15:46:23,296 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E14 Training 2048/19399, done at 2024-02-28 15:46:40, 0:00:19
# 2024-02-28 15:46:38,910 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E14 Training 16384/19399, done at 2024-02-28 15:46:42, 0:00:20
# 2024-02-28 15:46:42,031 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E14 Training 19399/19399, done at 2024-02-28 15:46:42
# 2024-02-28 15:46:42,033 INFO     pid:12811 __main__:013:logMetrics E14 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:46:42,043 INFO     pid:12811 __main__:074:logMetrics E14 trn      0.6469 loss
# 2024-02-28 15:46:42,044 INFO     pid:12811 __main__:100:logMetrics E14 trn        63.8% correct, 0.2431 precision, 0.5958 recall, 0.3453 f1 score
# 2024-02-28 15:46:42,044 INFO     pid:12811 __main__:116:logMetrics E14 trn_neg   0.3839 loss,  64.6% correct (336838 of 521318)
# 2024-02-28 15:46:42,044 INFO     pid:12811 __main__:133:logMetrics E14 trn_pos   2.0261 loss,  59.6% correct (59241 of 99431)
# 2024-02-28 15:46:42,093 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E14 Validation  ----/4903, starting
# 2024-02-28 15:46:42,287 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E14 Validation    16/4903, done at 2024-02-28 15:46:45, 0:00:03
# 2024-02-28 15:46:42,327 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E14 Validation    64/4903, done at 2024-02-28 15:46:46, 0:00:03
# 2024-02-28 15:46:42,481 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E14 Validation   256/4903, done at 2024-02-28 15:46:46, 0:00:03
# 2024-02-28 15:46:43,037 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E14 Validation  1024/4903, done at 2024-02-28 15:46:45, 0:00:03
# 2024-02-28 15:46:46,072 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E14 Validation  4096/4903, done at 2024-02-28 15:46:46, 0:00:04
# 2024-02-28 15:46:46,931 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E14 Validation  4903/4903, done at 2024-02-28 15:46:46
# 2024-02-28 15:46:46,932 INFO     pid:12811 __main__:013:logMetrics E14 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:46:46,935 INFO     pid:12811 __main__:074:logMetrics E14 val      0.6849 loss
# 2024-02-28 15:46:46,936 INFO     pid:12811 __main__:100:logMetrics E14 val        54.8% correct, 0.2298 precision, 0.6881 recall, 0.3446 f1 score
# 2024-02-28 15:46:46,936 INFO     pid:12811 __main__:116:logMetrics E14 val_neg   0.4448 loss,  51.9% correct (67299 of 129778)
# 2024-02-28 15:46:46,936 INFO     pid:12811 __main__:133:logMetrics E14 val_pos   1.8349 loss,  68.8% correct (18645 of 27096)
# 2024-02-28 15:46:46,950 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E15 Training ----/19399, starting
# 2024-02-28 15:46:47,189 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E15 Training   32/19399, done at 2024-02-28 15:47:11, 0:00:24
# 2024-02-28 15:46:47,419 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E15 Training  256/19399, done at 2024-02-28 15:47:07, 0:00:20
# 2024-02-28 15:46:49,923 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E15 Training 2048/19399, done at 2024-02-28 15:47:13, 0:00:26
# 2024-02-28 15:47:04,817 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E15 Training 16384/19399, done at 2024-02-28 15:47:08, 0:00:20
# 2024-02-28 15:47:07,920 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E15 Training 19399/19399, done at 2024-02-28 15:47:07
# 2024-02-28 15:47:07,923 INFO     pid:12811 __main__:013:logMetrics E15 StockPCTLabelPredictLSTM_A3
# 2024-02-28 15:47:07,936 INFO     pid:12811 __main__:074:logMetrics E15 trn      0.6464 loss
# 2024-02-28 15:47:07,936 INFO     pid:12811 __main__:100:logMetrics E15 trn        63.8% correct, 0.2432 precision, 0.5951 recall, 0.3453 f1 score
# 2024-02-28 15:47:07,937 INFO     pid:12811 __main__:116:logMetrics E15 trn_neg   0.3836 loss,  64.7% correct (337158 of 521318)
# 2024-02-28 15:47:07,937 INFO     pid:12811 __main__:133:logMetrics E15 trn_pos   2.0241 loss,  59.5% correct (59173 of 99431)
# 2024-02-28 15:47:07,985 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E15 Validation  ----/4903, starting
# ...
# 2024-02-28 16:01:12,313 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E48 Training ----/19399, starting
# 2024-02-28 16:01:12,910 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E48 Training   32/19399, done at 2024-02-28 16:01:34, 0:00:21
# 2024-02-28 16:01:13,158 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E48 Training  256/19399, done at 2024-02-28 16:01:34, 0:00:21
# 2024-02-28 16:01:15,009 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E48 Training 2048/19399, done at 2024-02-28 16:01:33, 0:00:20
# 2024-02-28 16:01:32,287 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E48 Training 16384/19399, done at 2024-02-28 16:01:35, 0:00:22
# 2024-02-28 16:01:36,365 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E48 Training 19399/19399, done at 2024-02-28 16:01:36
# 2024-02-28 16:01:36,369 INFO     pid:12811 __main__:013:logMetrics E48 StockPCTLabelPredictLSTM_A3
# 2024-02-28 16:01:36,381 INFO     pid:12811 __main__:074:logMetrics E48 trn      0.6343 loss
# 2024-02-28 16:01:36,382 INFO     pid:12811 __main__:100:logMetrics E48 trn        65.8% correct, 0.2568 precision, 0.5984 recall, 0.3594 f1 score
# 2024-02-28 16:01:36,382 INFO     pid:12811 __main__:116:logMetrics E48 trn_neg   0.3755 loss,  67.0% correct (349138 of 521318)
# 2024-02-28 16:01:36,382 INFO     pid:12811 __main__:133:logMetrics E48 trn_pos   1.9909 loss,  59.8% correct (59504 of 99431)
# 2024-02-28 16:01:36,430 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E48 Validation  ----/4903, starting
# 2024-02-28 16:01:37,021 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E48 Validation    16/4903, done at 2024-02-28 16:01:41, 0:00:04
# 2024-02-28 16:01:37,056 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E48 Validation    64/4903, done at 2024-02-28 16:01:40, 0:00:03
# 2024-02-28 16:01:37,220 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E48 Validation   256/4903, done at 2024-02-28 16:01:41, 0:00:04
# 2024-02-28 16:01:37,793 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E48 Validation  1024/4903, done at 2024-02-28 16:01:40, 0:00:03
# 2024-02-28 16:01:40,193 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E48 Validation  4096/4903, done at 2024-02-28 16:01:40, 0:00:03
# 2024-02-28 16:01:41,359 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E48 Validation  4903/4903, done at 2024-02-28 16:01:41
# 2024-02-28 16:01:41,360 INFO     pid:12811 __main__:013:logMetrics E48 StockPCTLabelPredictLSTM_A3
# 2024-02-28 16:01:41,363 INFO     pid:12811 __main__:074:logMetrics E48 val      0.6876 loss
# 2024-02-28 16:01:41,363 INFO     pid:12811 __main__:100:logMetrics E48 val        61.2% correct, 0.2430 precision, 0.5899 recall, 0.3442 f1 score
# 2024-02-28 16:01:41,363 INFO     pid:12811 __main__:116:logMetrics E48 val_neg   0.4065 loss,  61.6% correct (79996 of 129778)
# 2024-02-28 16:01:41,364 INFO     pid:12811 __main__:133:logMetrics E48 val_pos   2.0341 loss,  59.0% correct (15983 of 27096)
# 2024-02-28 16:01:41,377 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E49 Training ----/19399, starting
# 2024-02-28 16:01:41,985 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E49 Training   32/19399, done at 2024-02-28 16:02:04, 0:00:22
# 2024-02-28 16:01:42,223 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E49 Training  256/19399, done at 2024-02-28 16:02:02, 0:00:20
# 2024-02-28 16:01:44,059 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E49 Training 2048/19399, done at 2024-02-28 16:02:01, 0:00:19
# 2024-02-28 16:01:58,675 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E49 Training 16384/19399, done at 2024-02-28 16:02:01, 0:00:19
# 2024-02-28 16:02:02,045 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E49 Training 19399/19399, done at 2024-02-28 16:02:02
# 2024-02-28 16:02:02,049 INFO     pid:12811 __main__:013:logMetrics E49 StockPCTLabelPredictLSTM_A3
# 2024-02-28 16:02:02,059 INFO     pid:12811 __main__:074:logMetrics E49 trn      0.6340 loss
# 2024-02-28 16:02:02,060 INFO     pid:12811 __main__:100:logMetrics E49 trn        66.0% correct, 0.2574 precision, 0.5970 recall, 0.3597 f1 score
# 2024-02-28 16:02:02,060 INFO     pid:12811 __main__:116:logMetrics E49 trn_neg   0.3753 loss,  67.1% correct (350060 of 521318)
# 2024-02-28 16:02:02,060 INFO     pid:12811 __main__:133:logMetrics E49 trn_pos   1.9903 loss,  59.7% correct (59363 of 99431)
# 2024-02-28 16:02:02,108 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E49 Validation  ----/4903, starting
# 2024-02-28 16:02:02,684 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E49 Validation    16/4903, done at 2024-02-28 16:02:07, 0:00:05
# 2024-02-28 16:02:02,727 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E49 Validation    64/4903, done at 2024-02-28 16:02:07, 0:00:04
# 2024-02-28 16:02:02,872 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E49 Validation   256/4903, done at 2024-02-28 16:02:06, 0:00:03
# 2024-02-28 16:02:03,429 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E49 Validation  1024/4903, done at 2024-02-28 16:02:06, 0:00:03
# 2024-02-28 16:02:05,775 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E49 Validation  4096/4903, done at 2024-02-28 16:02:06, 0:00:03
# 2024-02-28 16:02:06,812 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E49 Validation  4903/4903, done at 2024-02-28 16:02:06
# 2024-02-28 16:02:06,813 INFO     pid:12811 __main__:013:logMetrics E49 StockPCTLabelPredictLSTM_A3
# 2024-02-28 16:02:06,817 INFO     pid:12811 __main__:074:logMetrics E49 val      0.6893 loss
# 2024-02-28 16:02:06,817 INFO     pid:12811 __main__:100:logMetrics E49 val        60.1% correct, 0.2401 precision, 0.6046 recall, 0.3437 f1 score
# 2024-02-28 16:02:06,817 INFO     pid:12811 __main__:116:logMetrics E49 val_neg   0.4102 loss,  60.1% correct (77940 of 129778)
# 2024-02-28 16:02:06,818 INFO     pid:12811 __main__:133:logMetrics E49 val_pos   2.0260 loss,  60.5% correct (16381 of 27096)
# 2024-02-28 16:02:06,832 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E50 Training ----/19399, starting
# 2024-02-28 16:02:07,448 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E50 Training   32/19399, done at 2024-02-28 16:02:28, 0:00:21
# 2024-02-28 16:02:07,686 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E50 Training  256/19399, done at 2024-02-28 16:02:28, 0:00:20
# 2024-02-28 16:02:09,508 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E50 Training 2048/19399, done at 2024-02-28 16:02:27, 0:00:19
# 2024-02-28 16:02:25,401 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E50 Training 16384/19399, done at 2024-02-28 16:02:28, 0:00:21
# 2024-02-28 16:02:31,000 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E50 Training 19399/19399, done at 2024-02-28 16:02:31
# 2024-02-28 16:02:31,004 INFO     pid:12811 __main__:013:logMetrics E50 StockPCTLabelPredictLSTM_A3
# 2024-02-28 16:02:31,013 INFO     pid:12811 __main__:074:logMetrics E50 trn      0.6338 loss
# 2024-02-28 16:02:31,014 INFO     pid:12811 __main__:100:logMetrics E50 trn        65.9% correct, 0.2574 precision, 0.5975 recall, 0.3598 f1 score
# 2024-02-28 16:02:31,014 INFO     pid:12811 __main__:116:logMetrics E50 trn_neg   0.3752 loss,  67.1% correct (349943 of 521318)
# 2024-02-28 16:02:31,014 INFO     pid:12811 __main__:133:logMetrics E50 trn_pos   1.9900 loss,  59.8% correct (59413 of 99431)
# 2024-02-28 16:02:31,069 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E50 Validation  ----/4903, starting
# 2024-02-28 16:02:31,652 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E50 Validation    16/4903, done at 2024-02-28 16:02:34, 0:00:03
# 2024-02-28 16:02:31,690 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E50 Validation    64/4903, done at 2024-02-28 16:02:35, 0:00:03
# 2024-02-28 16:02:31,828 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E50 Validation   256/4903, done at 2024-02-28 16:02:35, 0:00:03
# 2024-02-28 16:02:32,375 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E50 Validation  1024/4903, done at 2024-02-28 16:02:35, 0:00:03
# 2024-02-28 16:02:34,717 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E50 Validation  4096/4903, done at 2024-02-28 16:02:35, 0:00:03
# 2024-02-28 16:02:35,752 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E50 Validation  4903/4903, done at 2024-02-28 16:02:35
# 2024-02-28 16:02:35,754 INFO     pid:12811 __main__:013:logMetrics E50 StockPCTLabelPredictLSTM_A3
# 2024-02-28 16:02:35,757 INFO     pid:12811 __main__:074:logMetrics E50 val      0.6868 loss
# 2024-02-28 16:02:35,758 INFO     pid:12811 __main__:100:logMetrics E50 val        57.0% correct, 0.2380 precision, 0.6759 recall, 0.3521 f1 score
# 2024-02-28 16:02:35,758 INFO     pid:12811 __main__:116:logMetrics E50 val_neg   0.4511 loss,  54.8% correct (71161 of 129778)
# 2024-02-28 16:02:35,758 INFO     pid:12811 __main__:133:logMetrics E50 val_pos   1.8157 loss,  67.6% correct (18313 of 27096)
# 2024-02-28 16:02:35,772 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E51 Training ----/19399, starting
# 2024-02-28 16:02:36,405 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E51 Training   32/19399, done at 2024-02-28 16:02:58, 0:00:21
# 2024-02-28 16:02:36,643 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E51 Training  256/19399, done at 2024-02-28 16:02:57, 0:00:20
# 2024-02-28 16:02:38,459 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E51 Training 2048/19399, done at 2024-02-28 16:02:56, 0:00:19
# 2024-02-28 16:02:58,297 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E51 Training 16384/19399, done at 2024-02-28 16:03:02, 0:00:25
# 2024-02-28 16:03:04,024 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E51 Training 19399/19399, done at 2024-02-28 16:03:04
# 2024-02-28 16:03:04,028 INFO     pid:12811 __main__:013:logMetrics E51 StockPCTLabelPredictLSTM_A3
# 2024-02-28 16:03:04,039 INFO     pid:12811 __main__:074:logMetrics E51 trn      0.6335 loss
# 2024-02-28 16:03:04,039 INFO     pid:12811 __main__:100:logMetrics E51 trn        66.0% correct, 0.2576 precision, 0.5975 recall, 0.3600 f1 score
# 2024-02-28 16:03:04,040 INFO     pid:12811 __main__:116:logMetrics E51 trn_neg   0.3750 loss,  67.2% correct (350135 of 521318)
# 2024-02-28 16:03:04,040 INFO     pid:12811 __main__:133:logMetrics E51 trn_pos   1.9888 loss,  59.7% correct (59409 of 99431)
# 2024-02-28 16:03:04,092 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E51 Validation  ----/4903, starting
# 2024-02-28 16:03:04,692 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E51 Validation    16/4903, done at 2024-02-28 16:03:07, 0:00:03
# 2024-02-28 16:03:04,725 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E51 Validation    64/4903, done at 2024-02-28 16:03:08, 0:00:03
# 2024-02-28 16:03:04,861 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E51 Validation   256/4903, done at 2024-02-28 16:03:08, 0:00:03
# 2024-02-28 16:03:05,432 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E51 Validation  1024/4903, done at 2024-02-28 16:03:08, 0:00:03
# 2024-02-28 16:03:07,738 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E51 Validation  4096/4903, done at 2024-02-28 16:03:08, 0:00:03
# 2024-02-28 16:03:08,814 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E51 Validation  4903/4903, done at 2024-02-28 16:03:08
# 2024-02-28 16:03:08,815 INFO     pid:12811 __main__:013:logMetrics E51 StockPCTLabelPredictLSTM_A3
# 2024-02-28 16:03:08,818 INFO     pid:12811 __main__:074:logMetrics E51 val      0.6856 loss
# 2024-02-28 16:03:08,819 INFO     pid:12811 __main__:100:logMetrics E51 val        57.5% correct, 0.2371 precision, 0.6592 recall, 0.3488 f1 score
# 2024-02-28 16:03:08,819 INFO     pid:12811 __main__:116:logMetrics E51 val_neg   0.4357 loss,  55.7% correct (72306 of 129778)
# 2024-02-28 16:03:08,820 INFO     pid:12811 __main__:133:logMetrics E51 val_pos   1.8823 loss,  65.9% correct (17863 of 27096)
# 2024-02-28 16:03:08,834 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E52 Training ----/19399, starting
# 2024-02-28 16:03:09,489 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E52 Training   32/19399, done at 2024-02-28 16:03:33, 0:00:23
# 2024-02-28 16:03:09,733 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E52 Training  256/19399, done at 2024-02-28 16:03:30, 0:00:21
# 2024-02-28 16:03:11,544 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E52 Training 2048/19399, done at 2024-02-28 16:03:29, 0:00:19
# 2024-02-28 16:03:32,493 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E52 Training 16384/19399, done at 2024-02-28 16:03:36, 0:00:27
# 2024-02-28 16:03:38,406 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E52 Training 19399/19399, done at 2024-02-28 16:03:38
# 2024-02-28 16:03:38,411 INFO     pid:12811 __main__:013:logMetrics E52 StockPCTLabelPredictLSTM_A3
# 2024-02-28 16:03:38,435 INFO     pid:12811 __main__:074:logMetrics E52 trn      0.6332 loss
# 2024-02-28 16:03:38,437 INFO     pid:12811 __main__:100:logMetrics E52 trn        66.1% correct, 0.2587 precision, 0.5991 recall, 0.3614 f1 score
# 2024-02-28 16:03:38,437 INFO     pid:12811 __main__:116:logMetrics E52 trn_neg   0.3748 loss,  67.3% correct (350640 of 521318)
# 2024-02-28 16:03:38,437 INFO     pid:12811 __main__:133:logMetrics E52 trn_pos   1.9878 loss,  59.9% correct (59568 of 99431)
# 2024-02-28 16:03:38,501 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E52 Validation  ----/4903, starting
# 2024-02-28 16:03:39,145 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E52 Validation    16/4903, done at 2024-02-28 16:03:43, 0:00:03
# 2024-02-28 16:03:39,188 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E52 Validation    64/4903, done at 2024-02-28 16:03:43, 0:00:04
# 2024-02-28 16:03:39,327 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E52 Validation   256/4903, done at 2024-02-28 16:03:42, 0:00:03
# 2024-02-28 16:03:39,906 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E52 Validation  1024/4903, done at 2024-02-28 16:03:42, 0:00:03
# 2024-02-28 16:03:42,264 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E52 Validation  4096/4903, done at 2024-02-28 16:03:42, 0:00:03
# 2024-02-28 16:03:43,440 INFO     pid:12811 MyPyUtil.util:181:enumerateWithEstimate E52 Validation  4903/4903, done at 2024-02-28 16:03:43
# 2024-02-28 16:03:43,441 INFO     pid:12811 __main__:013:logMetrics E52 StockPCTLabelPredictLSTM_A3
# 2024-02-28 16:03:43,444 INFO     pid:12811 __main__:074:logMetrics E52 val      0.6893 loss
# 2024-02-28 16:03:43,445 INFO     pid:12811 __main__:100:logMetrics E52 val        62.3% correct, 0.2457 precision, 0.5724 recall, 0.3438 f1 score
# 2024-02-28 16:03:43,445 INFO     pid:12811 __main__:116:logMetrics E52 val_neg   0.3967 loss,  63.3% correct (82170 of 129778)
# 2024-02-28 16:03:43,445 INFO     pid:12811 __main__:133:logMetrics E52 val_pos   2.0908 loss,  57.2% correct (15509 of 27096)
# 2024-02-28 16:03:43,468 INFO     pid:12811 MyPyUtil.util:146:enumerateWithEstimate E53 Training ----/19399, starting
# 2024-02-28 16:03:44,150 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E53 Training   32/19399, done at 2024-02-28 16:04:15, 0:00:31
# 2024-02-28 16:03:44,394 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E53 Training  256/19399, done at 2024-02-28 16:04:06, 0:00:22
# 2024-02-28 16:03:46,173 INFO     pid:12811 MyPyUtil.util:166:enumerateWithEstimate E53 Training 2048/19399, done at 2024-02-28 16:04:03, 0:00:19
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# # best results after experiments
# """
# CrossEntropy is better than Focal
# CrossEntropy(best result: 0.3921) => lr = 0.01
# Focal       (best result: 0.3865) => lr = 0.1 , num_fc_layers = 1
# """
# search_space = {
#     "loss_fn": tune.grid_search(["CrossEntropy", "Focal"]),
#     "lr": tune.grid_search([0.01, 0.1]),  # , 0.01, 0.1, 0.08, 0.12]
#     "momentum": tune.uniform(
#         0.001, 0.2
#     ),  # tune.grid_search([0.11646759543664197]),  # tune.uniform(0.1, 0.9),
#     "optim_type": tune.grid_search([2]),  # 1: Adam, 2: SGD  => Adam bad result
#     "weight decay": tune.grid_search([0.00001]),  # best value
#     "num_layers": tune.grid_search([4]),  # [1, 2, 4, 8] best value = 3 or 4
#     "hidden_size": tune.grid_search([32, 128]),  # [8, 16, 32, 64, 128]
#     "num_fc_layers": tune.grid_search([1]),  # 1, 2, 3]),
#     "activation_type": tune.grid_search(
#         [2]
#     ),  # 1: ReLU(),  2: Sigmoid(),  3: Tanh()  => meaningless num_fc_layers == 1
# }

# turning_parameters = []
# total_configs = 1
# for k, v in search_space.items():
#     if (
#         type(v).__name__ == "dict"
#         and list(v.keys())[0] == "grid_search"
#         and len(list(v.values())[0]) > 1
#     ):
#         turning_parameters.append(k)
#         total_configs *= len(list(v.values())[0])
# print(turning_parameters)
# print(f"Total count of configs = {total_configs}")
# Out:
# ['loss_fn', 'lr', 'hidden_size']
# Total count of configs = 8

# %%
# import warnings


# warnings.filterwarnings("ignore", category=Warning)

# time_str = datetime.now().strftime("%Y-%m-%d_%H.%M.%S")
# log_dir = f"{log_dir_base}/{time_str}"
# os.mkdir(log_dir)

# XYData, (alpha, class_weight) = prepare_XYData_PCA(return_period)
# tuner = tune.Tuner(
#     tune.with_resources(
#         tune.with_parameters(
#             ray_train_task,
#             data=XYData,
#             alpha=alpha,
#             class_weight=class_weight,
#             time_str=time_str,
#         ),
#         resources={"cpu": 0.125, "gpu": 0.125},
#     ),
#     tune_config=tune.TuneConfig(
#         metric="f1_score",
#         mode="max",
#     ),
#     param_space=search_space,
# )
# results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-02-28 14:26:45</td></tr>
# <tr><td>Running for: </td><td>00:19:55.40        </td></tr>
# <tr><td>Memory:      </td><td>16.5/31.1 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/32 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                </th><th>status  </th><th>loc                </th><th style="text-align: right;">  activation_type</th><th style="text-align: right;">  hidden_size</th><th>loss_fn     </th><th style="text-align: right;">  lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">  num_fc_layers</th><th style="text-align: right;">  num_layers</th><th style="text-align: right;">  optim_type</th><th style="text-align: right;">  weight decay</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">     loss</th><th style="text-align: right;">  f1_score</th><th style="text-align: right;">  precision</th></tr>
# </thead>
# <tbody>
# <tr><td>ray_train_task_abd64_00000</td><td>RUNNING </td><td>192.168.0.125:29566</td><td style="text-align: right;">                2</td><td style="text-align: right;">           32</td><td>CrossEntropy</td><td style="text-align: right;">0.01</td><td style="text-align: right;"> 0.0755335</td><td style="text-align: right;">              1</td><td style="text-align: right;">           4</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">     8</td><td style="text-align: right;">         1075.67</td><td style="text-align: right;">0.651763 </td><td style="text-align: right;">  0.354097</td><td style="text-align: right;">   0.248079</td></tr>
# <tr><td>ray_train_task_abd64_00001</td><td>RUNNING </td><td>192.168.0.125:29567</td><td style="text-align: right;">                2</td><td style="text-align: right;">          128</td><td>CrossEntropy</td><td style="text-align: right;">0.01</td><td style="text-align: right;"> 0.190192 </td><td style="text-align: right;">              1</td><td style="text-align: right;">           4</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">     8</td><td style="text-align: right;">         1074.66</td><td style="text-align: right;">0.652532 </td><td style="text-align: right;">  0.346896</td><td style="text-align: right;">   0.235868</td></tr>
# <tr><td>ray_train_task_abd64_00002</td><td>RUNNING </td><td>192.168.0.125:29568</td><td style="text-align: right;">                2</td><td style="text-align: right;">           32</td><td>Focal       </td><td style="text-align: right;">0.01</td><td style="text-align: right;"> 0.146667 </td><td style="text-align: right;">              1</td><td style="text-align: right;">           4</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">     8</td><td style="text-align: right;">         1086.64</td><td style="text-align: right;">0.0451431</td><td style="text-align: right;">  0.357162</td><td style="text-align: right;">   0.242438</td></tr>
# <tr><td>ray_train_task_abd64_00003</td><td>RUNNING </td><td>192.168.0.125:29569</td><td style="text-align: right;">                2</td><td style="text-align: right;">          128</td><td>Focal       </td><td style="text-align: right;">0.01</td><td style="text-align: right;"> 0.120133 </td><td style="text-align: right;">              1</td><td style="text-align: right;">           4</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">     8</td><td style="text-align: right;">         1090   </td><td style="text-align: right;">0.0450024</td><td style="text-align: right;">  0.355567</td><td style="text-align: right;">   0.238966</td></tr>
# <tr><td>ray_train_task_abd64_00004</td><td>RUNNING </td><td>192.168.0.125:29570</td><td style="text-align: right;">                2</td><td style="text-align: right;">           32</td><td>CrossEntropy</td><td style="text-align: right;">0.1 </td><td style="text-align: right;"> 0.0320477</td><td style="text-align: right;">              1</td><td style="text-align: right;">           4</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">     8</td><td style="text-align: right;">         1072.28</td><td style="text-align: right;">0.643219 </td><td style="text-align: right;">  0.344336</td><td style="text-align: right;">   0.237176</td></tr>
# <tr><td>ray_train_task_abd64_00005</td><td>RUNNING </td><td>192.168.0.125:29571</td><td style="text-align: right;">                2</td><td style="text-align: right;">          128</td><td>CrossEntropy</td><td style="text-align: right;">0.1 </td><td style="text-align: right;"> 0.0320429</td><td style="text-align: right;">              1</td><td style="text-align: right;">           4</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">     8</td><td style="text-align: right;">         1074.77</td><td style="text-align: right;">0.642164 </td><td style="text-align: right;">  0.347217</td><td style="text-align: right;">   0.228749</td></tr>
# <tr><td>ray_train_task_abd64_00006</td><td>RUNNING </td><td>192.168.0.125:29572</td><td style="text-align: right;">                2</td><td style="text-align: right;">           32</td><td>Focal       </td><td style="text-align: right;">0.1 </td><td style="text-align: right;"> 0.0125586</td><td style="text-align: right;">              1</td><td style="text-align: right;">           4</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">     8</td><td style="text-align: right;">         1084.66</td><td style="text-align: right;">0.0443438</td><td style="text-align: right;">  0.353592</td><td style="text-align: right;">   0.234186</td></tr>
# <tr><td>ray_train_task_abd64_00007</td><td>RUNNING </td><td>192.168.0.125:29573</td><td style="text-align: right;">                2</td><td style="text-align: right;">          128</td><td>Focal       </td><td style="text-align: right;">0.1 </td><td style="text-align: right;"> 0.173369 </td><td style="text-align: right;">              1</td><td style="text-align: right;">           4</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">     8</td><td style="text-align: right;">         1088.81</td><td style="text-align: right;">0.0444789</td><td style="text-align: right;">  0.354363</td><td style="text-align: right;">   0.252015</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2024-02-28 14:26:45,111	WARNING tune.py:186 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2024-02-28 14:26:55,134	INFO tune.py:1042 -- Total run time: 1205.44 seconds (1195.40 seconds for the tuning loop).
# 2024-02-28 14:26:55,136	WARNING tune.py:1057 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: Tuner.restore(path="/home/skchen/ray_results/ray_train_task_2024-02-28_14-06-49", trainable=...)
