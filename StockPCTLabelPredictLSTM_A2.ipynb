# %%
# %matplotlib inline
import torch
import random
import pandas as pd
import numpy as np
import pandas_datareader.data as web
from matplotlib import pyplot
import seaborn as sns
import os

#Plotting 
from pandas.plotting import scatter_matrix

#Libraries for Statistical Models
import statsmodels.api as sm

#logging
from MyPyUtil.logconf import logging
log = logging.getLogger(__name__)
# log.setLevel(logging.ERROR)
log.setLevel(logging.INFO)
# log.setLevel(logging.WARN)
# log.setLevel(logging.DEBUG)


#Diable the warnings
import warnings
warnings.filterwarnings('ignore')

pd.options.display.max_columns = None
pd.options.display.expand_frame_repr = False
pd.options.display.float_format = '{:.3f}'.format

torch.seed = 42
random.seed(42)
np.random.seed(42)

# %run 'nb_utils.ipynb'
task_name = get_filename_of_ipynb()
print(task_name)
data_dir = f'{os.getcwd()}/data/'
log_dir_base = f'{os.getcwd()}/runs/{task_name}'
if os.path.exists(log_dir_base) == False:
    os.mkdir(log_dir_base)
log_dir = log_dir_base
print(f'{data_dir}\n{log_dir}')
# Out:
# StockPCTLabelPredictLSTM_A2
# /mnt/AIWorkSpace/work/fin-ml/data/
# /mnt/AIWorkSpace/work/fin-ml/runs/StockPCTLabelPredictLSTM_A2

# %%
# hyperparameters turning
from ray import tune, train, ray
from ray.tune.schedulers import ASHAScheduler

ray.init(log_to_driver=False)
# Out:
# 2024-02-20 11:03:09,601	INFO worker.py:1715 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.8.18', ray_version='2.9.1', ray_commit='cfbf98c315cfb2710c56039a3c96477d196de049', protocol_version=None)

# %%
stk_symbols = [
    "AAPL",
    "MSFT",
    "AMZN",
    "NVDA",
    "GOOGL",
    "GOOG",
    "META",
    "TSLA",
    "UNH",
    "LLY",
    "JPM",
    "XOM",
    "JNJ",
    "V",
    "PG",
    "AVGO",
    "MA",
    "HD",
    "CVX",
    "MRK",
    "ABBV",
    "PEP",
    "COST",
    "ADBE",
    "KO",
    "CSCO",
    "WMT",
    "TMO",
    "MCD",
    "PFE",
    "CRM",
    "BAC",
    "ACN",
    "CMCSA",
    "LIN",
    "NFLX",
    "ABT",
    "ORCL",
    "DHR",
    "AMD",
    "WFC",
    "DIS",
    "TXN",
    "PM",
    "VZ",
    "INTU",
    "COP",
    "CAT",
    "AMGN",
    "NEE",
    "INTC",
    "UNP",
    "LOW",
    "IBM",
    "BMY",
    "SPGI",
    "RTX",
    "HON",
    "BA",
    "UPS",
    "GE",
    "QCOM",
    "AMAT",
    "NKE",
    "PLD",
    "NOW",
    "BKNG",
    "SBUX",
    "MS",
    "ELV",
    "MDT",
    "GS",
    "DE",
    "ADP",
    "LMT",
    "TJX",
    "T",
    "BLK",
    "ISRG",
    "MDLZ",
    "GILD",
    "MMC",
    "AXP",
    "SYK",
    "REGN",
    "VRTX",
    "ETN",
    "LRCX",
    "ADI",
    "SCHW",
    "CVS",
    "ZTS",
    "CI",
    "CB",
    "AMT",
    "SLB",
    "C",
    "BDX",
    "MO",
    "PGR",
    "TMUS",
    "FI",
    "SO",
    "EOG",
    "BSX",
    "CME",
    "EQIX",
    "MU",
    "DUK",
    "PANW",
    "PYPL",
    "AON",
    "SNPS",
    "ITW",
    "KLAC",
    "LULU",
    "ICE",
    "APD",
    "SHW",
    "CDNS",
    "CSX",
    "NOC",
    "CL",
    "MPC",
    "HUM",
    "FDX",
    "WM",
    "MCK",
    "TGT",
    "ORLY",
    "HCA",
    "FCX",
    "EMR",
    "PXD",
    "MMM",
    "MCO",
    "ROP",
    "CMG",
    "PSX",
    "MAR",
    "PH",
    "APH",
    "GD",
    "USB",
    "NXPI",
    "AJG",
    "NSC",
    "PNC",
    "VLO",
    "GBP",
    "F",
    "MSI",
    "GM",
    "TT",
    "EW",
    "CARR",
    "AZO",
    "ADSK",
    "TDG",
    "ANET",
    "SRE",
    "ECL",
    "OXY",
    "PCAR",
    "ADM",
    "MNST",
    "KMB",
    "PSA",
    "CCI",
    "CHTR",
    "MCHP",
    "MSCI",
    "CTAS",
    "WMB",
    "AIG",
    "STZ",
    "HES",
    "NUE",
    "ROST",
    "AFL",
    "AEP",
    "IDXX",
    "D",
    "TEL",
    "JCI",
    "MET",
    "GIS",
    "IQV",
    "EXC",
    "WELL",
    "DXCM",
    "HLT",
    "ON",
    "COF",
    "PAYX",
    "TFC",
    "USD",
    "BIIB",
    "O",
    "FTNT",
    "DOW",
    "TRV",
    "DLR",
    "MRNA",
    "CPRT",
    "ODFL",
    "DHI",
    "YUM",
    "SPG",
    "CTSH",
    "AME",
    "BKR",
    "SYY",
    "A",
    "CTVA",
    "CNC",
    "EL",
    "AMP",
    # "CEG",  # PCT <= -0.05,  size = 0
    "HAL",
    # "OTIS",  # PCT <= -0.05,  size = 0
    "ROK",
    "PRU",
    "DD",
    "KMI",
    "VRSK",
    "LHX",
    "DG",
    "FIS",
    "CMI",
    "CSGP",
    "FAST",
    "PPG",
    "GPN",
    "GWW",
    "HSY",
    "BK",
    "XEL",
    "DVN",
    "EA",
    "NEM",
    "ED",
    "URI",
    "VICI",
    "PEG",
    "KR",
    "RSG",
    "LEN",
    "PWR",
    "WST",
    "COR",
    "OKE",
    "VMC",
    "KDP",
    "WBD",
    "ACGL",
    "ALL",
    "IR",
    "CDW",
    "FANG",
    "MLM",
    "PCG",
    "DAL",
    "EXR",
    "FTV",
    "AWK",
    "IT",
    "KHC",
    # "GEHC",  # PCT <= -0.05,  size = 0
    "WEC",
    "HPQ",
    "EIX",
    "CBRE",
    "APTV",
    "ANSS",
    "MTD",
    "DLTR",
    "AVB",
    "ILMN",
    "ALGN",
    "LYB",
    "TROW",
    "GLW",
    "EFX",
    "WY",
    "ZBH",
    "XYL",
    "SBAC",
    "RMD",
    "TSCO",
    "EBAY",
    "KEYS",
    "CHD",
    "STT",
    "DFS",
    "HIG",
    "ALB",
    "STE",
    "ES",
    "TTWO",
    "MPWR",
    "CAH",
    "EQR",
    "RCL",
    "WTW",
    "HPE",
    "DTE",
    "GPC",
    "BR",
    "ULTA",
    "FICO",
    "CTRA",
    "BAX",
    "AEE",
    "MTB",
    "MKC",
    "ETR",
    "WAB",
    "DOV",
    "FE",
    "RJF",
    "INVH",
    "FLT",
    "CLX",
    "TDY",
    "TRGP",
    "DRI",
    "LH",
    "HOLX",
    "VRSN",
    "MOH",
    "LUV",
    "PPL",
    "ARE",
    "NVR",
    "COO",
    "WBA",
    "PHM",
    "NDAQ",
    "HWM",
    "RF",
    "CNP",
    "IRM",
    "LVS",
    "FITB",
    "EXPD",
    "VTR",
    "FSLR",
    "PFG",
    "BRO",
    "J",
    "IEX",
    "BG",
    "ATO",
    "FDS",
    "ENPH",
    "MAA",
    "CMS",
    "IFF",
    "BALL",
    "SWKS",
    "CINF",
    "NTAP",
    "STLD",
    "UAL",
    "WAT",
    "OMC",
    "TER",
    "CCL",
    "JBHT",
    "MRO",
    "TYL",
    "HBAN",
    "K",
    "GRMN",
    "CBOE",
    "NTRS",
    "TSN",
    "AKAM",
    "EG",
    "ESS",
    "EQT",
    "TXT",
    "EXPE",
    "SJM",
    "PTC",
    "DGX",
    "AVY",
    "RVTY",
    "BBY",
    "CF",
    "CAG",
    "EPAM",
    "AMCR",
    "LW",
    "PAYC",
    "SNA",
    "AXON",
    "POOL",
    "SYF",
    "SWK",
    "ZBRA",
    "DPZ",
    "PKG",
    "CFG",
    "LDOS",
    "VTRS",
    "PODD",
    "LKQ",
    "MOS",
    "APA",
    "EVRG",
    "TRMB",
    "MGM",
    "NDSN",
    "WDC",
    "MAS",
    "LNT",
    "IPG",
    "MTCH",
    "STX",
    "KMX",
    "TECH",
    "WRB",
    "LYV",
    "IP",
    "UDR",
    "AES",
    "CE",
    "INCY",
    "L",
    "TAP",
    "GEN",
    "CPT",
    "KIM",
    "JKHY",
    "HRL",
    "HST",
    "FMC",
    "CZR",
    "PEAK",
    "CDAY",
    "PNR",
    "NI",
    "CHRW",
    "HSIC",
    "CRL",
    "REG",
    "QRVO",
    "TFX",
    "KEY",
    "GL",
    "EMN",
    "WYNN",
    "ALLE",
    "AAL",
    "FFIV",
    "BWA",
    "BXP",
    "MKTX",
    "ROL",
    "JNPR",
    "PNW",
    "ETSY",
    "BLDR",
    "FOXA",
    "AOS",
    "HAS",
    "HII",
    "NRG",
    "CPB",
    "UHS",
    "BIO",
    "WRK",
    "RHI",
    "CTLT",
    "XRAY",
    "BBWI",
    "NWSA",
    "TPR",
    "PARA",
    "WHR",
    "BEN",
    "AIZ",
    "NCLH",
    "GNRC",
    "FRT",
    "IVZ",
    "VFC",
    "CMA",
    "DVA",
    "JBL",
    "HUBB",
    "ZION",
    "UBER",
    "MHK",
    "RL",
    "FOX",
    "BX",
    "ABNB",
    "NWS",
]
# stk_symbols = [
#     "AAPL",
#     "MSFT",
#     "AMZN",
#     "NVDA",
#     "GOOGL",
#     "TSLA",
#     "META",
#     "GOOG",
#     "ADBE",
#     "NFLX",
#     "CSCO",
#     "INTC",
#     "INTU",
#     "CMCSA",
#     "TXN",
#     "AMAT",
#     "ADSK",
#     "AMD",
#     "QCOM",
#     "MU",
# ]

# stk_symbols = [
#     "AAPL",
#     "MSFT",
#     "AMZN",
#     "NVDA",
#     "GOOGL",
#     "TSLA",
#     "META",
#     "GOOG",
# ]

# %%
from datetime import datetime
import yfinance as yfin
from MyPyUtil.util import is_contained


def load_stk_data(stk_symbols, start, end, empty_vol_threshold):
    ticks_data = []
    for symbol in stk_symbols:
        stk_file = f"{data_dir}{symbol}_{start.strftime('%Y%m%d')}-{end.strftime('%Y%m%d')}.csv"
        bLoad = False
        if os.path.isfile(stk_file):
            try:
                _stk_data = pd.read_csv(stk_file).set_index("Date")
                bLoad = True
                print(f"read {stk_file} completely!")
            except:
                None
        if bLoad == False:
            # _stk_data = web.get_data_yahoo(stk_tickers, start, end)
            _stk_data = yfin.download([symbol], start, end).dropna()
            _stk_data.to_csv(stk_file)
            print(f"download {symbol} from yfin and write to {stk_file} completely!")

        statistics = _stk_data.describe()
        if is_contained(statistics, 0):
            if is_contained(
                statistics.loc[:, ["Open", "High", "Low", "Close", "Adj Close"]], 0
            ) or is_contained(statistics.loc["std"], 0):
                print(f"{symbol}: contains numerical errors. Ignore it.")
                continue
            else:
                empty_vol_index = _stk_data[_stk_data["Volume"] == 0].index
                if len(empty_vol_index) > empty_vol_threshold:
                    print(
                        f"The total volume with a value of zero ({len(empty_vol_index)}) is greater than the threshold({empty_vol_threshold}). Ignore it."
                    )
                    continue
                print(
                    f"A total of {len(empty_vol_index)} volume values ​​are zero. Delete these data."
                )

                cleaned_data = _stk_data.drop(empty_vol_index)
                print(
                    f"The cleaned data size is {len(cleaned_data)}. The original data size is {len(_stk_data)}."
                )
                if len(cleaned_data) == 0:
                    continue
                _stk_data = cleaned_data

        ticks_data.append(_stk_data)
        print(f"{symbol}, size:{len(_stk_data)}")
    return ticks_data

# %%
empty_vol_threshold = 5
data1 = load_stk_data(
    stk_symbols, datetime(2014, 1, 1), datetime(2019, 12, 31), empty_vol_threshold
)
data2 = load_stk_data(
    stk_symbols, datetime(2021, 1, 1), datetime(2022, 11, 9), empty_vol_threshold
)
data3 = load_stk_data(
    stk_symbols, datetime(2023, 1, 1), datetime(2023, 12, 31), empty_vol_threshold
)
ticks_data = []
ticks_data.extend(data1)
ticks_data.extend(data2)
ticks_data.extend(data3)
print(len(ticks_data))
# Out:
# read /mnt/AIWorkSpace/work/fin-ml/data/AAPL_20140101-20191231.csv completely!
# AAPL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MSFT_20140101-20191231.csv completely!
# MSFT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AMZN_20140101-20191231.csv completely!
# AMZN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NVDA_20140101-20191231.csv completely!
# NVDA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GOOGL_20140101-20191231.csv completely!
# GOOGL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GOOG_20140101-20191231.csv completely!
# GOOG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/META_20140101-20191231.csv completely!
# META, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TSLA_20140101-20191231.csv completely!
# TSLA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/UNH_20140101-20191231.csv completely!
# UNH, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LLY_20140101-20191231.csv completely!
# LLY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/JPM_20140101-20191231.csv completely!
# JPM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/XOM_20140101-20191231.csv completely!
# XOM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/JNJ_20140101-20191231.csv completely!
# JNJ, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/V_20140101-20191231.csv completely!
# V, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PG_20140101-20191231.csv completely!
# PG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AVGO_20140101-20191231.csv completely!
# AVGO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MA_20140101-20191231.csv completely!
# MA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HD_20140101-20191231.csv completely!
# HD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CVX_20140101-20191231.csv completely!
# CVX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MRK_20140101-20191231.csv completely!
# MRK, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ABBV_20140101-20191231.csv completely!
# ABBV, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PEP_20140101-20191231.csv completely!
# PEP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/COST_20140101-20191231.csv completely!
# COST, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ADBE_20140101-20191231.csv completely!
# ADBE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/KO_20140101-20191231.csv completely!
# KO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CSCO_20140101-20191231.csv completely!
# CSCO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WMT_20140101-20191231.csv completely!
# WMT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TMO_20140101-20191231.csv completely!
# TMO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MCD_20140101-20191231.csv completely!
# MCD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PFE_20140101-20191231.csv completely!
# PFE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CRM_20140101-20191231.csv completely!
# CRM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BAC_20140101-20191231.csv completely!
# BAC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ACN_20140101-20191231.csv completely!
# ACN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CMCSA_20140101-20191231.csv completely!
# CMCSA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LIN_20140101-20191231.csv completely!
# LIN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NFLX_20140101-20191231.csv completely!
# NFLX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ABT_20140101-20191231.csv completely!
# ABT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ORCL_20140101-20191231.csv completely!
# ORCL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DHR_20140101-20191231.csv completely!
# DHR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AMD_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# AMD, size:1508
# read /mnt/AIWorkSpace/work/fin-ml/data/WFC_20140101-20191231.csv completely!
# WFC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DIS_20140101-20191231.csv completely!
# DIS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TXN_20140101-20191231.csv completely!
# TXN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PM_20140101-20191231.csv completely!
# PM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/VZ_20140101-20191231.csv completely!
# VZ, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/INTU_20140101-20191231.csv completely!
# INTU, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/COP_20140101-20191231.csv completely!
# COP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CAT_20140101-20191231.csv completely!
# CAT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AMGN_20140101-20191231.csv completely!
# AMGN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NEE_20140101-20191231.csv completely!
# NEE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/INTC_20140101-20191231.csv completely!
# INTC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/UNP_20140101-20191231.csv completely!
# UNP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LOW_20140101-20191231.csv completely!
# LOW, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/IBM_20140101-20191231.csv completely!
# IBM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BMY_20140101-20191231.csv completely!
# BMY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/SPGI_20140101-20191231.csv completely!
# SPGI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/RTX_20140101-20191231.csv completely!
# RTX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HON_20140101-20191231.csv completely!
# HON, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BA_20140101-20191231.csv completely!
# BA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/UPS_20140101-20191231.csv completely!
# UPS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GE_20140101-20191231.csv completely!
# GE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/QCOM_20140101-20191231.csv completely!
# QCOM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AMAT_20140101-20191231.csv completely!
# AMAT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NKE_20140101-20191231.csv completely!
# NKE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PLD_20140101-20191231.csv completely!
# PLD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NOW_20140101-20191231.csv completely!
# NOW, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BKNG_20140101-20191231.csv completely!
# BKNG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/SBUX_20140101-20191231.csv completely!
# SBUX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MS_20140101-20191231.csv completely!
# MS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ELV_20140101-20191231.csv completely!
# ELV, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MDT_20140101-20191231.csv completely!
# MDT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GS_20140101-20191231.csv completely!
# GS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DE_20140101-20191231.csv completely!
# DE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ADP_20140101-20191231.csv completely!
# ADP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LMT_20140101-20191231.csv completely!
# LMT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TJX_20140101-20191231.csv completely!
# TJX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/T_20140101-20191231.csv completely!
# T, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BLK_20140101-20191231.csv completely!
# BLK, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ISRG_20140101-20191231.csv completely!
# ISRG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MDLZ_20140101-20191231.csv completely!
# MDLZ, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GILD_20140101-20191231.csv completely!
# GILD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MMC_20140101-20191231.csv completely!
# MMC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AXP_20140101-20191231.csv completely!
# AXP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/SYK_20140101-20191231.csv completely!
# SYK, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/REGN_20140101-20191231.csv completely!
# REGN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/VRTX_20140101-20191231.csv completely!
# VRTX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ETN_20140101-20191231.csv completely!
# ETN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LRCX_20140101-20191231.csv completely!
# LRCX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ADI_20140101-20191231.csv completely!
# ADI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/SCHW_20140101-20191231.csv completely!
# SCHW, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CVS_20140101-20191231.csv completely!
# CVS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ZTS_20140101-20191231.csv completely!
# ZTS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CI_20140101-20191231.csv completely!
# CI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CB_20140101-20191231.csv completely!
# CB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AMT_20140101-20191231.csv completely!
# AMT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/SLB_20140101-20191231.csv completely!
# SLB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/C_20140101-20191231.csv completely!
# C, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BDX_20140101-20191231.csv completely!
# BDX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MO_20140101-20191231.csv completely!
# MO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PGR_20140101-20191231.csv completely!
# PGR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TMUS_20140101-20191231.csv completely!
# TMUS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FI_20140101-20191231.csv completely!
# FI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/SO_20140101-20191231.csv completely!
# SO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EOG_20140101-20191231.csv completely!
# EOG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BSX_20140101-20191231.csv completely!
# BSX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CME_20140101-20191231.csv completely!
# CME, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EQIX_20140101-20191231.csv completely!
# EQIX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MU_20140101-20191231.csv completely!
# MU, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DUK_20140101-20191231.csv completely!
# DUK, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PANW_20140101-20191231.csv completely!
# PANW, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PYPL_20140101-20191231.csv completely!
# PYPL, size:1131
# read /mnt/AIWorkSpace/work/fin-ml/data/AON_20140101-20191231.csv completely!
# AON, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/SNPS_20140101-20191231.csv completely!
# SNPS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ITW_20140101-20191231.csv completely!
# ITW, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/KLAC_20140101-20191231.csv completely!
# KLAC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LULU_20140101-20191231.csv completely!
# LULU, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ICE_20140101-20191231.csv completely!
# ICE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/APD_20140101-20191231.csv completely!
# APD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/SHW_20140101-20191231.csv completely!
# SHW, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CDNS_20140101-20191231.csv completely!
# CDNS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CSX_20140101-20191231.csv completely!
# CSX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NOC_20140101-20191231.csv completely!
# NOC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CL_20140101-20191231.csv completely!
# CL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MPC_20140101-20191231.csv completely!
# MPC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HUM_20140101-20191231.csv completely!
# HUM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FDX_20140101-20191231.csv completely!
# FDX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WM_20140101-20191231.csv completely!
# WM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MCK_20140101-20191231.csv completely!
# MCK, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TGT_20140101-20191231.csv completely!
# TGT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ORLY_20140101-20191231.csv completely!
# ORLY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HCA_20140101-20191231.csv completely!
# HCA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FCX_20140101-20191231.csv completely!
# FCX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EMR_20140101-20191231.csv completely!
# EMR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PXD_20140101-20191231.csv completely!
# PXD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MMM_20140101-20191231.csv completely!
# MMM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MCO_20140101-20191231.csv completely!
# MCO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ROP_20140101-20191231.csv completely!
# ROP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CMG_20140101-20191231.csv completely!
# CMG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PSX_20140101-20191231.csv completely!
# PSX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MAR_20140101-20191231.csv completely!
# MAR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PH_20140101-20191231.csv completely!
# PH, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/APH_20140101-20191231.csv completely!
# APH, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GD_20140101-20191231.csv completely!
# GD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/USB_20140101-20191231.csv completely!
# USB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NXPI_20140101-20191231.csv completely!
# NXPI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AJG_20140101-20191231.csv completely!
# AJG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NSC_20140101-20191231.csv completely!
# NSC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PNC_20140101-20191231.csv completely!
# PNC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/VLO_20140101-20191231.csv completely!
# VLO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GBP_20140101-20191231.csv completely!
# GBP: contains numerical errors. Ignore it.
# read /mnt/AIWorkSpace/work/fin-ml/data/F_20140101-20191231.csv completely!
# F, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MSI_20140101-20191231.csv completely!
# MSI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GM_20140101-20191231.csv completely!
# GM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TT_20140101-20191231.csv completely!
# TT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EW_20140101-20191231.csv completely!
# EW, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CARR_20140101-20191231.csv completely!
# CARR: contains numerical errors. Ignore it.
# read /mnt/AIWorkSpace/work/fin-ml/data/AZO_20140101-20191231.csv completely!
# AZO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ADSK_20140101-20191231.csv completely!
# ADSK, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TDG_20140101-20191231.csv completely!
# TDG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ANET_20140101-20191231.csv completely!
# ANET, size:1402
# read /mnt/AIWorkSpace/work/fin-ml/data/SRE_20140101-20191231.csv completely!
# SRE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ECL_20140101-20191231.csv completely!
# ECL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/OXY_20140101-20191231.csv completely!
# OXY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PCAR_20140101-20191231.csv completely!
# PCAR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ADM_20140101-20191231.csv completely!
# ADM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MNST_20140101-20191231.csv completely!
# MNST, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/KMB_20140101-20191231.csv completely!
# KMB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PSA_20140101-20191231.csv completely!
# PSA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CCI_20140101-20191231.csv completely!
# CCI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CHTR_20140101-20191231.csv completely!
# CHTR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MCHP_20140101-20191231.csv completely!
# MCHP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MSCI_20140101-20191231.csv completely!
# MSCI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CTAS_20140101-20191231.csv completely!
# CTAS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WMB_20140101-20191231.csv completely!
# WMB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AIG_20140101-20191231.csv completely!
# AIG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/STZ_20140101-20191231.csv completely!
# STZ, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HES_20140101-20191231.csv completely!
# HES, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NUE_20140101-20191231.csv completely!
# NUE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ROST_20140101-20191231.csv completely!
# ROST, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AFL_20140101-20191231.csv completely!
# AFL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AEP_20140101-20191231.csv completely!
# AEP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/IDXX_20140101-20191231.csv completely!
# IDXX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/D_20140101-20191231.csv completely!
# D, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TEL_20140101-20191231.csv completely!
# TEL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/JCI_20140101-20191231.csv completely!
# JCI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MET_20140101-20191231.csv completely!
# MET, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GIS_20140101-20191231.csv completely!
# GIS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/IQV_20140101-20191231.csv completely!
# IQV, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EXC_20140101-20191231.csv completely!
# EXC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WELL_20140101-20191231.csv completely!
# WELL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DXCM_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# DXCM, size:1508
# read /mnt/AIWorkSpace/work/fin-ml/data/HLT_20140101-20191231.csv completely!
# HLT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ON_20140101-20191231.csv completely!
# ON, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/COF_20140101-20191231.csv completely!
# COF, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PAYX_20140101-20191231.csv completely!
# PAYX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TFC_20140101-20191231.csv completely!
# TFC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/USD_20140101-20191231.csv completely!
# The total volume with a value of zero (6) is greater than the threshold(5). Ignore it.
# read /mnt/AIWorkSpace/work/fin-ml/data/BIIB_20140101-20191231.csv completely!
# BIIB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/O_20140101-20191231.csv completely!
# O, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FTNT_20140101-20191231.csv completely!
# FTNT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DOW_20140101-20191231.csv completely!
# DOW, size:198
# read /mnt/AIWorkSpace/work/fin-ml/data/TRV_20140101-20191231.csv completely!
# TRV, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DLR_20140101-20191231.csv completely!
# DLR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MRNA_20140101-20191231.csv completely!
# MRNA, size:267
# read /mnt/AIWorkSpace/work/fin-ml/data/CPRT_20140101-20191231.csv completely!
# CPRT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ODFL_20140101-20191231.csv completely!
# ODFL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DHI_20140101-20191231.csv completely!
# DHI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/YUM_20140101-20191231.csv completely!
# YUM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/SPG_20140101-20191231.csv completely!
# SPG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CTSH_20140101-20191231.csv completely!
# CTSH, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AME_20140101-20191231.csv completely!
# AME, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BKR_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# BKR, size:1508
# read /mnt/AIWorkSpace/work/fin-ml/data/SYY_20140101-20191231.csv completely!
# SYY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/A_20140101-20191231.csv completely!
# A, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CTVA_20140101-20191231.csv completely!
# CTVA, size:152
# read /mnt/AIWorkSpace/work/fin-ml/data/CNC_20140101-20191231.csv completely!
# CNC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EL_20140101-20191231.csv completely!
# EL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AMP_20140101-20191231.csv completely!
# AMP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HAL_20140101-20191231.csv completely!
# HAL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ROK_20140101-20191231.csv completely!
# ROK, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PRU_20140101-20191231.csv completely!
# PRU, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DD_20140101-20191231.csv completely!
# DD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/KMI_20140101-20191231.csv completely!
# KMI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/VRSK_20140101-20191231.csv completely!
# VRSK, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LHX_20140101-20191231.csv completely!
# LHX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DG_20140101-20191231.csv completely!
# DG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FIS_20140101-20191231.csv completely!
# FIS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CMI_20140101-20191231.csv completely!
# CMI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CSGP_20140101-20191231.csv completely!
# CSGP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FAST_20140101-20191231.csv completely!
# FAST, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PPG_20140101-20191231.csv completely!
# PPG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GPN_20140101-20191231.csv completely!
# GPN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GWW_20140101-20191231.csv completely!
# GWW, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HSY_20140101-20191231.csv completely!
# HSY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BK_20140101-20191231.csv completely!
# BK, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/XEL_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# XEL, size:1508
# read /mnt/AIWorkSpace/work/fin-ml/data/DVN_20140101-20191231.csv completely!
# DVN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EA_20140101-20191231.csv completely!
# EA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NEM_20140101-20191231.csv completely!
# NEM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ED_20140101-20191231.csv completely!
# ED, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/URI_20140101-20191231.csv completely!
# URI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/VICI_20140101-20191231.csv completely!
# VICI, size:502
# read /mnt/AIWorkSpace/work/fin-ml/data/PEG_20140101-20191231.csv completely!
# PEG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/KR_20140101-20191231.csv completely!
# KR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/RSG_20140101-20191231.csv completely!
# RSG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LEN_20140101-20191231.csv completely!
# LEN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PWR_20140101-20191231.csv completely!
# PWR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WST_20140101-20191231.csv completely!
# WST, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/COR_20140101-20191231.csv completely!
# COR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/OKE_20140101-20191231.csv completely!
# OKE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/VMC_20140101-20191231.csv completely!
# VMC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/KDP_20140101-20191231.csv completely!
# KDP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WBD_20140101-20191231.csv completely!
# WBD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ACGL_20140101-20191231.csv completely!
# ACGL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ALL_20140101-20191231.csv completely!
# ALL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/IR_20140101-20191231.csv completely!
# IR, size:663
# read /mnt/AIWorkSpace/work/fin-ml/data/CDW_20140101-20191231.csv completely!
# CDW, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FANG_20140101-20191231.csv completely!
# FANG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MLM_20140101-20191231.csv completely!
# MLM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PCG_20140101-20191231.csv completely!
# PCG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DAL_20140101-20191231.csv completely!
# DAL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EXR_20140101-20191231.csv completely!
# EXR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FTV_20140101-20191231.csv completely!
# FTV, size:879
# read /mnt/AIWorkSpace/work/fin-ml/data/AWK_20140101-20191231.csv completely!
# AWK, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/IT_20140101-20191231.csv completely!
# IT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/KHC_20140101-20191231.csv completely!
# KHC, size:1131
# read /mnt/AIWorkSpace/work/fin-ml/data/WEC_20140101-20191231.csv completely!
# WEC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HPQ_20140101-20191231.csv completely!
# HPQ, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EIX_20140101-20191231.csv completely!
# EIX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CBRE_20140101-20191231.csv completely!
# CBRE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/APTV_20140101-20191231.csv completely!
# APTV, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ANSS_20140101-20191231.csv completely!
# ANSS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MTD_20140101-20191231.csv completely!
# MTD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DLTR_20140101-20191231.csv completely!
# DLTR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AVB_20140101-20191231.csv completely!
# AVB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ILMN_20140101-20191231.csv completely!
# ILMN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ALGN_20140101-20191231.csv completely!
# ALGN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LYB_20140101-20191231.csv completely!
# LYB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TROW_20140101-20191231.csv completely!
# TROW, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GLW_20140101-20191231.csv completely!
# GLW, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EFX_20140101-20191231.csv completely!
# EFX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WY_20140101-20191231.csv completely!
# WY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ZBH_20140101-20191231.csv completely!
# ZBH, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/XYL_20140101-20191231.csv completely!
# XYL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/SBAC_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# SBAC, size:1508
# read /mnt/AIWorkSpace/work/fin-ml/data/RMD_20140101-20191231.csv completely!
# RMD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TSCO_20140101-20191231.csv completely!
# TSCO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EBAY_20140101-20191231.csv completely!
# EBAY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/KEYS_20140101-20191231.csv completely!
# KEYS, size:1308
# read /mnt/AIWorkSpace/work/fin-ml/data/CHD_20140101-20191231.csv completely!
# CHD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/STT_20140101-20191231.csv completely!
# STT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DFS_20140101-20191231.csv completely!
# DFS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HIG_20140101-20191231.csv completely!
# HIG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ALB_20140101-20191231.csv completely!
# ALB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/STE_20140101-20191231.csv completely!
# STE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ES_20140101-20191231.csv completely!
# ES, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TTWO_20140101-20191231.csv completely!
# TTWO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MPWR_20140101-20191231.csv completely!
# MPWR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CAH_20140101-20191231.csv completely!
# CAH, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EQR_20140101-20191231.csv completely!
# EQR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/RCL_20140101-20191231.csv completely!
# RCL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WTW_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# WTW, size:1508
# read /mnt/AIWorkSpace/work/fin-ml/data/HPE_20140101-20191231.csv completely!
# HPE, size:1057
# read /mnt/AIWorkSpace/work/fin-ml/data/DTE_20140101-20191231.csv completely!
# DTE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GPC_20140101-20191231.csv completely!
# GPC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BR_20140101-20191231.csv completely!
# BR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ULTA_20140101-20191231.csv completely!
# ULTA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FICO_20140101-20191231.csv completely!
# FICO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CTRA_20140101-20191231.csv completely!
# CTRA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BAX_20140101-20191231.csv completely!
# BAX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AEE_20140101-20191231.csv completely!
# AEE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MTB_20140101-20191231.csv completely!
# MTB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MKC_20140101-20191231.csv completely!
# MKC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ETR_20140101-20191231.csv completely!
# ETR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WAB_20140101-20191231.csv completely!
# WAB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DOV_20140101-20191231.csv completely!
# DOV, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FE_20140101-20191231.csv completely!
# FE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/RJF_20140101-20191231.csv completely!
# RJF, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/INVH_20140101-20191231.csv completely!
# INVH, size:733
# read /mnt/AIWorkSpace/work/fin-ml/data/FLT_20140101-20191231.csv completely!
# FLT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CLX_20140101-20191231.csv completely!
# CLX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TDY_20140101-20191231.csv completely!
# TDY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TRGP_20140101-20191231.csv completely!
# TRGP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DRI_20140101-20191231.csv completely!
# DRI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LH_20140101-20191231.csv completely!
# LH, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HOLX_20140101-20191231.csv completely!
# HOLX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/VRSN_20140101-20191231.csv completely!
# VRSN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MOH_20140101-20191231.csv completely!
# MOH, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LUV_20140101-20191231.csv completely!
# LUV, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PPL_20140101-20191231.csv completely!
# PPL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ARE_20140101-20191231.csv completely!
# ARE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NVR_20140101-20191231.csv completely!
# NVR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/COO_20140101-20191231.csv completely!
# A total of 2 volume values ​​are zero. Delete these data.
# The cleaned data size is 1507. The original data size is 1509.
# COO, size:1507
# read /mnt/AIWorkSpace/work/fin-ml/data/WBA_20140101-20191231.csv completely!
# WBA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PHM_20140101-20191231.csv completely!
# PHM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NDAQ_20140101-20191231.csv completely!
# NDAQ, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HWM_20140101-20191231.csv completely!
# The total volume with a value of zero (35) is greater than the threshold(5). Ignore it.
# read /mnt/AIWorkSpace/work/fin-ml/data/RF_20140101-20191231.csv completely!
# RF, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CNP_20140101-20191231.csv completely!
# CNP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/IRM_20140101-20191231.csv completely!
# IRM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LVS_20140101-20191231.csv completely!
# LVS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FITB_20140101-20191231.csv completely!
# FITB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EXPD_20140101-20191231.csv completely!
# EXPD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/VTR_20140101-20191231.csv completely!
# VTR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FSLR_20140101-20191231.csv completely!
# FSLR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PFG_20140101-20191231.csv completely!
# A total of 2 volume values ​​are zero. Delete these data.
# The cleaned data size is 1507. The original data size is 1509.
# PFG, size:1507
# read /mnt/AIWorkSpace/work/fin-ml/data/BRO_20140101-20191231.csv completely!
# BRO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/J_20140101-20191231.csv completely!
# J, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/IEX_20140101-20191231.csv completely!
# IEX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BG_20140101-20191231.csv completely!
# BG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ATO_20140101-20191231.csv completely!
# ATO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FDS_20140101-20191231.csv completely!
# FDS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ENPH_20140101-20191231.csv completely!
# ENPH, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MAA_20140101-20191231.csv completely!
# MAA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CMS_20140101-20191231.csv completely!
# CMS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/IFF_20140101-20191231.csv completely!
# IFF, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BALL_20140101-20191231.csv completely!
# BALL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/SWKS_20140101-20191231.csv completely!
# SWKS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CINF_20140101-20191231.csv completely!
# CINF, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NTAP_20140101-20191231.csv completely!
# NTAP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/STLD_20140101-20191231.csv completely!
# STLD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/UAL_20140101-20191231.csv completely!
# UAL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WAT_20140101-20191231.csv completely!
# WAT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/OMC_20140101-20191231.csv completely!
# OMC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TER_20140101-20191231.csv completely!
# TER, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CCL_20140101-20191231.csv completely!
# CCL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/JBHT_20140101-20191231.csv completely!
# JBHT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MRO_20140101-20191231.csv completely!
# MRO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TYL_20140101-20191231.csv completely!
# TYL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HBAN_20140101-20191231.csv completely!
# HBAN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/K_20140101-20191231.csv completely!
# K, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GRMN_20140101-20191231.csv completely!
# GRMN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CBOE_20140101-20191231.csv completely!
# CBOE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NTRS_20140101-20191231.csv completely!
# NTRS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TSN_20140101-20191231.csv completely!
# TSN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AKAM_20140101-20191231.csv completely!
# AKAM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EG_20140101-20191231.csv completely!
# EG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ESS_20140101-20191231.csv completely!
# ESS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EQT_20140101-20191231.csv completely!
# EQT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TXT_20140101-20191231.csv completely!
# TXT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EXPE_20140101-20191231.csv completely!
# EXPE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/SJM_20140101-20191231.csv completely!
# SJM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PTC_20140101-20191231.csv completely!
# PTC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DGX_20140101-20191231.csv completely!
# DGX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AVY_20140101-20191231.csv completely!
# AVY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/RVTY_20140101-20191231.csv completely!
# RVTY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BBY_20140101-20191231.csv completely!
# BBY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CF_20140101-20191231.csv completely!
# CF, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CAG_20140101-20191231.csv completely!
# CAG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EPAM_20140101-20191231.csv completely!
# EPAM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AMCR_20140101-20191231.csv completely!
# The total volume with a value of zero (1110) is greater than the threshold(5). Ignore it.
# read /mnt/AIWorkSpace/work/fin-ml/data/LW_20140101-20191231.csv completely!
# LW, size:788
# read /mnt/AIWorkSpace/work/fin-ml/data/PAYC_20140101-20191231.csv completely!
# PAYC, size:1438
# read /mnt/AIWorkSpace/work/fin-ml/data/SNA_20140101-20191231.csv completely!
# SNA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AXON_20140101-20191231.csv completely!
# AXON, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/POOL_20140101-20191231.csv completely!
# POOL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/SYF_20140101-20191231.csv completely!
# SYF, size:1364
# read /mnt/AIWorkSpace/work/fin-ml/data/SWK_20140101-20191231.csv completely!
# SWK, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ZBRA_20140101-20191231.csv completely!
# ZBRA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DPZ_20140101-20191231.csv completely!
# DPZ, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PKG_20140101-20191231.csv completely!
# PKG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CFG_20140101-20191231.csv completely!
# CFG, size:1326
# read /mnt/AIWorkSpace/work/fin-ml/data/LDOS_20140101-20191231.csv completely!
# LDOS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/VTRS_20140101-20191231.csv completely!
# VTRS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PODD_20140101-20191231.csv completely!
# PODD, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LKQ_20140101-20191231.csv completely!
# LKQ, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MOS_20140101-20191231.csv completely!
# MOS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/APA_20140101-20191231.csv completely!
# APA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EVRG_20140101-20191231.csv completely!
# EVRG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TRMB_20140101-20191231.csv completely!
# TRMB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MGM_20140101-20191231.csv completely!
# MGM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NDSN_20140101-20191231.csv completely!
# NDSN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WDC_20140101-20191231.csv completely!
# WDC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MAS_20140101-20191231.csv completely!
# MAS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LNT_20140101-20191231.csv completely!
# LNT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/IPG_20140101-20191231.csv completely!
# IPG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MTCH_20140101-20191231.csv completely!
# MTCH, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/STX_20140101-20191231.csv completely!
# STX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/KMX_20140101-20191231.csv completely!
# KMX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TECH_20140101-20191231.csv completely!
# TECH, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WRB_20140101-20191231.csv completely!
# WRB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/LYV_20140101-20191231.csv completely!
# LYV, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/IP_20140101-20191231.csv completely!
# IP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/UDR_20140101-20191231.csv completely!
# UDR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AES_20140101-20191231.csv completely!
# AES, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CE_20140101-20191231.csv completely!
# CE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/INCY_20140101-20191231.csv completely!
# INCY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/L_20140101-20191231.csv completely!
# L, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TAP_20140101-20191231.csv completely!
# TAP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GEN_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# GEN, size:1508
# read /mnt/AIWorkSpace/work/fin-ml/data/CPT_20140101-20191231.csv completely!
# CPT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/KIM_20140101-20191231.csv completely!
# KIM, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/JKHY_20140101-20191231.csv completely!
# JKHY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HRL_20140101-20191231.csv completely!
# HRL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HST_20140101-20191231.csv completely!
# HST, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FMC_20140101-20191231.csv completely!
# FMC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CZR_20140101-20191231.csv completely!
# CZR, size:1328
# read /mnt/AIWorkSpace/work/fin-ml/data/PEAK_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# PEAK, size:1508
# read /mnt/AIWorkSpace/work/fin-ml/data/CDAY_20140101-20191231.csv completely!
# CDAY, size:423
# read /mnt/AIWorkSpace/work/fin-ml/data/PNR_20140101-20191231.csv completely!
# PNR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NI_20140101-20191231.csv completely!
# NI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CHRW_20140101-20191231.csv completely!
# CHRW, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HSIC_20140101-20191231.csv completely!
# HSIC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CRL_20140101-20191231.csv completely!
# CRL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/REG_20140101-20191231.csv completely!
# REG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/QRVO_20140101-20191231.csv completely!
# QRVO, size:1257
# read /mnt/AIWorkSpace/work/fin-ml/data/TFX_20140101-20191231.csv completely!
# TFX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/KEY_20140101-20191231.csv completely!
# KEY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GL_20140101-20191231.csv completely!
# GL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/EMN_20140101-20191231.csv completely!
# EMN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WYNN_20140101-20191231.csv completely!
# WYNN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ALLE_20140101-20191231.csv completely!
# ALLE, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AAL_20140101-20191231.csv completely!
# AAL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FFIV_20140101-20191231.csv completely!
# FFIV, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BWA_20140101-20191231.csv completely!
# BWA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BXP_20140101-20191231.csv completely!
# BXP, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/MKTX_20140101-20191231.csv completely!
# MKTX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ROL_20140101-20191231.csv completely!
# ROL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/JNPR_20140101-20191231.csv completely!
# JNPR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PNW_20140101-20191231.csv completely!
# PNW, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ETSY_20140101-20191231.csv completely!
# ETSY, size:1186
# read /mnt/AIWorkSpace/work/fin-ml/data/BLDR_20140101-20191231.csv completely!
# BLDR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FOXA_20140101-20191231.csv completely!
# FOXA, size:204
# read /mnt/AIWorkSpace/work/fin-ml/data/AOS_20140101-20191231.csv completely!
# AOS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HAS_20140101-20191231.csv completely!
# HAS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HII_20140101-20191231.csv completely!
# HII, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NRG_20140101-20191231.csv completely!
# NRG, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CPB_20140101-20191231.csv completely!
# CPB, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/UHS_20140101-20191231.csv completely!
# UHS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BIO_20140101-20191231.csv completely!
# BIO, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WRK_20140101-20191231.csv completely!
# WRK, size:1138
# read /mnt/AIWorkSpace/work/fin-ml/data/RHI_20140101-20191231.csv completely!
# RHI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CTLT_20140101-20191231.csv completely!
# CTLT, size:1364
# read /mnt/AIWorkSpace/work/fin-ml/data/XRAY_20140101-20191231.csv completely!
# XRAY, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BBWI_20140101-20191231.csv completely!
# BBWI, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NWSA_20140101-20191231.csv completely!
# NWSA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/TPR_20140101-20191231.csv completely!
# TPR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/PARA_20140101-20191231.csv completely!
# PARA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/WHR_20140101-20191231.csv completely!
# WHR, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/BEN_20140101-20191231.csv completely!
# BEN, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AIZ_20140101-20191231.csv completely!
# AIZ, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/NCLH_20140101-20191231.csv completely!
# NCLH, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/GNRC_20140101-20191231.csv completely!
# GNRC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FRT_20140101-20191231.csv completely!
# FRT, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/IVZ_20140101-20191231.csv completely!
# IVZ, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/VFC_20140101-20191231.csv completely!
# VFC, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/CMA_20140101-20191231.csv completely!
# CMA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/DVA_20140101-20191231.csv completely!
# DVA, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/JBL_20140101-20191231.csv completely!
# JBL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/HUBB_20140101-20191231.csv completely!
# A total of 1 volume values ​​are zero. Delete these data.
# The cleaned data size is 1508. The original data size is 1509.
# HUBB, size:1508
# read /mnt/AIWorkSpace/work/fin-ml/data/ZION_20140101-20191231.csv completely!
# ZION, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/UBER_20140101-20191231.csv completely!
# UBER, size:162
# read /mnt/AIWorkSpace/work/fin-ml/data/MHK_20140101-20191231.csv completely!
# MHK, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/RL_20140101-20191231.csv completely!
# RL, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/FOX_20140101-20191231.csv completely!
# FOX, size:203
# read /mnt/AIWorkSpace/work/fin-ml/data/BX_20140101-20191231.csv completely!
# BX, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/ABNB_20140101-20191231.csv completely!
# ABNB: contains numerical errors. Ignore it.
# read /mnt/AIWorkSpace/work/fin-ml/data/NWS_20140101-20191231.csv completely!
# NWS, size:1509
# read /mnt/AIWorkSpace/work/fin-ml/data/AAPL_20210101-20221109.csv completely!
# AAPL, size:467
# read /mnt/AIWorkSpace/work/fin-ml/data/MSFT_20210101-20221109.csv completely!
# MSFT, size:467
# read /mnt/AIWorkSpace/work/fin-ml/data/AMZN_20210101-20221109.csv completely!
# AMZN, size:467
# read /mnt/AIWorkSpace/work/fin-ml/data/NVDA_20210101-20221109.csv completely!
# NVDA, size:467
# ...
# DRI, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/LH_20230101-20231231.csv completely!
# LH, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/HOLX_20230101-20231231.csv completely!
# HOLX, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/VRSN_20230101-20231231.csv completely!
# VRSN, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/MOH_20230101-20231231.csv completely!
# MOH, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/LUV_20230101-20231231.csv completely!
# LUV, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/PPL_20230101-20231231.csv completely!
# PPL, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/ARE_20230101-20231231.csv completely!
# ARE, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/NVR_20230101-20231231.csv completely!
# NVR, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/COO_20230101-20231231.csv completely!
# COO, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/WBA_20230101-20231231.csv completely!
# WBA, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/PHM_20230101-20231231.csv completely!
# PHM, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/NDAQ_20230101-20231231.csv completely!
# NDAQ, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/HWM_20230101-20231231.csv completely!
# HWM, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/RF_20230101-20231231.csv completely!
# RF, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CNP_20230101-20231231.csv completely!
# CNP, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/IRM_20230101-20231231.csv completely!
# IRM, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/LVS_20230101-20231231.csv completely!
# LVS, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/FITB_20230101-20231231.csv completely!
# FITB, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/EXPD_20230101-20231231.csv completely!
# EXPD, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/VTR_20230101-20231231.csv completely!
# VTR, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/FSLR_20230101-20231231.csv completely!
# FSLR, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/PFG_20230101-20231231.csv completely!
# PFG, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/BRO_20230101-20231231.csv completely!
# BRO, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/J_20230101-20231231.csv completely!
# J, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/IEX_20230101-20231231.csv completely!
# IEX, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/BG_20230101-20231231.csv completely!
# BG, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/ATO_20230101-20231231.csv completely!
# ATO, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/FDS_20230101-20231231.csv completely!
# FDS, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/ENPH_20230101-20231231.csv completely!
# ENPH, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/MAA_20230101-20231231.csv completely!
# MAA, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CMS_20230101-20231231.csv completely!
# CMS, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/IFF_20230101-20231231.csv completely!
# IFF, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/BALL_20230101-20231231.csv completely!
# BALL, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/SWKS_20230101-20231231.csv completely!
# SWKS, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CINF_20230101-20231231.csv completely!
# CINF, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/NTAP_20230101-20231231.csv completely!
# NTAP, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/STLD_20230101-20231231.csv completely!
# STLD, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/UAL_20230101-20231231.csv completely!
# UAL, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/WAT_20230101-20231231.csv completely!
# WAT, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/OMC_20230101-20231231.csv completely!
# OMC, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/TER_20230101-20231231.csv completely!
# TER, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CCL_20230101-20231231.csv completely!
# CCL, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/JBHT_20230101-20231231.csv completely!
# JBHT, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/MRO_20230101-20231231.csv completely!
# MRO, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/TYL_20230101-20231231.csv completely!
# TYL, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/HBAN_20230101-20231231.csv completely!
# HBAN, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/K_20230101-20231231.csv completely!
# K, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/GRMN_20230101-20231231.csv completely!
# GRMN, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CBOE_20230101-20231231.csv completely!
# CBOE, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/NTRS_20230101-20231231.csv completely!
# NTRS, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/TSN_20230101-20231231.csv completely!
# TSN, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/AKAM_20230101-20231231.csv completely!
# AKAM, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/EG_20230101-20231231.csv completely!
# EG, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/ESS_20230101-20231231.csv completely!
# ESS, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/EQT_20230101-20231231.csv completely!
# EQT, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/TXT_20230101-20231231.csv completely!
# TXT, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/EXPE_20230101-20231231.csv completely!
# EXPE, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/SJM_20230101-20231231.csv completely!
# SJM, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/PTC_20230101-20231231.csv completely!
# PTC, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/DGX_20230101-20231231.csv completely!
# DGX, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/AVY_20230101-20231231.csv completely!
# AVY, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/RVTY_20230101-20231231.csv completely!
# RVTY, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/BBY_20230101-20231231.csv completely!
# BBY, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CF_20230101-20231231.csv completely!
# CF, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CAG_20230101-20231231.csv completely!
# CAG, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/EPAM_20230101-20231231.csv completely!
# EPAM, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/AMCR_20230101-20231231.csv completely!
# AMCR, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/LW_20230101-20231231.csv completely!
# LW, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/PAYC_20230101-20231231.csv completely!
# PAYC, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/SNA_20230101-20231231.csv completely!
# SNA, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/AXON_20230101-20231231.csv completely!
# AXON, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/POOL_20230101-20231231.csv completely!
# POOL, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/SYF_20230101-20231231.csv completely!
# SYF, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/SWK_20230101-20231231.csv completely!
# SWK, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/ZBRA_20230101-20231231.csv completely!
# ZBRA, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/DPZ_20230101-20231231.csv completely!
# DPZ, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/PKG_20230101-20231231.csv completely!
# PKG, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CFG_20230101-20231231.csv completely!
# CFG, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/LDOS_20230101-20231231.csv completely!
# LDOS, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/VTRS_20230101-20231231.csv completely!
# VTRS, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/PODD_20230101-20231231.csv completely!
# PODD, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/LKQ_20230101-20231231.csv completely!
# LKQ, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/MOS_20230101-20231231.csv completely!
# MOS, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/APA_20230101-20231231.csv completely!
# APA, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/EVRG_20230101-20231231.csv completely!
# EVRG, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/TRMB_20230101-20231231.csv completely!
# TRMB, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/MGM_20230101-20231231.csv completely!
# MGM, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/NDSN_20230101-20231231.csv completely!
# NDSN, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/WDC_20230101-20231231.csv completely!
# WDC, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/MAS_20230101-20231231.csv completely!
# MAS, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/LNT_20230101-20231231.csv completely!
# LNT, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/IPG_20230101-20231231.csv completely!
# IPG, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/MTCH_20230101-20231231.csv completely!
# MTCH, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/STX_20230101-20231231.csv completely!
# STX, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/KMX_20230101-20231231.csv completely!
# KMX, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/TECH_20230101-20231231.csv completely!
# TECH, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/WRB_20230101-20231231.csv completely!
# WRB, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/LYV_20230101-20231231.csv completely!
# LYV, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/IP_20230101-20231231.csv completely!
# IP, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/UDR_20230101-20231231.csv completely!
# UDR, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/AES_20230101-20231231.csv completely!
# AES, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CE_20230101-20231231.csv completely!
# CE, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/INCY_20230101-20231231.csv completely!
# INCY, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/L_20230101-20231231.csv completely!
# L, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/TAP_20230101-20231231.csv completely!
# TAP, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/GEN_20230101-20231231.csv completely!
# GEN, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CPT_20230101-20231231.csv completely!
# CPT, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/KIM_20230101-20231231.csv completely!
# KIM, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/JKHY_20230101-20231231.csv completely!
# JKHY, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/HRL_20230101-20231231.csv completely!
# HRL, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/HST_20230101-20231231.csv completely!
# HST, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/FMC_20230101-20231231.csv completely!
# FMC, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CZR_20230101-20231231.csv completely!
# CZR, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/PEAK_20230101-20231231.csv completely!
# PEAK, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CDAY_20230101-20231231.csv completely!
# CDAY, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/PNR_20230101-20231231.csv completely!
# PNR, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/NI_20230101-20231231.csv completely!
# NI, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CHRW_20230101-20231231.csv completely!
# CHRW, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/HSIC_20230101-20231231.csv completely!
# HSIC, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CRL_20230101-20231231.csv completely!
# CRL, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/REG_20230101-20231231.csv completely!
# REG, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/QRVO_20230101-20231231.csv completely!
# QRVO, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/TFX_20230101-20231231.csv completely!
# TFX, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/KEY_20230101-20231231.csv completely!
# KEY, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/GL_20230101-20231231.csv completely!
# GL, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/EMN_20230101-20231231.csv completely!
# EMN, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/WYNN_20230101-20231231.csv completely!
# WYNN, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/ALLE_20230101-20231231.csv completely!
# ALLE, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/AAL_20230101-20231231.csv completely!
# AAL, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/FFIV_20230101-20231231.csv completely!
# FFIV, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/BWA_20230101-20231231.csv completely!
# BWA, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/BXP_20230101-20231231.csv completely!
# BXP, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/MKTX_20230101-20231231.csv completely!
# MKTX, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/ROL_20230101-20231231.csv completely!
# ROL, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/JNPR_20230101-20231231.csv completely!
# JNPR, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/PNW_20230101-20231231.csv completely!
# PNW, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/ETSY_20230101-20231231.csv completely!
# ETSY, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/BLDR_20230101-20231231.csv completely!
# BLDR, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/FOXA_20230101-20231231.csv completely!
# FOXA, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/AOS_20230101-20231231.csv completely!
# AOS, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/HAS_20230101-20231231.csv completely!
# HAS, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/HII_20230101-20231231.csv completely!
# HII, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/NRG_20230101-20231231.csv completely!
# NRG, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CPB_20230101-20231231.csv completely!
# CPB, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/UHS_20230101-20231231.csv completely!
# UHS, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/BIO_20230101-20231231.csv completely!
# BIO, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/WRK_20230101-20231231.csv completely!
# WRK, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/RHI_20230101-20231231.csv completely!
# RHI, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CTLT_20230101-20231231.csv completely!
# CTLT, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/XRAY_20230101-20231231.csv completely!
# XRAY, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/BBWI_20230101-20231231.csv completely!
# BBWI, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/NWSA_20230101-20231231.csv completely!
# NWSA, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/TPR_20230101-20231231.csv completely!
# TPR, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/PARA_20230101-20231231.csv completely!
# PARA, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/WHR_20230101-20231231.csv completely!
# WHR, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/BEN_20230101-20231231.csv completely!
# BEN, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/AIZ_20230101-20231231.csv completely!
# AIZ, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/NCLH_20230101-20231231.csv completely!
# NCLH, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/GNRC_20230101-20231231.csv completely!
# GNRC, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/FRT_20230101-20231231.csv completely!
# FRT, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/IVZ_20230101-20231231.csv completely!
# IVZ, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/VFC_20230101-20231231.csv completely!
# VFC, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/CMA_20230101-20231231.csv completely!
# CMA, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/DVA_20230101-20231231.csv completely!
# DVA, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/JBL_20230101-20231231.csv completely!
# JBL, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/HUBB_20230101-20231231.csv completely!
# HUBB, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/ZION_20230101-20231231.csv completely!
# ZION, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/UBER_20230101-20231231.csv completely!
# UBER, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/MHK_20230101-20231231.csv completely!
# MHK, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/RL_20230101-20231231.csv completely!
# RL, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/FOX_20230101-20231231.csv completely!
# FOX, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/BX_20230101-20231231.csv completely!
# BX, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/ABNB_20230101-20231231.csv completely!
# ABNB, size:250
# read /mnt/AIWorkSpace/work/fin-ml/data/NWS_20230101-20231231.csv completely!
# NWS, size:250
# 1486

# %%
import torch

device_name = (
    "cuda"
    if torch.cuda.is_available()
    else "mps" if torch.backends.mps.is_available() else "cpu"
)
device = torch.device(device_name)
return_period = 5
seq_len = 3
validation_size = 0.2
epoch_num = 100
batch_size = 32
num_workers = 3
pin_memory = True
shuffle = True
print(f"device_name:{device}")
# Out:
# device_name:cuda

# %%
pct_threshold = 0.04
class_percentage_threshold = 0  # percentage threshold for class size
classificationThreshold = 0.5


# # number of classes = 3
# # 0: PCT <= -0.05
# # 1: 0.05 < PCT < -0.05
# # 2: PCT >= 0.05
# num_classes = 3


# def gen_pct_label(stk_data, _return_period):
#     max_price_period = (
#         stk_data["Adj Close"].rolling(_return_period).max().shift(-_return_period)
#     )
#     max_pct_period = (max_price_period - stk_data["Adj Close"]) / stk_data["Adj Close"]
#     pct_label = max_pct_period.apply(
#         lambda x: 2 if x >= pct_threshold else 0 if x <= -pct_threshold else 1
#     ).astype("int8")
#     pct_label.name = "label"
#     return pct_label


# number of classes = 2
# 0: PCT < 0.05
# 1: PCT >= -0.05
num_classes = 2


def gen_pct_label(stk_data, _return_period):
    max_price_period = (
        stk_data["Adj Close"].rolling(_return_period).max().shift(-_return_period)
    )
    max_pct_period = (max_price_period - stk_data["Adj Close"]) / stk_data["Adj Close"]
    pct_label = max_pct_period.apply(lambda x: 1 if x >= pct_threshold else 0).astype(
        "int8"
    )
    pct_label.name = "label"
    return pct_label


def class_percentage(analysis_data):
    stat = analysis_data.groupby("label").size()
    total = len(analysis_data)
    p = []
    for i in range(num_classes):
        p.append(stat[i] / total if i in stat.index else 0.0)
    return p

# %%
def to_adjusted(stk_data):
    """
    Adjusted Open = Open * Adjusted Close / Close
    Adjusted High = High * Adjusted Close / Close
    Adjusted Low = Low * Adjusted Close / Close
    Adjusted volume = Volume / (Adjusted Close / Close)
    """
    ratio_data = stk_data["Adj Close"] / stk_data["Close"]
    adjusted_OHLV = pd.DataFrame(index=stk_data.index)
    adjusted_OHLV["Adj Open"] = ratio_data * stk_data["Open"]
    adjusted_OHLV["Adj High"] = ratio_data * stk_data["High"]
    adjusted_OHLV["Adj Low"] = ratio_data * stk_data["Low"]
    adjusted_OHLV["Adj Close"] = stk_data["Adj Close"]
    adjusted_OHLV["Adj Volume"] = (ratio_data * stk_data["Volume"]).astype("int")
    adjusted_OHLV["Pre Adj Close"] = stk_data["Adj Close"].shift(1)
    adjusted_OHLV["Pre Adj Volume"] = adjusted_OHLV["Adj Volume"].shift(1)
    adjusted_OHLV = adjusted_OHLV.dropna()
    adjusted_OHLV["Pre Adj Volume"] = adjusted_OHLV["Pre Adj Volume"].astype("int")
    adjusted_OHLV["B4_Adj Open pct"] = (
        adjusted_OHLV["Adj Open"] - adjusted_OHLV["Pre Adj Close"]
    ) / adjusted_OHLV["Pre Adj Close"]
    adjusted_OHLV["B4_Adj High pct"] = (
        adjusted_OHLV["Adj High"] - adjusted_OHLV["Pre Adj Close"]
    ) / adjusted_OHLV["Pre Adj Close"]
    adjusted_OHLV["B4_Adj Low pct"] = (
        adjusted_OHLV["Adj Low"] - adjusted_OHLV["Pre Adj Close"]
    ) / adjusted_OHLV["Pre Adj Close"]
    adjusted_OHLV["B4_Adj Volume pct"] = (
        adjusted_OHLV["Adj Volume"] - adjusted_OHLV["Pre Adj Volume"]
    ) / adjusted_OHLV["Pre Adj Volume"]

    return adjusted_OHLV

# %%
def gen_buy_sell_signal(stk_data):
    import pandas_ta as ta

    sma = pd.concat(
        [
            stk_data.ta.sma(close="Adj Close", length=10),
            stk_data.ta.sma(close="Adj Close", length=60),
        ],
        axis=1,
    ).dropna()
    buy_signal = sma["SMA_10"] > sma["SMA_60"]

    buy_sell_signal = stk_data[[]].copy()
    buy_sell_signal["Signal"] = (buy_signal).astype("int")

    return buy_sell_signal


def gen_analysis_data(stk_data, _return_period):
    import pandas_ta as ta

    try:
        adjusted_OHLV = to_adjusted(stk_data)
        data = pd.concat(
            [
                # stk_data.ta.adosc(prefix="B1"),
                # stk_data.ta.kvo(prefix="B1"),
                adjusted_OHLV.ta.adosc(
                    high="Adj High",
                    low="Adj Low",
                    close="Adj Close",
                    volume="Adj Volume",
                    prefix="B2",
                ),
                adjusted_OHLV.ta.kvo(
                    high="Adj High",
                    low="Adj Low",
                    close="Adj Close",
                    volume="Adj Volume",
                    prefix="B2",
                ),
                stk_data.ta.rsi(close="Adj Close", length=10, prefix="B3"),
                stk_data.ta.rsi(close="Adj Close", length=30, prefix="B3"),
                stk_data.ta.rsi(close="Adj Close", length=200, prefix="B3"),
                stk_data.ta.stoch(k=10, prefix="B3"),
                stk_data.ta.stoch(k=30, prefix="B3"),
                stk_data.ta.stoch(k=200, prefix="B3"),
                adjusted_OHLV.loc[
                    :,
                    [
                        "B4_Adj Open pct",
                        "B4_Adj High pct",
                        "B4_Adj Low pct",
                        "B4_Adj Volume pct",
                    ],
                ],
                gen_buy_sell_signal(stk_data),
            ],
            axis=1,
        )

        data = pd.concat(
            [data.astype("float32"), gen_pct_label(stk_data, _return_period)],
            axis=1,
        ).dropna()
    except:
        data = None
    return data


def prepare_analysis_data(_return_period, verbose=False):
    from tqdm import tqdm

    ticks_dataset = []
    ignore_ticks_data_count = 0
    for i, tick_data in enumerate(tqdm(ticks_data)):
        analysis_data = gen_analysis_data(tick_data, _return_period)
        if analysis_data is None:
            print(f"Failed to generate {stk_symbols[i]} analysis data")
            continue
        classes_percentage = class_percentage(analysis_data)
        if 0 in classes_percentage:
            if verbose:
                print(
                    f"Some classes don't have any data  : {stk_symbols[i]}, {classes_percentage}"
                )
            ignore_ticks_data_count += 1
        elif any(p < class_percentage_threshold for p in classes_percentage):
            if verbose:
                print(
                    f"Some classes are too small  : {stk_symbols[i]}, {classes_percentage}"
                )
            ignore_ticks_data_count += 1
        else:
            ticks_dataset.append(analysis_data)
    if ignore_ticks_data_count > 0:
        print(
            f"There are {ignore_ticks_data_count} stocks in total, some classes have no data or are too small"
        )
    return ticks_dataset

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import math
from MyPyUtil.util import ivmax


class LSTMDataSet(Dataset):
    def __init__(self, ticks_data_X, ticks_data_Y, _seq_len):
        self.ticks_data_X = ticks_data_X
        self.ticks_data_Y = ticks_data_Y
        self.seq_len = _seq_len

        len_array = [len(d) - self.seq_len + 1 for d in ticks_data_X]
        self.idx_boundary = [len_array[0]]

        for i in range(1, len(len_array)):
            self.idx_boundary.append(len_array[i] + self.idx_boundary[i - 1])

        self.build_class_indices()

    def build_class_indices(self):
        total_y = pd.concat(
            [t[self.seq_len - 1 :]["label"] for t in self.ticks_data_Y]
        ).reset_index()
        self.class_indices = []
        for i in range(num_classes):
            class_idx_list = total_y.index[total_y["label"] == i].tolist()
            self.class_indices.append(class_idx_list)

    def __len__(self):
        return self.idx_boundary[-1]

    def info(self):
        print(f"Dataset size: {self.idx_boundary[-1]}")
        for i in range(num_classes):
            print(
                f"class {i}: {len(self.class_indices[i]) * 100 /self.idx_boundary[-1]:.1f}% {len(self.class_indices[i])}"
            )

    def __getitem__(self, idx):
        for ticks_data_idx in range(len(self.ticks_data_X)):
            if self.idx_boundary[ticks_data_idx] > idx:
                break
        offset = (
            idx if ticks_data_idx == 0 else idx - self.idx_boundary[ticks_data_idx - 1]
        )
        x = np.array(self.ticks_data_X[ticks_data_idx][offset : offset + self.seq_len])
        y = int(self.ticks_data_Y[ticks_data_idx].iloc[offset + self.seq_len - 1, :])
        return (x, y)

# %%
import random
import math
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import StandardScaler, Normalizer
from sklearn_pandas import DataFrameMapper
from sklearn.utils.class_weight import compute_class_weight


def find_alpha_and_class_weight(y):
    weight_of_CE = compute_class_weight(
        class_weight="balanced", classes=np.unique(y), y=y["label"].values
    )
    alpha = []
    for i in range(len(weight_of_CE)):
        alpha.append(weight_of_CE[i] / sum(weight_of_CE))

    return (alpha, weight_of_CE)


def prepare_XYData(_return_period):
    ticks_dataset = prepare_analysis_data(_return_period)
    ticks_X_train_data = []
    ticks_Y_train_data = []
    ticks_X_test_data = []
    ticks_Y_test_data = []
    ticks_X_dfm = []
    for idx, dataset in enumerate(ticks_dataset):
        # test_size = int(dataset.shape[0] * validation_size)
        train_size = int(dataset.shape[0] * (1 - validation_size))
        train_data = dataset.iloc[0:train_size]
        test_data = dataset.iloc[train_size - seq_len + 1 :]

        X_train_data = train_data.iloc[:, :-1]
        Y_train_data = train_data.iloc[:, -1:]

        X_test_data = test_data.iloc[:, :-1]
        Y_test_data = test_data.iloc[:, -1:]

        features = [
            ([column], StandardScaler()) for column in X_train_data.columns[:-1].values
        ]
        features.extend(
            [([column], None) for column in X_train_data.columns[-1:].values]
        )
        if len(features) != 17:
            print(f"Wrong data: {stk_symbols[idx]}, {X_train_data.columns.values}")
            continue
        # print(idx)
        X_dfm = DataFrameMapper(features, input_df=True, df_out=True)
        X_train_data = X_dfm.fit_transform(X_train_data)
        X_test_data = X_dfm.transform(X_test_data)

        ticks_X_dfm.append(X_dfm)
        ticks_X_train_data.append(X_train_data)
        ticks_Y_train_data.append(Y_train_data)
        ticks_X_test_data.append(X_test_data)
        ticks_Y_test_data.append(Y_test_data)

    return [
        ticks_X_train_data,
        ticks_Y_train_data,
        ticks_X_test_data,
        ticks_Y_test_data,
    ], find_alpha_and_class_weight(pd.concat(ticks_Y_train_data))

# %%
from torch import nn


class StockPCTLabelPredictLSTM(nn.Module):
    def __init__(self, input_size, config):
        super().__init__()
        self.setup_model(
            input_size=input_size,
            hidden_size=config["hidden_size"],
            num_layers=config["num_layers"],
            num_fc_layers=config["num_fc_layers"],
            activation_type=config["activation_type"],
        )

    def setup_model(
        self,
        input_size,
        hidden_size,
        num_layers,
        num_fc_layers,
        activation_type,
    ):
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        """
            input_size    : The number of expected features in the input x
            hidden_size   : The number of features in the hidden state h
            num_layers    : Number of recurrent layers. E.g., setting num_layers=2 would mean stacking two LSTMs together to form a stacked LSTM, with the second LSTM taking in outputs of the first LSTM and computing the final results. Default: 1
            bias          : If False, then the layer does not use bias weights b_ih and b_hh. Default: True
            batch_first   : If True, then the input and output tensors are provided as (batch, seq, feature) instead of (seq, batch, feature). Note that this does not apply to hidden or cell states. See the Inputs/Outputs sections below for details. Default: False
            dropout       : If non-zero, introduces a Dropout layer on the outputs of each LSTM layer except the last layer, with dropout probability equal to dropout. Default: 0
            bidirectional : If True, becomes a bidirectional LSTM. Default: False
            proj_size     : If > 0, will use LSTM with projections of corresponding size. Default: 0
        """
        self.rnn = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)

        layers = []
        in_features = self.hidden_size
        for i in range(1, num_fc_layers):
            out_features = int(in_features / 2)
            if out_features <= num_classes:
                break
            layers.append(nn.Linear(in_features, out_features))
            (
                layers.append(nn.ReLU() if activation_type == 1 else nn.Sigmoid())
                if activation_type == 2
                else nn.Tanh()
            )
            in_features = out_features

        layers.append(nn.Linear(in_features, num_classes))
        self.fc = nn.Sequential(*layers)
        self.fc.apply(self.init_weights)

    def init_weights(self, m):
        if isinstance(m, nn.Linear):
            initrange = 0.5
            nn.init.uniform_(m.weight, -initrange, initrange)
            nn.init.zeros_(m.bias)

    def forward(self, x):
        h_0 = torch.zeros(self.num_layers, x.shape[0], self.hidden_size).to(device)
        c_0 = torch.zeros(self.num_layers, x.shape[0], self.hidden_size).to(device)
        out, (h_out, _) = self.rnn(x, (h_0, c_0))

        fc_input = h_out[-1].view(-1, self.hidden_size)
        return self.fc(fc_input)


def save_model(model, hyper_parameters, file_path, epoch_num=None):
    state = {
        "epoch_num": epoch_num,
        "time": str(datetime.now),
        "model_state": model.state_dict(),
        "input_size": model.input_size,
        "hyper_parameters": hyper_parameters,
    }
    torch.save(state, file_path)


def load_model(file_path):
    data_dict = torch.load(file_path)
    hyper_parameters = data_dict["hyper_parameters"]
    model = StockPCTLabelPredictLSTM(
        input_size=data_dict["input_size"],
        config=hyper_parameters,
    )
    model.load_state_dict(data_dict["model_state"])
    return model, hyper_parameters

# %%
import torch.nn as nn

METRICS_LABEL_NDX = 0  # ground_truth
METRICS_PBTY_NDX = 1  # Probability of predicition
METRICS_PRED_NDX = 2  # class(label) of predicition
METRICS_LOSS_NDX = 3
METRICS_SIZE = 4
softmax = nn.Softmax(dim=1)
totalTrainingSamples_count = 0

# %%
from collections import namedtuple
from torch.utils.tensorboard import SummaryWriter


def logMetrics(
    epoch_ndx,
    mode_str,
    metrics_t,
    classificationThreshold=0.5,
    config=None,
    log_hparam=False,
):
    log.info(
        "E{} {}".format(
            epoch_ndx,
            task_name,
        )
    )
    F1_rec = namedtuple(
        "f1_rec",
        "target_class pos_correct neg_correct pos_count neg_count pos_loss neg_loss precision recall F1",
    )
    F1_metrics = []
    for target_class in reversed(range(num_classes)):
        posLabel_mask = metrics_t[METRICS_LABEL_NDX] == target_class
        pos_count = posLabel_mask.sum()
        negLabel_mask = metrics_t[METRICS_LABEL_NDX] != target_class
        neg_count = negLabel_mask.sum()

        posPred_mask = metrics_t[METRICS_PRED_NDX] == target_class
        threshold_mask = metrics_t[METRICS_PBTY_NDX] > classificationThreshold
        # TP, truePos_count
        TP = pos_correct = int((posLabel_mask & posPred_mask & threshold_mask).sum())

        negPred_mask = metrics_t[METRICS_PRED_NDX] != target_class
        # TN, trueNeg_count
        TN = neg_correct = int((negLabel_mask & negPred_mask).sum())

        # FP, falsePos_count
        FP = neg_count - neg_correct
        # FN, falseNeg_count
        FN = pos_count - pos_correct

        # precision = TP / (TP + FP)
        precision = 0.0 if (TP + FP) == 0 else TP / np.float32(TP + FP)
        # recall = TP / (TP + FN)
        recall = 0.0 if (TP + FN) == 0 else TP / np.float32(TP + FN)
        # F1 = 2 * precision * recall / (precision + recall)
        F1 = (
            0.0
            if (precision + recall) == 0.0
            else (2 * precision * recall) / np.float32(precision + recall)
        )
        F1_metrics.append(
            F1_rec(
                target_class,
                pos_correct,
                neg_correct,
                pos_count,
                neg_count,
                metrics_t[METRICS_LOSS_NDX, posLabel_mask].mean(),
                metrics_t[METRICS_LOSS_NDX, negLabel_mask].mean(),
                precision,
                recall,
                F1,
            )
        )

        if num_classes == 2:
            break

    metrics_dict = {}
    metrics_dict[" e_loss/all"] = metrics_t[METRICS_LOSS_NDX].mean()
    log.info(
        ("E{} {:8} { e_loss/all:.4f} loss").format(
            epoch_ndx,
            mode_str,
            **metrics_dict,
        )
    )

    for target_class, rec in enumerate(F1_metrics):
        target_class_str = f"class {rec.target_class}" if num_classes > 2 else ""
        metrics_dict[f"{target_class_str} e_loss/pos"] = rec.pos_loss
        metrics_dict[f"{target_class_str} e_loss/neg"] = rec.neg_loss

        metrics_dict[f"{target_class_str} correct/all"] = (
            (rec.pos_correct + rec.neg_correct) / metrics_t.shape[1] * 100
        )
        metrics_dict[f"{target_class_str} correct/neg"] = (
            (rec.neg_correct) / rec.neg_count * 100
        )
        metrics_dict[f"{target_class_str} correct/pos"] = (
            (rec.pos_correct) / rec.pos_count * 100
        )
        metrics_dict[f"{target_class_str} pr/precision"] = rec.precision
        metrics_dict[f"{target_class_str} pr/recall"] = rec.recall
        metrics_dict[f"{target_class_str} pr/f1_score"] = rec.F1

        log.info(
            (
                "E{} {:8} {} {"
                + f"{target_class_str}"
                + " correct/all:-5.1f}% correct, "
                + "{"
                + f"{target_class_str}"
                + " pr/precision:.4f} precision, "
                + "{"
                + f"{target_class_str}"
                + " pr/recall:.4f} recall, "
                + "{"
                + f"{target_class_str}"
                + " pr/f1_score:.4f} f1 score"
            ).format(epoch_ndx, mode_str, target_class_str, **metrics_dict)
        )
        log.info(
            (
                "E{} {:8} {} {"
                + f"{target_class_str}"
                + " e_loss/neg:.4f} loss, "
                + "{"
                + f"{target_class_str}"
                + " correct/neg:-5.1f}% correct ({neg_correct:} of {neg_count:})"
            ).format(
                epoch_ndx,
                mode_str + "_neg",
                target_class_str,
                neg_correct=rec.neg_correct,
                neg_count=rec.neg_count,
                **metrics_dict,
            )
        )
        log.info(
            (
                "E{} {:8} {} {"
                + f"{target_class_str}"
                + " e_loss/pos:.4f} loss, "
                + "{"
                + f"{target_class_str}"
                + " correct/pos:-5.1f}% correct ({pos_correct:} of {pos_count:})"
            ).format(
                epoch_ndx,
                mode_str + "_pos",
                target_class_str,
                pos_correct=rec.pos_correct,
                pos_count=rec.pos_count,
                **metrics_dict,
            )
        )

    writer = SummaryWriter(log_dir=log_dir + f"/{mode_str}_cls")
    for key, value in metrics_dict.items():
        writer.add_scalar(key, value, totalTrainingSamples_count)

    writer.add_pr_curve(
        "pr",
        metrics_t[METRICS_LABEL_NDX],
        metrics_t[METRICS_PRED_NDX],
        totalTrainingSamples_count,
    )

    bins = [x / 50.0 for x in range(51)]
    negHist_mask = negLabel_mask & (metrics_t[METRICS_PBTY_NDX] > 0.01)
    posHist_mask = posLabel_mask & (metrics_t[METRICS_PBTY_NDX] < 0.99)
    if negHist_mask.any():
        writer.add_histogram(
            "is_neg",
            metrics_t[METRICS_PBTY_NDX, negHist_mask],
            totalTrainingSamples_count,
            bins=bins,
        )
    if posHist_mask.any():
        writer.add_histogram(
            "is_pos",
            metrics_t[METRICS_PBTY_NDX, posHist_mask],
            totalTrainingSamples_count,
            bins=bins,
        )

    if log_hparam:
        hparam = config.copy()
        hparam["0:trn,1:val"] = 0 if mode_str == "trn" else 1
        writer.add_hparams(
            hparam,
            {
                "loss": metrics_t[METRICS_LOSS_NDX].mean(),
                "F1": F1_metrics[-1].F1,
            },
        )

    writer.close()

    return float(metrics_dict[" e_loss/all"]), F1_metrics
# Out:
# 2024-02-20 11:03:16.435141: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-20 11:03:16.455517: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-20 11:03:16.799770: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2, ignore_index=-100, reduction="mean"):
        super().__init__()
        # use standard CE loss without reducion as basis
        self.CE = nn.CrossEntropyLoss(reduction="none", ignore_index=ignore_index)
        self.alpha = alpha
        if isinstance(alpha, (float, int)):
            self.alpha = torch.Tensor([alpha, 1 - alpha]).to(device)
        if isinstance(alpha, list):
            self.alpha = torch.Tensor(alpha).to(device)
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, input, target):
        """
        input (B, N)
        target (B)
        """
        minus_logpt = self.CE(input, target)
        pt = torch.exp(-minus_logpt)  # don't forget the minus here
        focal_loss = (1 - pt) ** self.gamma * minus_logpt

        # apply class weights
        if self.alpha != None:
            focal_loss *= self.alpha.gather(0, target)

        if self.reduction == "mean":
            return focal_loss.mean()
        elif self.reduction == "sum":
            return focal_loss.sum()
        else:
            return focal_loss

# %%
import sys


def computeBatchLoss(model, loss_fn, x, y, metrics_g, batch_idx):
    x_g = x.to(device)
    y_g = y.to(device)
    outputs = model(x_g)
    if outputs.isnan().sum() > 0:
        return sys.float_info.max

    loss_g = loss_fn(outputs, y_g)
    probability_g, predition_g = torch.max(softmax(outputs), dim=1)

    start_ndx = batch_idx * batch_size
    end_ndx = start_ndx + y.size(0)
    if metrics_g != None:
        metrics_g[METRICS_LABEL_NDX, start_ndx:end_ndx] = y_g
        metrics_g[METRICS_PBTY_NDX, start_ndx:end_ndx] = probability_g
        metrics_g[METRICS_PRED_NDX, start_ndx:end_ndx] = predition_g
        metrics_g[METRICS_LOSS_NDX, start_ndx:end_ndx] = loss_g
    loss = loss_g.mean()
    return loss

# %%
from MyPyUtil.util import enumerateWithEstimate
import torch
from tqdm import tqdm


def doTraining(model, optimizer, loss_fn, epoch_ndx, train_dl, trnMetrics_g):
    global totalTrainingSamples_count
    model.train()

    batch_iter = enumerateWithEstimate(
        train_dl,
        "E{} Training".format(epoch_ndx),
        start_ndx=train_dl.num_workers,
    )
    for batch_ndx, (x, y) in batch_iter:
        # for batch_ndx, (x, y) in enumerate(tqdm(train_dl)):
        optimizer.zero_grad()

        loss = computeBatchLoss(
            model,
            loss_fn,
            x,
            y,
            trnMetrics_g,
            batch_ndx,
        )

        if loss == sys.float_info.max:
            print(f"forward error: {batch_ndx}")
        else:
            loss.backward()
            optimizer.step()

    totalTrainingSamples_count += len(train_dl.dataset)
    return trnMetrics_g.to("cpu") if trnMetrics_g != None else None

# %%
from MyPyUtil.util import enumerateWithEstimate
import torch
from tqdm import tqdm


def doTrainingForRayTune(model, optimizer, loss_fn, epoch_ndx, train_dl):
    model.train()

    total_loss = 0.0
    batch_iter = enumerateWithEstimate(
        train_dl,
        "E{} Training".format(epoch_ndx),
        start_ndx=train_dl.num_workers,
    )
    for batch_ndx, (x, y) in batch_iter:
        # for batch_ndx, (x, y) in enumerate(tqdm(train_dl)):
        optimizer.zero_grad()

        loss = computeBatchLoss(
            model,
            loss_fn,
            x,
            y,
            None,
            batch_ndx,
        )

        if loss == sys.float_info.max:
            print(f"forward error: {batch_ndx}")
        else:
            loss.backward()
            optimizer.step()
            total_loss += loss.item() * len(x)

    return total_loss / len(train_dl.dataset)

# %%
def doValidation(model, loss_fn, epoch_ndx, val_dl, valMetrics_g):
    from sklearn.metrics import f1_score

    with torch.no_grad():
        model.eval()

        batch_iter = enumerateWithEstimate(
            val_dl,
            "E{} Validation ".format(epoch_ndx),
            start_ndx=val_dl.num_workers,
        )
        for batch_ndx, (x, y) in batch_iter:
            # for batch_ndx, (x, y) in enumerate(tqdm(val_dl)):
            loss = computeBatchLoss(model, loss_fn, x, y, valMetrics_g, batch_ndx)
            if loss == sys.float_info.max:
                print(f"forward error: {batch_ndx}")

    return valMetrics_g.to("cpu")

# %%
def config_2_str(config):
    return "_".join(
        (
            v
            if type(v).__name__ == "str"
            else "None" if v is None else str(v) if v < 1 else f"{v:g}"
        )
        for v in config.values()
    )

# %%
def ray_train_task(config, data, alpha, class_weight, time_str):
    global totalTrainingSamples_count
    global log_dir

    best_f1 = 0

    lr = config["lr"]
    momentum = config["momentum"]
    optim_type = config["optim_type"]
    totalTrainingSamples_count = 0

    id_str = config_2_str(config)
    # print(id_str)
    log_dir = f"{log_dir_base}/{time_str}/{id_str}"
    os.mkdir(log_dir)

    model_name = f"{log_dir}/{id_str}.pt"

    train_dataset = LSTMDataSet(
        data[0],
        data[1],
        seq_len,
    )
    test_dataset = LSTMDataSet(
        data[2],
        data[3],
        seq_len,
    )

    print("Training data:")
    train_dataset.info()
    print("\nTest data")
    test_dataset.info()

    train_loader = DataLoader(
        train_dataset,
        batch_size,
        shuffle=shuffle,
        num_workers=num_workers,
        pin_memory=pin_memory,
        pin_memory_device=device_name,
    )
    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        pin_memory=pin_memory,
        pin_memory_device=device_name,
    )

    features_size = len(data[0][0].columns)

    model = StockPCTLabelPredictLSTM(input_size=features_size, config=config)
    model = model.to(device)

    optimizer = (
        torch.optim.Adam(model.parameters(), lr=lr)
        if optim_type == 1
        else torch.optim.SGD(
            model.parameters(),
            lr=lr,
            momentum=momentum,
            weight_decay=config["weight decay"],
        )
    )

    if config["loss_fn"] == "CrossEntropy":
        loss_fn = torch.nn.CrossEntropyLoss(
            weight=torch.tensor(class_weight, dtype=torch.float32).to(device),
            reduction="none",
        )
    else:
        loss_fn = FocalLoss(alpha=alpha, reduction="none")

    trnMetrics_g = None
    # torch.empty(
    #     METRICS_SIZE,
    #     len(train_loader.dataset),
    #     device=device,
    # )
    valMetrics_g = torch.empty(
        METRICS_SIZE,
        len(test_loader.dataset),
        device=device,
    )

    for epoch_ndx in range(epoch_num):
        # trnMetrics_g.zero_()
        valMetrics_g.zero_()

        loss = doTrainingForRayTune(model, optimizer, loss_fn, epoch_ndx, train_loader)

        # trnMetrics_t = doTraining(
        #     model, optimizer, loss_fn, epoch_ndx, train_loader, trnMetrics_g
        # )
        # # loss, _ = logMetrics(
        #     epoch_ndx,
        #     "trn",
        #     trnMetrics_t,
        #     classificationThreshold,
        #     config,
        #     (epoch_ndx == epoch_num - 1),
        # )

        valMetrics_t = doValidation(
            model, loss_fn, epoch_ndx, test_loader, valMetrics_g
        )
        _, F1_metrics = logMetrics(
            epoch_ndx,
            "val",
            valMetrics_t,
            classificationThreshold,
            config,
            (epoch_ndx == epoch_num - 1),
        )
        if F1_metrics[0].F1 > best_f1:
            best_f1 = F1_metrics[0].F1
            save_model(model, config, model_name)

        train.report(
            {
                "loss": loss,
                "f1_score": F1_metrics[0].F1,
                "precision": F1_metrics[0].precision,
                "recall": F1_metrics[0].recall,
            }
        )

# %%
# config = {
#     "loss_fn": "CrossEntropy",
#     "lr": 0.01,
#     "momentum": 0.11646759543664197,
#     "optim_type": 2,  # 1: Adam, 2: SGD  => Adam bad result
#     "weight decay": 0.00001,  # best value
#     "num_layers": 6,  # [1, 2, 4, 8] best value = 3 or 4
#     "hidden_size": 256,  # [8, 16, 32, 64, 128]
#     "num_fc_layers": 1,  # 1, 2, 3]),
#     "activation_type": 2,  # 1: ReLU(),  2: Sigmoid(),  3: Tanh()  => meaningless num_fc_layers == 1
# }
# time_str = datetime.now().strftime("%Y-%m-%d_%H.%M.%S")
# log_dir = f"{log_dir_base}/{time_str}"
# os.mkdir(log_dir)

# XYData, (alpha, class_weight) = prepare_XYData(return_period)
# ray_train_task(
#     config,
#     data=XYData,
#     alpha=alpha,
#     class_weight=class_weight,
#     time_str=time_str,
# )

# %%
# best results after experiments
"""
CrossEntropy is better than Focal
CrossEntropy(best result: 0.3921) => lr = 0.01
Focal       (best result: 0.3865) => lr = 0.1 , num_fc_layers = 1
"""
search_space = {
    "loss_fn": tune.grid_search(["CrossEntropy", "Focal"]),
    "lr": tune.grid_search([0.01, 0.1]),  # , 0.01, 0.1, 0.08, 0.12]
    "momentum": tune.uniform(
        0.001, 0.2
    ),  # tune.grid_search([0.11646759543664197]),  # tune.uniform(0.1, 0.9),
    "optim_type": tune.grid_search([2]),  # 1: Adam, 2: SGD  => Adam bad result
    "weight decay": tune.grid_search([0.00001]),  # best value
    "num_layers": tune.grid_search([4, 6]),  # [1, 2, 4, 8] best value = 3 or 4
    "hidden_size": tune.grid_search([256]),  # [8, 16, 32, 64, 128]
    "num_fc_layers": tune.grid_search([2]),  # 1, 2, 3]),
    "activation_type": tune.grid_search(
        [2]
    ),  # 1: ReLU(),  2: Sigmoid(),  3: Tanh()  => meaningless num_fc_layers == 1
}

turning_parameters = []
total_configs = 1
for k, v in search_space.items():
    if (
        type(v).__name__ == "dict"
        and list(v.keys())[0] == "grid_search"
        and len(list(v.values())[0]) > 1
    ):
        turning_parameters.append(k)
        total_configs *= len(list(v.values())[0])
print(turning_parameters)
print(f"Total count of configs = {total_configs}")
# Out:
# ['loss_fn', 'lr', 'num_layers']
# Total count of configs = 8

# %%
import warnings


warnings.filterwarnings("ignore", category=Warning)

time_str = datetime.now().strftime("%Y-%m-%d_%H.%M.%S")
log_dir = f"{log_dir_base}/{time_str}"
os.mkdir(log_dir)

XYData, (alpha, class_weight) = prepare_XYData(return_period)
tuner = tune.Tuner(
    tune.with_resources(
        tune.with_parameters(
            ray_train_task,
            data=XYData,
            alpha=alpha,
            class_weight=class_weight,
            time_str=time_str,
        ),
        resources={"cpu": 0.125, "gpu": 0.125},
    ),
    tune_config=tune.TuneConfig(
        metric="f1_score",
        mode="max",
    ),
    param_space=search_space,
)
results = tuner.fit()
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-02-20 15:33:57</td></tr>
# <tr><td>Running for: </td><td>04:29:49.20        </td></tr>
# <tr><td>Memory:      </td><td>6.9/31.1 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 0.125/32 CPUs, 0.125/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                </th><th>status    </th><th>loc                </th><th style="text-align: right;">  activation_type</th><th style="text-align: right;">  hidden_size</th><th>loss_fn     </th><th style="text-align: right;">  lr</th><th style="text-align: right;">  momentum</th><th style="text-align: right;">  num_fc_layers</th><th style="text-align: right;">  num_layers</th><th style="text-align: right;">  optim_type</th><th style="text-align: right;">  weight decay</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">     loss</th><th style="text-align: right;">  f1_score</th><th style="text-align: right;">  precision</th></tr>
# </thead>
# <tbody>
# <tr><td>ray_train_task_d3131_00000</td><td>TERMINATED</td><td>192.168.0.125:11705</td><td style="text-align: right;">                2</td><td style="text-align: right;">          256</td><td>CrossEntropy</td><td style="text-align: right;">0.01</td><td style="text-align: right;"> 0.0755335</td><td style="text-align: right;">              2</td><td style="text-align: right;">           4</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">   100</td><td style="text-align: right;">         16036  </td><td style="text-align: right;">0.617959 </td><td style="text-align: right;">  0.348774</td><td style="text-align: right;">   0.242091</td></tr>
# <tr><td>ray_train_task_d3131_00001</td><td>TERMINATED</td><td>192.168.0.125:11706</td><td style="text-align: right;">                2</td><td style="text-align: right;">          256</td><td>Focal       </td><td style="text-align: right;">0.01</td><td style="text-align: right;"> 0.190192 </td><td style="text-align: right;">              2</td><td style="text-align: right;">           4</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">   100</td><td style="text-align: right;">         16113.8</td><td style="text-align: right;">0.0441208</td><td style="text-align: right;">  0.350255</td><td style="text-align: right;">   0.230883</td></tr>
# <tr><td>ray_train_task_d3131_00002</td><td>TERMINATED</td><td>192.168.0.125:11707</td><td style="text-align: right;">                2</td><td style="text-align: right;">          256</td><td>CrossEntropy</td><td style="text-align: right;">0.1 </td><td style="text-align: right;"> 0.146667 </td><td style="text-align: right;">              2</td><td style="text-align: right;">           4</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">   100</td><td style="text-align: right;">         16027.1</td><td style="text-align: right;">0.298195 </td><td style="text-align: right;">  0.29848 </td><td style="text-align: right;">   0.221905</td></tr>
# <tr><td>ray_train_task_d3131_00003</td><td>TERMINATED</td><td>192.168.0.125:11708</td><td style="text-align: right;">                2</td><td style="text-align: right;">          256</td><td>Focal       </td><td style="text-align: right;">0.1 </td><td style="text-align: right;"> 0.120133 </td><td style="text-align: right;">              2</td><td style="text-align: right;">           4</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">   100</td><td style="text-align: right;">         16123  </td><td style="text-align: right;">0.0433568</td><td style="text-align: right;">  0.344867</td><td style="text-align: right;">   0.26829 </td></tr>
# <tr><td>ray_train_task_d3131_00004</td><td>TERMINATED</td><td>192.168.0.125:11709</td><td style="text-align: right;">                2</td><td style="text-align: right;">          256</td><td>CrossEntropy</td><td style="text-align: right;">0.01</td><td style="text-align: right;"> 0.0320477</td><td style="text-align: right;">              2</td><td style="text-align: right;">           6</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">   100</td><td style="text-align: right;">         16147  </td><td style="text-align: right;">0.621128 </td><td style="text-align: right;">  0.34622 </td><td style="text-align: right;">   0.240791</td></tr>
# <tr><td>ray_train_task_d3131_00005</td><td>TERMINATED</td><td>192.168.0.125:11710</td><td style="text-align: right;">                2</td><td style="text-align: right;">          256</td><td>Focal       </td><td style="text-align: right;">0.01</td><td style="text-align: right;"> 0.0320429</td><td style="text-align: right;">              2</td><td style="text-align: right;">           6</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">   100</td><td style="text-align: right;">         16186.5</td><td style="text-align: right;">0.0448592</td><td style="text-align: right;">  0.353647</td><td style="text-align: right;">   0.240176</td></tr>
# <tr><td>ray_train_task_d3131_00006</td><td>TERMINATED</td><td>192.168.0.125:11711</td><td style="text-align: right;">                2</td><td style="text-align: right;">          256</td><td>CrossEntropy</td><td style="text-align: right;">0.1 </td><td style="text-align: right;"> 0.0125586</td><td style="text-align: right;">              2</td><td style="text-align: right;">           6</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">   100</td><td style="text-align: right;">         16149  </td><td style="text-align: right;">0.693631 </td><td style="text-align: right;">  0       </td><td style="text-align: right;">   0       </td></tr>
# <tr><td>ray_train_task_d3131_00007</td><td>TERMINATED</td><td>192.168.0.125:11712</td><td style="text-align: right;">                2</td><td style="text-align: right;">          256</td><td>Focal       </td><td style="text-align: right;">0.1 </td><td style="text-align: right;"> 0.173369 </td><td style="text-align: right;">              2</td><td style="text-align: right;">           6</td><td style="text-align: right;">           2</td><td style="text-align: right;">         1e-05</td><td style="text-align: right;">   100</td><td style="text-align: right;">         16186.6</td><td style="text-align: right;">0.043513 </td><td style="text-align: right;">  0.312433</td><td style="text-align: right;">   0.265745</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2024-02-20 15:33:57,583	INFO tune.py:1042 -- Total run time: 16189.22 seconds (16189.19 seconds for the tuning loop).
